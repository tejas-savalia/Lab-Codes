# %%
import numpy as np
import scipy.stats as stat
import matplotlib.pyplot as plt

# %%
angle_distribution_means = np.array(range(360))
angle_distribution_stds = np.ones(360) + 40
weights = np.random.rand(360)

# %% [markdown]
# Define the width of the distributions in terms of standard deviations. Read up on the populationv vector code.

# %%
def plot_gauss(mean, std):
    pdf = list()
    for x in range(360):
        pdf.append((1/np.sqrt(2*np.pi*std**2))*np.exp(-(x - mean)**2/(2 * std**2)))
        
    plt.plot(pdf)
    #plt.plot(pdf)

# %%
desired_direction = 45

# %%
discharge = np.random.normal(angle_distribution_means[desired_direction], angle_distribution_stds[desired_direction])

# %%
stat.norm.pdf(1, 3)
# Out:
# 0.05399096651318806

# %%
45 = weights*stat.norm.pdf()
# Out:
#   File "<ipython-input-7-ffa1b02a20d3>", line 1
#     45 = weights*stat.norm.pdf()
#                                 ^
# SyntaxError: can't assign to literal

# %%
weights*stat.norm.pdf(angle_distribution_means, angle_distribution_stds)
# Out:
# array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 1.35113183e-315,
#        4.04032384e-299, 2.93489126e-283, 2.27135118e-267, 1.01273228e-252,
#        6.46838661e-238, 9.42959874e-224, 3.13696773e-210, 6.96588874e-197,
#        6.25778482e-184, 2.12126599e-171, 1.25161792e-159, 1.14682289e-148,
#        5.68519448e-137, 2.62576749e-126, 4.36747294e-116, 1.65363388e-106,
#        1.57252325e-097, 1.31804353e-088, 4.60337106e-080, 2.36493356e-072,
#        3.38862995e-064, 4.34452041e-057, 1.20632833e-050, 1.72271504e-045,
#        5.77730161e-038, 3.81799335e-033, 1.97687079e-027, 2.71162181e-023,
#        1.68931940e-019, 1.25990974e-015, 7.34721982e-012, 4.88108550e-009,
#        8.50635938e-007, 4.85962441e-005, 1.92670304e-004, 5.55199672e-003,
#        1.83075629e-001, 3.45923308e-001, 1.92911087e-001, 1.77686008e-002,
#        3.32141074e-003, 1.27434725e-004, 2.73237678e-007, 2.49592803e-011,
# ...

# %%
plt.plot(weights*stat.norm.pdf(135, angle_distribution_means, angle_distribution_stds))

# %%
#Calculate neuronal discharge for a cell with preferred angle C when the movement direction is M
def discharge(C, M):
    b = 0.5
    k = 0.5
    return b + k*np.cos(M - C)

# %%
#100 cells. An arraw of w's indicate their discharge rates. Magnitude of contribution of cell i is the function of the 
#movement direction  and is taken to be equal to the change in cell activity from an offset level
num_cells = 100
def weights(num_cells, M):
