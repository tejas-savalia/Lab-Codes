# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ddm import Model, Sample
from ddm import Model
from ddm.models import DriftConstant, NoiseConstant, BoundConstant, OverlayNonDecision, ICRange
from ddm.functions import fit_adjust_model, display_model
from ddm import Fittable
from ddm.models import LossRobustBIC, LossRobustLikelihood, LossSquaredError
from ddm.functions import fit_adjust_model, fit_model
import seaborn as sns
import pickle

# %%
from ddm import set_N_cpus
set_N_cpus(8)
# Out:
# Warning: renormalizing probability density from Warning: renormalizing probability density from1.3790676848509882  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from1.157971787164501
#   2.081255163261618to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density fromWarning: renormalizing probability density from Warning: renormalizing probability density from 3.38829436350576431.0600633384272014 1.7421408454470706  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
#  Warning: renormalizing probability density from  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# 1.7406828854583705to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
#
#  1.8592448956529013 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012049483123583 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0117407841463493 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.012340940326857 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.013993781252387 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0107428803489569 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.108226923646892 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0317090205 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012226158971568 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0111326541071697 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.0540032485451512 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.3241295385528487 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.2642315677191285 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from Warning: renormalizing probability density from 1.02118068936894571.4751793493043335  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
#
# Warning: renormalizing probability density from 1.0639859142845045 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0131254706385018 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0131808788469234 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0410224454220187 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116128645664677 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.7636947931642037 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0966249553996685 Warning: renormalizing probability density from to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.1.3570949134429253 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
#
# Warning: renormalizing probability density from 1.0100657516489582 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012089801426232 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0800086003622789 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 2.34987803907173 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4260732576952082 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0121870102113295 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0810604975817122 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010361495037926 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.779058890989314 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 2.1875957080090855 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4892564049267112Warning: renormalizing probability density from  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.1.6252166144835831
#  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1647529714942513 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0244715186612556 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0140055054337866 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113447088748517 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1258059644008 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0136871585455958 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0410142662987591 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010608478515811 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# 1.0104435162415681 Warning: renormalizing probability density from 1.0756922716057722 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
#  1.0231429449225733 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0184275648771055 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0106127921825228 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0128837760092697 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.013750114107696 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115689932788925 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0109716169517013 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0155796095127703 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0149761771526031 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1220885698112804 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
# 1.6130720207886884 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0859424377573734 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1226707341248259 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0131582973341657 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0130643702497852 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0133459320528417 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0178703285874684 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0118418968758456 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0123632491989605 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102681499152188 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012256585893647 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0106806773139791 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0109155901889362 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102701672474605 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011562093432279 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011559533235737 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0114434210923564 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.0145989863011822 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0231250427200425 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120429298487208 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0264757031798524 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0118044302852045 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
# 1.0100896632899978 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0109732201268606 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012711295516405 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113093693487039 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113869993307474 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105443773945122 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117592320391124 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012974297377099 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0106753673375526 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from1.0111538549527022  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0125959180782198 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0101695092060954 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120204524495242 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0107538178757536 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0118097978746305 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100662954473212 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0110528365167752 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.0108775645326207 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012458656149874 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117075463812168 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0101216867129308 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105955917250997 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0112082798346596 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010189328800347 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0125382461932142 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0131070790739902 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115484058403086 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010220394227852 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0104364270840651 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012302292447416 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120812228168734 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0126480043577124 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0124804624102706 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011070473755393 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113276060728005 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0110254861780277 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0128750619203184 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120757557458457 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0118922137500699 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0111693241655337 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0104249372464824 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011986276186929 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0101746113388352 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100108760986486 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01172887914819 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0127394511309735 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100004005398406 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0129299535387029 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115471643012706 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0122928159632179 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0619432856315965 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4038027181870607 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0104167054259063 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01166774317762 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105012127240895 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0104959870785712 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114972813741399 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114797835194882 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105249723489496 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01626090119792 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105589595367261 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120341690348629 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116013005300237 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0112050979282683 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105283717080114 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010604940061303 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0106542227049444 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105080309001746 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010249210768754 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0135604585609936 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0123786820246938 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0109581885046368 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116055182616654 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from1.0114872708003677  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0129661527996097 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0119470307910765 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0109215326315184 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120031075724811 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0121194440066663 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0106010420332316 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0111234109255447 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011483654116637 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011350973736917 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011273740239809 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117083794108706 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120911129425338 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114518045161582 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012345664354816 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115910847037775 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116659144897262 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0105028042649309 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.011588167760695 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114637217633653 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0103029855585397 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012195115120845 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010829517452117 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117332631793343 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0118225874662745 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0108642054372499 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0111795195791475 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0119791744298061 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114559669752878 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0123625808608607 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0120714815013212 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117805130949915 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010462752983955 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011652963533781 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012357664377398 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011295657725518 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117849444304325 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0108500609111963 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.2755506338067952 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115604694697928 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0122173897538456 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0112393055643063 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011419558503516 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010173049486757 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102162735862024 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100172221936412 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01111277238519 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113622244500797 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0886540149980557 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 2.0644005780837453 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114941871587586 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from1.0116819858793702  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0138432888815634 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.026466169163764 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1691422884681926 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0406393988741893 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102812507484344 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0111171719314316 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113413962118853 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from  1.011379812724197to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011083894555074 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.1309178233429464 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01085499010462 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115831793943124 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0112529774953811 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# ...
# Warning: renormalizing probability density from 1.0132261593772283 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100532878184258 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.9436721529213672 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102181544695503 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4837084725614613 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.721409428400329 Warning: renormalizing probability density fromto 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from  1.41833930952686951.9684179378171083 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
#  to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
#
# 1.2755767842141275 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0107751940353977 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113533553665572 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0108105853694818 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114220261662061 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0144126770360224 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0110633357892176 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010088096054802 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102782910690684 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116696571363368 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102904506409456 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010188648447159 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114255380534996 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011455185215558 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.012288528818327 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0100237251357869 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011815152406344 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115159351901972 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0116855719815987 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011599649147631 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117451139134515 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0108915844548831 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.01033971299598 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0105722691060601 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0117844709986552 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0170033949180688 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102016706330246 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115424440319591 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115043077468593 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010463891289369 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.5950328261948992 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0167270391899752 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011592716312461 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0103027416170287 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.011509754860679 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0107098203323306 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115356200966346 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from
#  1.0114205759735695 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from 1.0108864903263917 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0124425192256394 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0113036778577336 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0112508013073158 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.010614801955697 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0115128507309827 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0108324382710179 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0464031121588289 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4003517366493763 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.233367270197312 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0481918424750458 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0128538957175712 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0200756168494898 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0129350141460893 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.9585872150954233 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102998950571134 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.Warning: renormalizing probability density from
#  1.0441941861467743 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0467675689823517 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.7453212841629187 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0125211750772778 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0110787012223357 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0435863654049 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0119521159247724 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0102331914680565 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0114501656476356 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.4347284488081258 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.7732024798834576 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.
# Warning: renormalizing probability density from 1.0127240211201651 to 1.  Try decreasing dt.  If that doesn't eliminate this warning, it may be due to extreme parameter values and/or bugs in your model speficiation.

# %%
incorrect_thresold = np.array([np.pi/9])
model_fits_4param = np.zeros((14, 12, len(incorrect_thresold)), dtype = object)

for participant in range(14):
    noise_fittable=Fittable(minval = 0, maxval = 10)
    ter_fittable=Fittable(minval=0, maxval=5)
    for block in range(12):
        for ic in range(len(incorrect_thresold)):
            df_rt = pd.read_csv(open('RTs.csv'))
            df_error = pd.read_csv(open('Angular_errors.csv'))

            df_rt['Correct'] = 0
            df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
            df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0

            df_rt = df_rt[df_rt['participant_id'] == participant]

            df_rt = df_rt[df_rt["ITs"] > .001]
            df_rt = df_rt[df_rt["ITs"] < 5]
            df_rt = df_rt.drop(['Trial', 'Unnamed: 0', 'participant_id', 'condition', 'MTs'], axis = 1)

            samp = Sample.from_pandas_dataframe(df_rt[df_rt['block'] == block], rt_column_name="ITs", correct_column_name="Correct")
            model_fit = Model(name='Simple model (fitted)',
                          drift=DriftConstant(drift=Fittable(minval=-20, maxval=20)),
                          noise=NoiseConstant(noise=Fittable(minval = 0, maxval = 5)),                      
                          bound=BoundConstant(B=Fittable(minval = 0, maxval = 20)),
                          overlay=OverlayNonDecision(nondectime=Fittable(minval = 0, maxval = 1)),
                          dx=.001, dt=.01, T_dur=5)

            try:
                fit_adjust_model(samp, model_fit,
                             fitting_method="differential_evolution",
                             lossfunction=LossRobustLikelihood, verbose=False)
            except:
                print (participant, block)
            model_fits_4param[participant][block][ic] = model_fit
# Out:
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= -1.50269
# differential_evolution step 2: f(x)= -1.50269
# differential_evolution step 3: f(x)= -1.50269
# differential_evolution step 4: f(x)= -1.54881
# differential_evolution step 5: f(x)= -1.54881
# differential_evolution step 6: f(x)= -1.82997
# differential_evolution step 7: f(x)= -1.8645
# differential_evolution step 8: f(x)= -1.92554
# differential_evolution step 9: f(x)= -1.92554
# differential_evolution step 10: f(x)= -1.99465
# differential_evolution step 11: f(x)= -1.99465
# differential_evolution step 12: f(x)= -1.99465
# differential_evolution step 13: f(x)= -1.99465
# differential_evolution step 14: f(x)= -2.00891
# differential_evolution step 15: f(x)= -2.01293
# differential_evolution step 16: f(x)= -2.01293
# differential_evolution step 17: f(x)= -2.01293
# differential_evolution step 18: f(x)= -2.01293
# differential_evolution step 19: f(x)= -2.01293
# differential_evolution step 20: f(x)= -2.01431
# differential_evolution step 21: f(x)= -2.01431
# differential_evolution step 22: f(x)= -2.01431
# differential_evolution step 23: f(x)= -2.01431
# differential_evolution step 24: f(x)= -2.01431
# differential_evolution step 25: f(x)= -2.01431
# differential_evolution step 26: f(x)= -2.01431
# differential_evolution step 27: f(x)= -2.01447
# differential_evolution step 28: f(x)= -2.01447
# differential_evolution step 29: f(x)= -2.01447
# differential_evolution step 30: f(x)= -2.01447
# Params [-8.71075947  3.46972448  2.47385627  0.11325156] gave -2.0145553054891496
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 136.948
# differential_evolution step 2: f(x)= 109.307
# differential_evolution step 3: f(x)= 109.307
# differential_evolution step 4: f(x)= 105.49
# differential_evolution step 5: f(x)= 105.49
# differential_evolution step 6: f(x)= 104.115
# differential_evolution step 7: f(x)= 104.115
# differential_evolution step 8: f(x)= 104.026
# differential_evolution step 9: f(x)= 104.026
# differential_evolution step 10: f(x)= 103.888
# differential_evolution step 11: f(x)= 103.815
# differential_evolution step 12: f(x)= 103.795
# differential_evolution step 13: f(x)= 103.783
# differential_evolution step 14: f(x)= 103.698
# Params [-3.70686801e-06  4.36968445e+00  4.75378589e+00  3.92231843e-01] gave 103.64233364085328
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 179.852
# differential_evolution step 2: f(x)= 133.561
# differential_evolution step 3: f(x)= 108.308
# differential_evolution step 4: f(x)= 105.794
# differential_evolution step 5: f(x)= 105.642
# differential_evolution step 6: f(x)= 102.163
# differential_evolution step 7: f(x)= 102.163
# differential_evolution step 8: f(x)= 102.163
# differential_evolution step 9: f(x)= 100.137
# differential_evolution step 10: f(x)= 100.137
# differential_evolution step 11: f(x)= 100.137
# differential_evolution step 12: f(x)= 100.137
# differential_evolution step 13: f(x)= 99.9441
# differential_evolution step 14: f(x)= 99.9441
# differential_evolution step 15: f(x)= 99.7448
# differential_evolution step 16: f(x)= 99.7448
# differential_evolution step 17: f(x)= 99.7448
# Params [2.4807799  4.61722685 5.75978716 0.23441022] gave 99.74277985184057
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 81.8244
# differential_evolution step 2: f(x)= 81.8244
# differential_evolution step 3: f(x)= 81.8244
# differential_evolution step 4: f(x)= 81.7276
# differential_evolution step 5: f(x)= 81.7276
# differential_evolution step 6: f(x)= 81.7276
# differential_evolution step 7: f(x)= 81.3259
# differential_evolution step 8: f(x)= 80.7813
# differential_evolution step 9: f(x)= 80.6734
# differential_evolution step 10: f(x)= 80.6734
# differential_evolution step 11: f(x)= 80.5603
# differential_evolution step 12: f(x)= 80.4519
# differential_evolution step 13: f(x)= 80.4519
# differential_evolution step 14: f(x)= 80.4177
# differential_evolution step 15: f(x)= 80.383
# differential_evolution step 16: f(x)= 80.383
# Params [4.02164964 4.70176327 6.05677167 0.32626936] gave 80.38230081245871
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 207.2
# differential_evolution step 2: f(x)= 149.725
# differential_evolution step 3: f(x)= 144.172
# differential_evolution step 4: f(x)= 141.592
# differential_evolution step 5: f(x)= 141.592
# differential_evolution step 6: f(x)= 141.592
# differential_evolution step 7: f(x)= 141.592
# differential_evolution step 8: f(x)= 141.592
# differential_evolution step 9: f(x)= 131.491
# differential_evolution step 10: f(x)= 129.777
# differential_evolution step 11: f(x)= 127.305
# differential_evolution step 12: f(x)= 127.305
# differential_evolution step 13: f(x)= 127.302
# differential_evolution step 14: f(x)= 127.302
# differential_evolution step 15: f(x)= 127.302
# differential_evolution step 16: f(x)= 127.146
# differential_evolution step 17: f(x)= 127.146
# differential_evolution step 18: f(x)= 127.146
# differential_evolution step 19: f(x)= 127.117
# differential_evolution step 20: f(x)= 126.965
# differential_evolution step 21: f(x)= 126.965
# differential_evolution step 22: f(x)= 126.939
# differential_evolution step 23: f(x)= 126.939
# differential_evolution step 24: f(x)= 126.939
# differential_evolution step 25: f(x)= 126.936
# differential_evolution step 26: f(x)= 126.936
# Params [1.39427556 3.44443733 3.71621003 0.00927596] gave 126.93434926914152
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 217.402
# differential_evolution step 2: f(x)= 200.676
# differential_evolution step 3: f(x)= 128.035
# differential_evolution step 4: f(x)= 128.035
# differential_evolution step 5: f(x)= 128.035
# differential_evolution step 6: f(x)= 128.035
# differential_evolution step 7: f(x)= 111.197
# differential_evolution step 8: f(x)= 111.197
# differential_evolution step 9: f(x)= 111.197
# differential_evolution step 10: f(x)= 110.846
# differential_evolution step 11: f(x)= 110.846
# differential_evolution step 12: f(x)= 110.068
# differential_evolution step 13: f(x)= 110.068
# differential_evolution step 14: f(x)= 110.068
# differential_evolution step 15: f(x)= 110.068
# differential_evolution step 16: f(x)= 109.947
# differential_evolution step 17: f(x)= 109.939
# differential_evolution step 18: f(x)= 109.939
# differential_evolution step 19: f(x)= 109.939
# differential_evolution step 20: f(x)= 109.939
# Params [2.38772082 4.2124888  5.65978434 0.00950425] gave 109.93619172602983
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 95.9726
# differential_evolution step 2: f(x)= 93.0551
# differential_evolution step 3: f(x)= 80.2677
# differential_evolution step 4: f(x)= 78.539
# differential_evolution step 5: f(x)= 78.539
# differential_evolution step 6: f(x)= 78.539
# differential_evolution step 7: f(x)= 78.539
# differential_evolution step 8: f(x)= 78.539
# differential_evolution step 9: f(x)= 78.4612
# differential_evolution step 10: f(x)= 78.4612
# differential_evolution step 11: f(x)= 78.4612
# differential_evolution step 12: f(x)= 78.3688
# differential_evolution step 13: f(x)= 78.3439
# differential_evolution step 14: f(x)= 78.3439
# differential_evolution step 15: f(x)= 78.3388
# differential_evolution step 16: f(x)= 78.3388
# differential_evolution step 17: f(x)= 78.3388
# Params [3.84829344 3.91172763 6.28159907 0.13156578] gave 78.33718483805188
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 102.275
# differential_evolution step 2: f(x)= 93.2095
# differential_evolution step 3: f(x)= 88.2838
# differential_evolution step 4: f(x)= 87.077
# differential_evolution step 5: f(x)= 84.2132
# differential_evolution step 6: f(x)= 64.1443
# differential_evolution step 7: f(x)= 64.1443
# differential_evolution step 8: f(x)= 64.1443
# differential_evolution step 9: f(x)= 64.1443
# differential_evolution step 10: f(x)= 58.524
# differential_evolution step 11: f(x)= 58.524
# differential_evolution step 12: f(x)= 58.524
# differential_evolution step 13: f(x)= 58.2174
# differential_evolution step 14: f(x)= 56.9056
# differential_evolution step 15: f(x)= 56.5806
# differential_evolution step 16: f(x)= 56.5806
# differential_evolution step 17: f(x)= 56.5806
# differential_evolution step 18: f(x)= 56.5806
# differential_evolution step 19: f(x)= 56.5806
# differential_evolution step 20: f(x)= 56.5806
# differential_evolution step 21: f(x)= 56.5806
# differential_evolution step 22: f(x)= 56.3374
# differential_evolution step 23: f(x)= 56.3374
# differential_evolution step 24: f(x)= 56.3374
# differential_evolution step 25: f(x)= 56.325
# differential_evolution step 26: f(x)= 56.3249
# differential_evolution step 27: f(x)= 56.3191
# differential_evolution step 28: f(x)= 56.3191
# differential_evolution step 29: f(x)= 56.3171
# Params [5.63294259e+00 4.08033207e+00 5.22016764e+00 4.30379568e-03] gave 56.3149874464897
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 41.2809
# differential_evolution step 2: f(x)= 41.2809
# differential_evolution step 3: f(x)= 41.2809
# differential_evolution step 4: f(x)= 41.2809
# differential_evolution step 5: f(x)= 41.2809
# differential_evolution step 6: f(x)= 41.2809
# differential_evolution step 7: f(x)= 41.2809
# differential_evolution step 8: f(x)= 41.2487
# differential_evolution step 9: f(x)= 41.2487
# differential_evolution step 10: f(x)= 41.0937
# differential_evolution step 11: f(x)= 41.0937
# differential_evolution step 12: f(x)= 41.0932
# differential_evolution step 13: f(x)= 41.0932
# differential_evolution step 14: f(x)= 41.0932
# differential_evolution step 15: f(x)= 41.0932
# differential_evolution step 16: f(x)= 41.0932
# Params [7.03808046 4.69153298 6.10302119 0.11020413] gave 41.087672986174894
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 101.019
# differential_evolution step 2: f(x)= 88.3474
# differential_evolution step 3: f(x)= 83.9732
# differential_evolution step 4: f(x)= 64.5657
# differential_evolution step 5: f(x)= 60.6307
# differential_evolution step 6: f(x)= 60.6307
# differential_evolution step 7: f(x)= 60.6307
# differential_evolution step 8: f(x)= 60.6307
# differential_evolution step 9: f(x)= 60.6307
# differential_evolution step 10: f(x)= 60.6307
# differential_evolution step 11: f(x)= 60.6128
# differential_evolution step 12: f(x)= 60.6128
# differential_evolution step 13: f(x)= 59.8567
# differential_evolution step 14: f(x)= 59.8567
# differential_evolution step 15: f(x)= 59.8567
# differential_evolution step 16: f(x)= 59.8567
# differential_evolution step 17: f(x)= 59.8567
# differential_evolution step 18: f(x)= 59.7774
# differential_evolution step 19: f(x)= 59.7774
# differential_evolution step 20: f(x)= 59.7419
# Params [3.43325275 3.88172033 3.99888093 0.05178499] gave 59.730103134709026
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 201.707
# differential_evolution step 2: f(x)= 93.406
# differential_evolution step 3: f(x)= 93.406
# differential_evolution step 4: f(x)= 93.0231
# differential_evolution step 5: f(x)= 93.0231
# differential_evolution step 6: f(x)= 76.3194
# differential_evolution step 7: f(x)= 76.3194
# differential_evolution step 8: f(x)= 76.3194
# differential_evolution step 9: f(x)= 76.3194
# differential_evolution step 10: f(x)= 76.3194
# differential_evolution step 11: f(x)= 76.3194
# differential_evolution step 12: f(x)= 76.3194
# differential_evolution step 13: f(x)= 76.3194
# differential_evolution step 14: f(x)= 76.3194
# differential_evolution step 15: f(x)= 76.2436
# differential_evolution step 16: f(x)= 76.2436
# differential_evolution step 17: f(x)= 76.2436
# differential_evolution step 18: f(x)= 76.2404
# differential_evolution step 19: f(x)= 76.2215
# differential_evolution step 20: f(x)= 76.2215
# Params [0.99023529 4.73342325 4.12027743 0.35690875] gave 76.2009043781116
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 45.5998
# differential_evolution step 2: f(x)= 29.0624
# differential_evolution step 3: f(x)= 29.0624
# differential_evolution step 4: f(x)= 29.0624
# differential_evolution step 5: f(x)= 24.4904
# differential_evolution step 6: f(x)= 24.4904
# differential_evolution step 7: f(x)= 22.3978
# differential_evolution step 8: f(x)= 22.3978
# differential_evolution step 9: f(x)= 22.294
# differential_evolution step 10: f(x)= 22.294
# differential_evolution step 11: f(x)= 22.294
# differential_evolution step 12: f(x)= 22.294
# differential_evolution step 13: f(x)= 22.294
# differential_evolution step 14: f(x)= 22.1995
# differential_evolution step 15: f(x)= 22.1995
# differential_evolution step 16: f(x)= 22.1995
# differential_evolution step 17: f(x)= 22.1995
# differential_evolution step 18: f(x)= 22.1995
# differential_evolution step 19: f(x)= 22.1635
# differential_evolution step 20: f(x)= 22.1635
# differential_evolution step 21: f(x)= 22.1635
# differential_evolution step 22: f(x)= 22.1635
# Params [6.79222824 4.59667009 3.80364863 0.38870389] gave 22.160787116628487
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= -0.922611
# differential_evolution step 2: f(x)= -0.922611
# differential_evolution step 3: f(x)= -0.922611
# differential_evolution step 4: f(x)= -0.997761
# differential_evolution step 5: f(x)= -0.997761
# differential_evolution step 6: f(x)= -0.997761
# differential_evolution step 7: f(x)= -1.02517
# differential_evolution step 8: f(x)= -1.05882
# differential_evolution step 9: f(x)= -1.10653
# differential_evolution step 10: f(x)= -1.1261
# differential_evolution step 11: f(x)= -1.1261
# differential_evolution step 12: f(x)= -1.1261
# differential_evolution step 13: f(x)= -1.12783
# differential_evolution step 14: f(x)= -1.12783
# differential_evolution step 15: f(x)= -1.14957
# differential_evolution step 16: f(x)= -1.14957
# differential_evolution step 17: f(x)= -1.15334
# differential_evolution step 18: f(x)= -1.15442
# differential_evolution step 19: f(x)= -1.15442
# differential_evolution step 20: f(x)= -1.15442
# differential_evolution step 21: f(x)= -1.15442
# differential_evolution step 22: f(x)= -1.15442
# differential_evolution step 23: f(x)= -1.1551
# differential_evolution step 24: f(x)= -1.15672
# differential_evolution step 25: f(x)= -1.15672
# differential_evolution step 26: f(x)= -1.15672
# differential_evolution step 27: f(x)= -1.15672
# differential_evolution step 28: f(x)= -1.15672
# Params [-10.66307646   3.88227623   2.55913762   0.7979495 ] gave -1.1569471991726916
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 73.898
# differential_evolution step 2: f(x)= 59.8046
# differential_evolution step 3: f(x)= 57.5123
# differential_evolution step 4: f(x)= 57.5123
# differential_evolution step 5: f(x)= 56.2577
# differential_evolution step 6: f(x)= 56.2577
# differential_evolution step 7: f(x)= 56.2577
# differential_evolution step 8: f(x)= 56.2088
# differential_evolution step 9: f(x)= 56.0453
# differential_evolution step 10: f(x)= 56.0453
# differential_evolution step 11: f(x)= 55.822
# differential_evolution step 12: f(x)= 55.822
# differential_evolution step 13: f(x)= 55.6454
# differential_evolution step 14: f(x)= 55.6454
# differential_evolution step 15: f(x)= 55.6454
# differential_evolution step 16: f(x)= 55.6454
# differential_evolution step 17: f(x)= 55.6346
# Params [4.68132473 4.67186151 4.78223307 0.53057628] gave 55.60849279583991
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 114.963
# differential_evolution step 2: f(x)= 112.306
# differential_evolution step 3: f(x)= 102.953
# differential_evolution step 4: f(x)= 102.953
# differential_evolution step 5: f(x)= 102.953
# differential_evolution step 6: f(x)= 100.209
# differential_evolution step 7: f(x)= 100.209
# differential_evolution step 8: f(x)= 100.209
# differential_evolution step 9: f(x)= 100.209
# differential_evolution step 10: f(x)= 100.209
# differential_evolution step 11: f(x)= 99.8581
# differential_evolution step 12: f(x)= 99.8581
# differential_evolution step 13: f(x)= 99.8223
# differential_evolution step 14: f(x)= 99.8223
# differential_evolution step 15: f(x)= 99.8223
# differential_evolution step 16: f(x)= 99.8223
# differential_evolution step 17: f(x)= 99.8053
# differential_evolution step 18: f(x)= 99.7876
# Params [-0.12880449  1.58772783  1.8264471   0.34440066] gave 99.75025809409163
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 99.8133
# differential_evolution step 2: f(x)= 85.7068
# differential_evolution step 3: f(x)= 75.3225
# differential_evolution step 4: f(x)= 70.2182
# differential_evolution step 5: f(x)= 68.7585
# differential_evolution step 6: f(x)= 68.7585
# differential_evolution step 7: f(x)= 68.7585
# differential_evolution step 8: f(x)= 68.7585
# differential_evolution step 9: f(x)= 68.3892
# differential_evolution step 10: f(x)= 68.2988
# differential_evolution step 11: f(x)= 68.2407
# differential_evolution step 12: f(x)= 68.2407
# differential_evolution step 13: f(x)= 68.2099
# differential_evolution step 14: f(x)= 68.0964
# differential_evolution step 15: f(x)= 67.9704
# differential_evolution step 16: f(x)= 67.9704
# differential_evolution step 17: f(x)= 67.9704
# differential_evolution step 18: f(x)= 67.9704
# differential_evolution step 19: f(x)= 67.9704
# differential_evolution step 20: f(x)= 67.9704
# Params [-5.25769803e+00  3.92295511e+00  1.16100534e+01  6.62456240e-03] gave 67.92057225178937
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 56.6283
# differential_evolution step 2: f(x)= 48.1475
# differential_evolution step 3: f(x)= 48.1475
# differential_evolution step 4: f(x)= 48.1475
# differential_evolution step 5: f(x)= 46.5545
# differential_evolution step 6: f(x)= 46.3095
# differential_evolution step 7: f(x)= 45.3595
# differential_evolution step 8: f(x)= 45.3595
# differential_evolution step 9: f(x)= 45.0151
# differential_evolution step 10: f(x)= 45.0151
# differential_evolution step 11: f(x)= 45.0151
# differential_evolution step 12: f(x)= 44.927
# differential_evolution step 13: f(x)= 44.927
# differential_evolution step 14: f(x)= 44.927
# differential_evolution step 15: f(x)= 44.927
# differential_evolution step 16: f(x)= 44.8879
# differential_evolution step 17: f(x)= 44.8323
# differential_evolution step 18: f(x)= 44.8263
# differential_evolution step 19: f(x)= 44.8263
# Params [5.51925064 4.32637481 5.33412401 0.45251542] gave 44.825318537098305
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 58.53
# differential_evolution step 2: f(x)= 55.9455
# differential_evolution step 3: f(x)= 55.9455
# differential_evolution step 4: f(x)= 55.5617
# differential_evolution step 5: f(x)= 55.2806
# differential_evolution step 6: f(x)= 54.8922
# differential_evolution step 7: f(x)= 54.8922
# differential_evolution step 8: f(x)= 54.8922
# differential_evolution step 9: f(x)= 54.8922
# differential_evolution step 10: f(x)= 54.3629
# differential_evolution step 11: f(x)= 54.3629
# differential_evolution step 12: f(x)= 54.3263
# differential_evolution step 13: f(x)= 54.3263
# differential_evolution step 14: f(x)= 54.3263
# differential_evolution step 15: f(x)= 54.3263
# Params [6.44616877 4.1565182  8.02548011 0.25907498] gave 54.31441299442147
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 133.578
# differential_evolution step 2: f(x)= 132.687
# differential_evolution step 3: f(x)= 107.528
# differential_evolution step 4: f(x)= 107.528
# differential_evolution step 5: f(x)= 107.528
# differential_evolution step 6: f(x)= 105.349
# differential_evolution step 7: f(x)= 105.349
# differential_evolution step 8: f(x)= 105.349
# differential_evolution step 9: f(x)= 101.259
# differential_evolution step 10: f(x)= 100.526
# differential_evolution step 11: f(x)= 99.9192
# differential_evolution step 12: f(x)= 99.9192
# differential_evolution step 13: f(x)= 99.9192
# differential_evolution step 14: f(x)= 99.9192
# differential_evolution step 15: f(x)= 99.1348
# differential_evolution step 16: f(x)= 99.1348
# differential_evolution step 17: f(x)= 99.1348
# differential_evolution step 18: f(x)= 99.1348
# differential_evolution step 19: f(x)= 99.1348
# differential_evolution step 20: f(x)= 99.1348
# differential_evolution step 21: f(x)= 99.1348
# differential_evolution step 22: f(x)= 99.1241
# differential_evolution step 23: f(x)= 99.1241
# Params [3.02802401 4.57008702 7.40240958 0.00998779] gave 99.12398265361259
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 114.523
# differential_evolution step 2: f(x)= 109.456
# differential_evolution step 3: f(x)= 105.454
# differential_evolution step 4: f(x)= 103.749
# differential_evolution step 5: f(x)= 103.207
# differential_evolution step 6: f(x)= 103.207
# differential_evolution step 7: f(x)= 102.69
# differential_evolution step 8: f(x)= 102.69
# differential_evolution step 9: f(x)= 102.557
# differential_evolution step 10: f(x)= 101.83
# differential_evolution step 11: f(x)= 101.791
# differential_evolution step 12: f(x)= 101.78
# differential_evolution step 13: f(x)= 101.718
# differential_evolution step 14: f(x)= 101.718
# differential_evolution step 15: f(x)= 101.718
# differential_evolution step 16: f(x)= 101.718
# differential_evolution step 17: f(x)= 101.718
# Params [1.32974905 2.98310842 4.05435862 0.36996133] gave 101.69942948732913
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 95.1727
# differential_evolution step 2: f(x)= 83.2768
# differential_evolution step 3: f(x)= 83.2767
# differential_evolution step 4: f(x)= 83.2767
# differential_evolution step 5: f(x)= 83.2767
# differential_evolution step 6: f(x)= 83.2767
# differential_evolution step 7: f(x)= 82.5295
# differential_evolution step 8: f(x)= 82.5295
# differential_evolution step 9: f(x)= 82.5295
# differential_evolution step 10: f(x)= 82.5295
# differential_evolution step 11: f(x)= 82.5019
# differential_evolution step 12: f(x)= 82.3881
# differential_evolution step 13: f(x)= 82.3881
# differential_evolution step 14: f(x)= 82.3881
# differential_evolution step 15: f(x)= 82.3798
# differential_evolution step 16: f(x)= 82.3229
# differential_evolution step 17: f(x)= 82.3229
# differential_evolution step 18: f(x)= 82.3229
# differential_evolution step 19: f(x)= 82.3229
# Params [2.63596823 3.08357007 3.98192618 0.64499216] gave 82.27714421510417
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 84.1639
# differential_evolution step 2: f(x)= 80.3609
# differential_evolution step 3: f(x)= 80.3609
# differential_evolution step 4: f(x)= 78.0626
# differential_evolution step 5: f(x)= 78.0626
# differential_evolution step 6: f(x)= 77.5249
# differential_evolution step 7: f(x)= 77.5249
# differential_evolution step 8: f(x)= 77.5249
# differential_evolution step 9: f(x)= 77.5249
# differential_evolution step 10: f(x)= 77.5249
# differential_evolution step 11: f(x)= 77.4773
# differential_evolution step 12: f(x)= 77.4544
# differential_evolution step 13: f(x)= 77.4544
# differential_evolution step 14: f(x)= 77.4544
# Params [4.11779616 4.92170495 6.26911521 0.61291705] gave 77.44260824386465
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 79.624
# differential_evolution step 2: f(x)= 79.624
# differential_evolution step 3: f(x)= 79.0796
# differential_evolution step 4: f(x)= 79.0796
# differential_evolution step 5: f(x)= 79.0796
# differential_evolution step 6: f(x)= 77.8339
# differential_evolution step 7: f(x)= 77.8339
# differential_evolution step 8: f(x)= 77.8339
# differential_evolution step 9: f(x)= 77.8339
# differential_evolution step 10: f(x)= 77.8339
# differential_evolution step 11: f(x)= 77.8339
# differential_evolution step 12: f(x)= 77.7752
# differential_evolution step 13: f(x)= 77.7453
# differential_evolution step 14: f(x)= 77.7453
# differential_evolution step 15: f(x)= 77.6015
# Params [4.85633726 4.8075586  6.9220153  0.5020518 ] gave 77.59326109202928
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 73.9055
# differential_evolution step 2: f(x)= 25.0816
# differential_evolution step 3: f(x)= 18.6678
# differential_evolution step 4: f(x)= 18.6033
# differential_evolution step 5: f(x)= 14.2419
# differential_evolution step 6: f(x)= 14.2419
# differential_evolution step 7: f(x)= 12.9466
# differential_evolution step 8: f(x)= 12.9466
# differential_evolution step 9: f(x)= 12.3718
# differential_evolution step 10: f(x)= 12.3718
# differential_evolution step 11: f(x)= 12.3718
# differential_evolution step 12: f(x)= 12.3718
# differential_evolution step 13: f(x)= 12.3718
# differential_evolution step 14: f(x)= 12.3492
# differential_evolution step 15: f(x)= 12.3194
# differential_evolution step 16: f(x)= 12.261
# differential_evolution step 17: f(x)= 12.261
# differential_evolution step 18: f(x)= 12.2496
# differential_evolution step 19: f(x)= 12.2373
# differential_evolution step 20: f(x)= 12.2373
# differential_evolution step 21: f(x)= 12.231
# differential_evolution step 22: f(x)= 12.1958
# differential_evolution step 23: f(x)= 12.1958
# differential_evolution step 24: f(x)= 12.1958
# differential_evolution step 25: f(x)= 12.1958
# differential_evolution step 26: f(x)= 12.1958
# differential_evolution step 27: f(x)= 12.192
# differential_evolution step 28: f(x)= 12.1839
# differential_evolution step 29: f(x)= 12.1839
# Params [4.19194704 2.37291458 2.11765597 0.55430857] gave 12.183649726799999
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= -0
# Params [-1.21352071  2.87608252  4.4685319   0.14581821] gave -0.0
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 46.2681
# differential_evolution step 2: f(x)= 46.2681
# differential_evolution step 3: f(x)= 46.2681
# differential_evolution step 4: f(x)= 46.2681
# differential_evolution step 5: f(x)= 46.2681
# differential_evolution step 6: f(x)= 45.783
# differential_evolution step 7: f(x)= 45.783
# differential_evolution step 8: f(x)= 45.783
# differential_evolution step 9: f(x)= 45.783
# differential_evolution step 10: f(x)= 45.783
# differential_evolution step 11: f(x)= 45.783
# differential_evolution step 12: f(x)= 45.5743
# differential_evolution step 13: f(x)= 45.1452
# differential_evolution step 14: f(x)= 45.1452
# differential_evolution step 15: f(x)= 45.1452
# differential_evolution step 16: f(x)= 45.1452
# differential_evolution step 17: f(x)= 45.1452
# differential_evolution step 18: f(x)= 45.1124
# differential_evolution step 19: f(x)= 45.1124
# differential_evolution step 20: f(x)= 45.1124
# Params [-7.18330394  4.46275881  7.44514703  0.59685944] gave 45.08154411477443
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 71.4499
# differential_evolution step 2: f(x)= 54.8844
# differential_evolution step 3: f(x)= 49.785
# differential_evolution step 4: f(x)= 43.3232
# differential_evolution step 5: f(x)= 43.3232
# differential_evolution step 6: f(x)= 43.3232
# differential_evolution step 7: f(x)= 43.3232
# differential_evolution step 8: f(x)= 42.7233
# differential_evolution step 9: f(x)= 42.605
# differential_evolution step 10: f(x)= 42.605
# differential_evolution step 11: f(x)= 42.605
# differential_evolution step 12: f(x)= 42.2046
# differential_evolution step 13: f(x)= 42.2046
# differential_evolution step 14: f(x)= 42.2046
# differential_evolution step 15: f(x)= 42.2046
# differential_evolution step 16: f(x)= 42.2046
# differential_evolution step 17: f(x)= 42.2046
# differential_evolution step 18: f(x)= 42.1997
# differential_evolution step 19: f(x)= 42.1997
# differential_evolution step 20: f(x)= 42.1997
# differential_evolution step 21: f(x)= 42.1465
# differential_evolution step 22: f(x)= 42.1465
# differential_evolution step 23: f(x)= 42.1321
# differential_evolution step 24: f(x)= 42.1123
# differential_evolution step 25: f(x)= 42.1123
# differential_evolution step 26: f(x)= 42.1101
# differential_evolution step 27: f(x)= 42.1101
# Params [-4.83341345  3.13337356  4.49917095  0.46640835] gave 42.1060659742607
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 20.3725
# differential_evolution step 2: f(x)= 14.8336
# differential_evolution step 3: f(x)= 14.8336
# differential_evolution step 4: f(x)= 14.4505
# differential_evolution step 5: f(x)= 14.4505
# differential_evolution step 6: f(x)= 14.4505
# differential_evolution step 7: f(x)= 14.4505
# differential_evolution step 8: f(x)= 14.4505
# differential_evolution step 9: f(x)= 12.9488
# differential_evolution step 10: f(x)= 12.9488
# differential_evolution step 11: f(x)= 12.9488
# differential_evolution step 12: f(x)= 12.9488
# differential_evolution step 13: f(x)= 12.5523
# differential_evolution step 14: f(x)= 12.5523
# differential_evolution step 15: f(x)= 12.5523
# differential_evolution step 16: f(x)= 12.5227
# differential_evolution step 17: f(x)= 12.5146
# differential_evolution step 18: f(x)= 12.5146
# differential_evolution step 19: f(x)= 12.5146
# differential_evolution step 20: f(x)= 12.4766
# differential_evolution step 21: f(x)= 12.4766
# differential_evolution step 22: f(x)= 12.4428
# differential_evolution step 23: f(x)= 12.4428
# differential_evolution step 24: f(x)= 12.4428
# differential_evolution step 25: f(x)= 12.4376
# differential_evolution step 26: f(x)= 12.4376
# differential_evolution step 27: f(x)= 12.4267
# differential_evolution step 28: f(x)= 12.4267
# differential_evolution step 29: f(x)= 12.4267
# differential_evolution step 30: f(x)= 12.4267
# differential_evolution step 31: f(x)= 12.4267
# differential_evolution step 32: f(x)= 12.4267
# Params [-13.06053684   4.90716803  10.34231292   0.49891194] gave 12.420931232330334
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 23.9887
# differential_evolution step 2: f(x)= 23.9887
# differential_evolution step 3: f(x)= 23.9887
# differential_evolution step 4: f(x)= 23.9887
# differential_evolution step 5: f(x)= 23.9887
# differential_evolution step 6: f(x)= 23.9887
# differential_evolution step 7: f(x)= 23.1178
# differential_evolution step 8: f(x)= 23.1178
# differential_evolution step 9: f(x)= 23.1178
# differential_evolution step 10: f(x)= 23.038
# differential_evolution step 11: f(x)= 23.038
# differential_evolution step 12: f(x)= 23.038
# differential_evolution step 13: f(x)= 23.038
# differential_evolution step 14: f(x)= 23.0353
# differential_evolution step 15: f(x)= 23.0353
# differential_evolution step 16: f(x)= 23.0353
# differential_evolution step 17: f(x)= 23.0353
# ...
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 131.151
# differential_evolution step 2: f(x)= 104.229
# differential_evolution step 3: f(x)= 104.229
# differential_evolution step 4: f(x)= 104.229
# differential_evolution step 5: f(x)= 102.233
# differential_evolution step 6: f(x)= 99.4368
# differential_evolution step 7: f(x)= 99.4368
# differential_evolution step 8: f(x)= 99.4368
# differential_evolution step 9: f(x)= 99.0563
# differential_evolution step 10: f(x)= 98.9285
# differential_evolution step 11: f(x)= 98.9285
# differential_evolution step 12: f(x)= 98.9285
# differential_evolution step 13: f(x)= 98.9285
# differential_evolution step 14: f(x)= 98.9285
# differential_evolution step 15: f(x)= 98.9285
# differential_evolution step 16: f(x)= 98.92
# differential_evolution step 17: f(x)= 98.8944
# Params [1.32715747 3.76900026 4.28189027 0.29040759] gave 98.88663561164608
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 124.391
# differential_evolution step 2: f(x)= 95.3999
# differential_evolution step 3: f(x)= 90.4691
# differential_evolution step 4: f(x)= 90.4691
# differential_evolution step 5: f(x)= 90.4691
# differential_evolution step 6: f(x)= 89.7871
# differential_evolution step 7: f(x)= 88.7492
# differential_evolution step 8: f(x)= 88.7492
# differential_evolution step 9: f(x)= 87.3731
# differential_evolution step 10: f(x)= 87.3731
# differential_evolution step 11: f(x)= 87.3731
# differential_evolution step 12: f(x)= 87.3731
# differential_evolution step 13: f(x)= 87.2248
# differential_evolution step 14: f(x)= 87.2248
# differential_evolution step 15: f(x)= 87.2248
# differential_evolution step 16: f(x)= 87.2248
# differential_evolution step 17: f(x)= 87.1821
# differential_evolution step 18: f(x)= 87.1821
# differential_evolution step 19: f(x)= 87.1821
# Params [3.03807322 4.78206164 5.54735736 0.50304497] gave 87.15949059946684
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 160.667
# differential_evolution step 2: f(x)= 159.606
# differential_evolution step 3: f(x)= 151.951
# differential_evolution step 4: f(x)= 140.562
# differential_evolution step 5: f(x)= 110.403
# differential_evolution step 6: f(x)= 110.403
# differential_evolution step 7: f(x)= 110.403
# differential_evolution step 8: f(x)= 110.163
# differential_evolution step 9: f(x)= 110.163
# differential_evolution step 10: f(x)= 108.654
# differential_evolution step 11: f(x)= 108.654
# differential_evolution step 12: f(x)= 108.654
# differential_evolution step 13: f(x)= 108.654
# differential_evolution step 14: f(x)= 108.654
# differential_evolution step 15: f(x)= 108.654
# differential_evolution step 16: f(x)= 108.654
# differential_evolution step 17: f(x)= 108.654
# differential_evolution step 18: f(x)= 108.616
# differential_evolution step 19: f(x)= 108.616
# differential_evolution step 20: f(x)= 108.612
# differential_evolution step 21: f(x)= 108.612
# differential_evolution step 22: f(x)= 108.603
# Params [2.16568156 4.6325919  5.04254554 0.00626493] gave 108.60104863690842
# <ipython-input-109-07b879591143>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
# <ipython-input-109-07b879591143>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0
# differential_evolution step 1: f(x)= 118.859
# differential_evolution step 2: f(x)= 118.859
# differential_evolution step 3: f(x)= 110.759
# differential_evolution step 4: f(x)= 110.759
# differential_evolution step 5: f(x)= 110.759
# differential_evolution step 6: f(x)= 110.759
# differential_evolution step 7: f(x)= 110.436
# differential_evolution step 8: f(x)= 110.436
# differential_evolution step 9: f(x)= 109.697
# differential_evolution step 10: f(x)= 109.697
# differential_evolution step 11: f(x)= 109.697
# differential_evolution step 12: f(x)= 109.697
# differential_evolution step 13: f(x)= 109.655
# differential_evolution step 14: f(x)= 109.655
# differential_evolution step 15: f(x)= 109.655
# differential_evolution step 16: f(x)= 109.655
# differential_evolution step 17: f(x)= 109.655
# differential_evolution step 18: f(x)= 109.395
# differential_evolution step 19: f(x)= 109.395
# differential_evolution step 20: f(x)= 109.395
# differential_evolution step 21: f(x)= 109.395
# differential_evolution step 22: f(x)= 109.395
# differential_evolution step 23: f(x)= 109.395
# differential_evolution step 24: f(x)= 109.395
# differential_evolution step 25: f(x)= 109.395
# differential_evolution step 26: f(x)= 109.395
# differential_evolution step 27: f(x)= 109.395
# differential_evolution step 28: f(x)= 109.395
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-07b879591143> in <module>
#      29
#      30             #try:
# ---> 31             fit_adjust_model(samp, model_fit,
#      32                              fitting_method="differential_evolution",
#      33                              lossfunction=LossRobustLikelihood, verbose=False)
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in fit_adjust_model(sample, model, fitparams, fitting_method, lossfunction, verify, method, verbose)
#     343         x_fit = basinhopping(_fit_model, x_0, minimizer_kwargs={"bounds" : constraints, "method" : "TNC"}, disp=True, **fitparams)
#     344     elif fitting_method == "differential_evolution":
# --> 345         x_fit = differential_evolution(_fit_model, constraints, disp=True, **fitparams)
#     346     elif fitting_method == "hillclimb":
#     347         x_fit = evolution_strategy(_fit_model, x_0, **fitparams)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     306                                      workers=workers,
#     307                                      constraints=constraints) as solver:
# --> 308         ret = solver.solve()
#     309
#     310     return ret
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     808                                   " infeasible solution", UserWarning)
#     809
# --> 810             result = minimize(self.func,
#     811                               np.copy(DE_result.x),
#     812                               method=polish_method,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in __call__(self, x)
#    1259
#    1260     def __call__(self, x):
# -> 1261         return self.f(x, *self.args)
#    1262
#    1263
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in _fit_model(xs)
#     327                 x = p.minval
#     328             s(m, x)
# --> 329         lossf = lf.loss(m)
#     330         if verbose:
#     331             print(repr(m), "loss="+ str(lossf))
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\models\loss.py in loss(self, model)
#     168     def loss(self, model):
#     169         assert model.dt == self.dt and model.T_dur == self.T_dur
# --> 170         sols = self.cache_by_conditions(model)
#     171         loglikelihood = 0
#     172         for k in sols.keys():
#
# ~\anaconda3\lib\site-packages\ddm\models\loss.py in cache_by_conditions(self, model)
#      94         """
#      95         from ..functions import solve_all_conditions
# ---> 96         return solve_all_conditions(model, self.sample, conditions=self.required_conditions, method=self.method)
#      97
#      98 @paranoidclass
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in solve_all_conditions(model, sample, conditions, method)
#     473     if _parallel_pool is None: # No parallelization
#     474         for c in conds:
# --> 475             cache[frozenset(c.items())] = meth(conditions=c)
#     476         return cache
#     477     else: # Parallelize across pool
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\model.py in solve(self, conditions, return_evolution)
#     479         self.check_conditions_satisfied(conditions)
#     480         if self.has_analytical_solution() and return_evolution is False:
# --> 481             return self.solve_analytical(conditions=conditions)
#     482         elif isinstance(self.get_dependence("bound"), BoundConstant) and return_evolution is False:
#     483             return self.solve_numerical_cn(conditions=conditions)
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\model.py in solve_analytical(self, conditions)
#     518                                                        self.t_domain(), shift, -self.get_dependence("bound").t) # TODO why must this be negative? -MS
#     519         else: # Constant bound DDM
# --> 520             anal_pdf_corr, anal_pdf_err = analytic_ddm(self.get_dependence("drift").get_drift(t=0, conditions=conditions),
#     521                                                        self.get_dependence("noise").get_noise(t=0, conditions=conditions),
#     522                                                        self.get_dependence("bound").get_bound(t=0, conditions=conditions),
#
# ~\anaconda3\lib\site-packages\ddm\analytic.py in analytic_ddm(drift, noise, b, teval, shift, b_slope)
#      91     teval_valid = teval[b+b_slope*teval>0]
#      92
# ---> 93     dist_cor = analytic_ddm_linbound(b_upper, -drift+b_slope, -b_lower, -drift-b_slope, teval_valid)
#      94     dist_err = analytic_ddm_linbound(b_lower,  drift+b_slope, -b_upper,  drift-b_slope, teval_valid)
#      95
#
# ~\anaconda3\lib\site-packages\ddm\analytic.py in analytic_ddm_linbound(a1, b1, a2, b2, teval)
#      43         # Break when the relative increment is low for three consecutive updates
#      44         # np.where statement avoids dividing by 0
# ---> 45         if np.max(np.abs(inc/np.where(suminc==0,1e-30,suminc))) < errbnd:
#      46             checkerr += 1
#      47             if checkerr == 3:
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
model_fits[participant][block][0]

# %%
drift_rates = np.zeros((14, 12, len(incorrect_thresold)))
drift_noise = np.zeros((14, 12, len(incorrect_thresold)))
bounds = np.zeros((14, 12, len(incorrect_thresold)))
Ter = np.zeros((14, 12, len(incorrect_thresold)))
for participant in range(14):
    for block in range(12):
        for ic in range(len(incorrect_thresold)):
            if block > 1:
                drift_rates[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[0].real
                #drift_noise[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real
                drift_noise[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[1].real

                bounds[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real 
                #Ter[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[3].real
                Ter[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[3].real
            else:
                drift_rates[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[0].real
                drift_noise[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real
                #drift_noise[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[1].real

                bounds[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[2].real 
                Ter[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[3].real
                #Ter[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[3].real

# %%
df_ddm = pd.DataFrame({'Condition': np.tile(np.ravel(np.array([np.repeat(['Sudden'], 12*len(incorrect_thresold)), np.repeat(['Gradual'], 12*len(incorrect_thresold))])), 7),
                       'Block': np.tile(np.repeat(np.arange(12), len(incorrect_thresold)), 14),
                      'Drift_Rates': np.ravel(drift_rates),
                       'Drift_Noise': np.ravel(drift_noise),
                       'Incorrect_Criterian':np.tile(np.array([20]), 12*14),
                      'Bounds': np.ravel(bounds),
                      'Ter': np.ravel(Ter)})

# %%
df_ddm

# %%
sns.catplot(x = 'Block', y = 'Bounds', data = df_ddm, kind='point', hue = 'Condition', ci = 95, col = 'Incorrect_Criterian', capsize = 0.2)

# %%
from ddm import Bound
class BoundBlocks(Bound):
    name = "constant"
    required_parameters = ["BBlock0", "BBlock1", "BBlock2", "BBlock3", "BBlock4", "BBlock5",
                          "BBlock6", "BBlock7", "BBlock8", "BBlock9", "BBlock10", "BBlock11"]
    required_conditions = ['block']
    def get_bound(self, conditions, *args, **kwargs):
        if conditions['block'] == 0:
            return self.BBlock0
        if conditions['block'] == 1:
            return self.BBlock1
        if conditions['block'] == 2:
            return self.BBlock2
        if conditions['block'] == 3:
            return self.BBlock3
        if conditions['block'] == 4:
            return self.BBlock4
        if conditions['block'] == 5:
            return self.BBlock5
        if conditions['block'] == 6:
            return self.BBlock6
        if conditions['block'] == 7:
            return self.BBlock7
        if conditions['block'] == 8:
            return self.BBlock8
        if conditions['block'] == 9:
            return self.BBlock9
        if conditions['block'] == 10:
            return self.BBlock10
        if conditions['block'] == 11:
            return self.BBlock11

# %%
from ddm import Drift
class DriftBlocks(Drift):
    name = "constant"
    required_parameters = ["VBlock0", "VBlock1", "VBlock2", "VBlock3", "VBlock4", "VBlock5",
                          "VBlock6", "VBlock7", "VBlock8", "VBlock9", "VBlock10", "VBlock11"]
    required_conditions = ['block']
    def get_drift(self, conditions, *args, **kwargs):
        if conditions['block'] == 0:
            return self.VBlock0
        if conditions['block'] == 1:
            return self.VBlock1
        if conditions['block'] == 2:
            return self.VBlock2
        if conditions['block'] == 3:
            return self.VBlock3
        if conditions['block'] == 4:
            return self.VBlock4
        if conditions['block'] == 5:
            return self.VBlock5
        if conditions['block'] == 6:
            return self.VBlock6
        if conditions['block'] == 7:
            return self.VBlock7
        if conditions['block'] == 8:
            return self.VBlock8
        if conditions['block'] == 9:
            return self.VBlock9
        if conditions['block'] == 10:
            return self.VBlock10
        if conditions['block'] == 11:
            return self.VBlock11

# %%
model_fits = np.zeros(14, dtype = object)
for participant in [5, 6, 7, 9, 12]:
    print(participant)
    df_rt = pd.read_csv(open('RTs.csv'))
    df_error = pd.read_csv(open('Angular_errors.csv'))

    df_rt['Correct'] = 0
    df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
    df_rt['Correct'][df_error['Error'] > np.pi/9] = 0

    df_rt = df_rt[df_rt['participant_id'] == participant]

    df_rt = df_rt[df_rt["ITs"] > .001]
    df_rt = df_rt[df_rt["ITs"] < 5]
    df_rt = df_rt.drop(['Trial', 'Unnamed: 0', 'participant_id', 'condition', 'MTs'], axis = 1)

    samp = Sample.from_pandas_dataframe(df_rt, rt_column_name="ITs", correct_column_name="Correct")
    
    
    model = Model(bound=BoundBlocks(BBlock0 = Fittable(minval = 0, maxval = 20),
                               BBlock1 = Fittable(minval = 0, maxval = 20),
                               BBlock2 = Fittable(minval = 0, maxval = 20),
                               BBlock3 = Fittable(minval = 0, maxval = 20),
                               BBlock4 = Fittable(minval = 0, maxval = 20),
                               BBlock5 = Fittable(minval = 0, maxval = 20),
                               BBlock6 = Fittable(minval = 0, maxval = 20),
                               BBlock7 = Fittable(minval = 0, maxval = 20),
                               BBlock8 = Fittable(minval = 0, maxval = 20),
                               BBlock9 = Fittable(minval = 0, maxval = 20),
                               BBlock10 = Fittable(minval = 0, maxval = 20),
                               BBlock11 = Fittable(minval = 0, maxval = 20)),
              
              drift=DriftBlocks(VBlock0 = Fittable(minval = -20, maxval = 20),
                               VBlock1 = Fittable(minval = -20, maxval = 20),
                               VBlock2 = Fittable(minval = -20, maxval = 20),
                               VBlock3 = Fittable(minval = -20, maxval = 20),
                               VBlock4 = Fittable(minval = -20, maxval = 20),
                               VBlock5 = Fittable(minval = -20, maxval = 20),
                               VBlock6 = Fittable(minval = -20, maxval = 20),
                               VBlock7 = Fittable(minval = -20, maxval = 20),
                               VBlock8 = Fittable(minval = -20, maxval = 20),
                               VBlock9 = Fittable(minval = -20, maxval = 20),
                               VBlock10 = Fittable(minval = -20, maxval = 20),
                               VBlock11 = Fittable(minval = -20, maxval = 20)),
              
              overlay=OverlayNonDecision(nondectime=Fittable(minval=0, maxval=0.5)),
              
              noise=NoiseConstant(noise=Fittable(minval=0.01, maxval=5)), 
                               dt=0.01, dx = 0.01, T_dur = 5
             )
    model_fits[participant] = fit_adjust_model(samp, model, verbose = False, lossfunction=LossSquaredError)
# Out:
# 5
# <ipython-input-22-35855da91661>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-22-35855da91661>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 0.27975
# differential_evolution step 2: f(x)= 0.27975
# differential_evolution step 3: f(x)= 0.27975
# differential_evolution step 4: f(x)= 0.27975
# differential_evolution step 5: f(x)= 0.276606
# differential_evolution step 6: f(x)= 0.263774
# differential_evolution step 7: f(x)= 0.263774
# differential_evolution step 8: f(x)= 0.263774
# differential_evolution step 9: f(x)= 0.263774
# differential_evolution step 10: f(x)= 0.263774
# differential_evolution step 11: f(x)= 0.253113
# differential_evolution step 12: f(x)= 0.253113
# differential_evolution step 13: f(x)= 0.253113
# differential_evolution step 14: f(x)= 0.253113
# differential_evolution step 15: f(x)= 0.253113
# differential_evolution step 16: f(x)= 0.253113
# differential_evolution step 17: f(x)= 0.253113
# differential_evolution step 18: f(x)= 0.253113
# differential_evolution step 19: f(x)= 0.253113
# differential_evolution step 20: f(x)= 0.252568
# differential_evolution step 21: f(x)= 0.247018
# differential_evolution step 22: f(x)= 0.247018
# differential_evolution step 23: f(x)= 0.247018
# differential_evolution step 24: f(x)= 0.247018
# differential_evolution step 25: f(x)= 0.235931
# differential_evolution step 26: f(x)= 0.235931
# differential_evolution step 27: f(x)= 0.235931
# differential_evolution step 28: f(x)= 0.235931
# differential_evolution step 29: f(x)= 0.235931
# differential_evolution step 30: f(x)= 0.235931
# differential_evolution step 31: f(x)= 0.235931
# differential_evolution step 32: f(x)= 0.235931
# differential_evolution step 33: f(x)= 0.235931
# differential_evolution step 34: f(x)= 0.235931
# differential_evolution step 35: f(x)= 0.235931
# differential_evolution step 36: f(x)= 0.235931
# differential_evolution step 37: f(x)= 0.23004
# differential_evolution step 38: f(x)= 0.23004
# differential_evolution step 39: f(x)= 0.23004
# differential_evolution step 40: f(x)= 0.23004
# differential_evolution step 41: f(x)= 0.228399
# differential_evolution step 42: f(x)= 0.228399
# differential_evolution step 43: f(x)= 0.228399
# differential_evolution step 44: f(x)= 0.228399
# differential_evolution step 45: f(x)= 0.228399
# differential_evolution step 46: f(x)= 0.228399
# differential_evolution step 47: f(x)= 0.228399
# differential_evolution step 48: f(x)= 0.227226
# differential_evolution step 49: f(x)= 0.225937
# differential_evolution step 50: f(x)= 0.225937
# differential_evolution step 51: f(x)= 0.225937
# differential_evolution step 52: f(x)= 0.225937
# differential_evolution step 53: f(x)= 0.225937
# differential_evolution step 54: f(x)= 0.225937
# differential_evolution step 55: f(x)= 0.225937
# differential_evolution step 56: f(x)= 0.225937
# differential_evolution step 57: f(x)= 0.225937
# differential_evolution step 58: f(x)= 0.225937
# differential_evolution step 59: f(x)= 0.225937
# differential_evolution step 60: f(x)= 0.225937
# differential_evolution step 61: f(x)= 0.225937
# differential_evolution step 62: f(x)= 0.225937
# differential_evolution step 63: f(x)= 0.225937
# differential_evolution step 64: f(x)= 0.225937
# differential_evolution step 65: f(x)= 0.225937
# differential_evolution step 66: f(x)= 0.225937
# differential_evolution step 67: f(x)= 0.225937
# differential_evolution step 68: f(x)= 0.22408
# differential_evolution step 69: f(x)= 0.22408
# differential_evolution step 70: f(x)= 0.22408
# differential_evolution step 71: f(x)= 0.220885
# differential_evolution step 72: f(x)= 0.219741
# differential_evolution step 73: f(x)= 0.219741
# differential_evolution step 74: f(x)= 0.219741
# differential_evolution step 75: f(x)= 0.219741
# differential_evolution step 76: f(x)= 0.219198
# differential_evolution step 77: f(x)= 0.219198
# differential_evolution step 78: f(x)= 0.219198
# differential_evolution step 79: f(x)= 0.219198
# differential_evolution step 80: f(x)= 0.219198
# differential_evolution step 81: f(x)= 0.219198
# differential_evolution step 82: f(x)= 0.215009
# differential_evolution step 83: f(x)= 0.215009
# differential_evolution step 84: f(x)= 0.215009
# differential_evolution step 85: f(x)= 0.215009
# differential_evolution step 86: f(x)= 0.215009
# differential_evolution step 87: f(x)= 0.215009
# differential_evolution step 88: f(x)= 0.215009
# differential_evolution step 89: f(x)= 0.215009
# differential_evolution step 90: f(x)= 0.215009
# differential_evolution step 91: f(x)= 0.215009
# differential_evolution step 92: f(x)= 0.215009
# differential_evolution step 93: f(x)= 0.215009
# differential_evolution step 94: f(x)= 0.215009
# differential_evolution step 95: f(x)= 0.215009
# differential_evolution step 96: f(x)= 0.215009
# differential_evolution step 97: f(x)= 0.215009
# differential_evolution step 98: f(x)= 0.213846
# differential_evolution step 99: f(x)= 0.213846
# differential_evolution step 100: f(x)= 0.213846
# differential_evolution step 101: f(x)= 0.213846
# differential_evolution step 102: f(x)= 0.213846
# differential_evolution step 103: f(x)= 0.213846
# differential_evolution step 104: f(x)= 0.213846
# differential_evolution step 105: f(x)= 0.213846
# differential_evolution step 106: f(x)= 0.213846
# differential_evolution step 107: f(x)= 0.211744
# differential_evolution step 108: f(x)= 0.211365
# differential_evolution step 109: f(x)= 0.211365
# differential_evolution step 110: f(x)= 0.211365
# differential_evolution step 111: f(x)= 0.211365
# differential_evolution step 112: f(x)= 0.211365
# differential_evolution step 113: f(x)= 0.211241
# differential_evolution step 114: f(x)= 0.211241
# differential_evolution step 115: f(x)= 0.211241
# differential_evolution step 116: f(x)= 0.211241
# differential_evolution step 117: f(x)= 0.211241
# differential_evolution step 118: f(x)= 0.211241
# differential_evolution step 119: f(x)= 0.211241
# differential_evolution step 120: f(x)= 0.211241
# differential_evolution step 121: f(x)= 0.211241
# differential_evolution step 122: f(x)= 0.211241
# differential_evolution step 123: f(x)= 0.210991
# differential_evolution step 124: f(x)= 0.210991
# differential_evolution step 125: f(x)= 0.210991
# differential_evolution step 126: f(x)= 0.210991
# differential_evolution step 127: f(x)= 0.210991
# differential_evolution step 128: f(x)= 0.210991
# differential_evolution step 129: f(x)= 0.210991
# differential_evolution step 130: f(x)= 0.210991
# differential_evolution step 131: f(x)= 0.210991
# differential_evolution step 132: f(x)= 0.210991
# differential_evolution step 133: f(x)= 0.210991
# differential_evolution step 134: f(x)= 0.210991
# differential_evolution step 135: f(x)= 0.210179
# differential_evolution step 136: f(x)= 0.210179
# differential_evolution step 137: f(x)= 0.210179
# differential_evolution step 138: f(x)= 0.210002
# differential_evolution step 139: f(x)= 0.210002
# differential_evolution step 140: f(x)= 0.210002
# differential_evolution step 141: f(x)= 0.210002
# differential_evolution step 142: f(x)= 0.210002
# differential_evolution step 143: f(x)= 0.210002
# differential_evolution step 144: f(x)= 0.210002
# differential_evolution step 145: f(x)= 0.210002
# differential_evolution step 146: f(x)= 0.210002
# differential_evolution step 147: f(x)= 0.209822
# differential_evolution step 148: f(x)= 0.209822
# differential_evolution step 149: f(x)= 0.209822
# differential_evolution step 150: f(x)= 0.20863
# differential_evolution step 151: f(x)= 0.20863
# differential_evolution step 152: f(x)= 0.20863
# differential_evolution step 153: f(x)= 0.207778
# differential_evolution step 154: f(x)= 0.207778
# differential_evolution step 155: f(x)= 0.207778
# differential_evolution step 156: f(x)= 0.207778
# differential_evolution step 157: f(x)= 0.207778
# differential_evolution step 158: f(x)= 0.207778
# differential_evolution step 159: f(x)= 0.207778
# differential_evolution step 160: f(x)= 0.207538
# differential_evolution step 161: f(x)= 0.207538
# differential_evolution step 162: f(x)= 0.207538
# differential_evolution step 163: f(x)= 0.20621
# differential_evolution step 164: f(x)= 0.20621
# differential_evolution step 165: f(x)= 0.20621
# differential_evolution step 166: f(x)= 0.20621
# differential_evolution step 167: f(x)= 0.20621
# differential_evolution step 168: f(x)= 0.20621
# differential_evolution step 169: f(x)= 0.205975
# differential_evolution step 170: f(x)= 0.205184
# differential_evolution step 171: f(x)= 0.205136
# differential_evolution step 172: f(x)= 0.205136
# differential_evolution step 173: f(x)= 0.205136
# differential_evolution step 174: f(x)= 0.205136
# Params [ 20.          19.37239586  -0.07399437 -12.1747762  -12.88588693
#   -8.3251831  -11.08655875 -12.90451753   0.27175182   4.83489934
#    4.74370898   2.61792756   4.0386715   17.78144693  15.14170905
#    4.47365183   9.9592453   14.58481927   8.50931047  11.5504636
#    9.43612761   3.9149249    2.78717769   3.25536443   3.69380573
#    0.4747267 ] gave 0.2005204998625098
# 6
# <ipython-input-22-35855da91661>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-22-35855da91661>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 0.378351
# differential_evolution step 2: f(x)= 0.378351
# differential_evolution step 3: f(x)= 0.378351
# differential_evolution step 4: f(x)= 0.378351
# differential_evolution step 5: f(x)= 0.37642
# differential_evolution step 6: f(x)= 0.369549
# differential_evolution step 7: f(x)= 0.369549
# differential_evolution step 8: f(x)= 0.369549
# differential_evolution step 9: f(x)= 0.361135
# differential_evolution step 10: f(x)= 0.358375
# differential_evolution step 11: f(x)= 0.354134
# differential_evolution step 12: f(x)= 0.354134
# differential_evolution step 13: f(x)= 0.354134
# differential_evolution step 14: f(x)= 0.354134
# differential_evolution step 15: f(x)= 0.354134
# differential_evolution step 16: f(x)= 0.354134
# differential_evolution step 17: f(x)= 0.354134
# differential_evolution step 18: f(x)= 0.354134
# differential_evolution step 19: f(x)= 0.354134
# differential_evolution step 20: f(x)= 0.34974
# differential_evolution step 21: f(x)= 0.34974
# differential_evolution step 22: f(x)= 0.34974
# differential_evolution step 23: f(x)= 0.341198
# differential_evolution step 24: f(x)= 0.336546
# differential_evolution step 25: f(x)= 0.335174
# differential_evolution step 26: f(x)= 0.335174
# differential_evolution step 27: f(x)= 0.335174
# differential_evolution step 28: f(x)= 0.335174
# differential_evolution step 29: f(x)= 0.334513
# differential_evolution step 30: f(x)= 0.334513
# differential_evolution step 31: f(x)= 0.329462
# differential_evolution step 32: f(x)= 0.329462
# differential_evolution step 33: f(x)= 0.329462
# differential_evolution step 34: f(x)= 0.329462
# differential_evolution step 35: f(x)= 0.329462
# differential_evolution step 36: f(x)= 0.32441
# differential_evolution step 37: f(x)= 0.32441
# differential_evolution step 38: f(x)= 0.32441
# differential_evolution step 39: f(x)= 0.32441
# differential_evolution step 40: f(x)= 0.32441
# differential_evolution step 41: f(x)= 0.32441
# differential_evolution step 42: f(x)= 0.32441
# differential_evolution step 43: f(x)= 0.32441
# differential_evolution step 44: f(x)= 0.32441
# differential_evolution step 45: f(x)= 0.32441
# differential_evolution step 46: f(x)= 0.32441
# differential_evolution step 47: f(x)= 0.32441
# differential_evolution step 48: f(x)= 0.32441
# differential_evolution step 49: f(x)= 0.31926
# differential_evolution step 50: f(x)= 0.31926
# differential_evolution step 51: f(x)= 0.31926
# differential_evolution step 52: f(x)= 0.31926
# differential_evolution step 53: f(x)= 0.31926
# differential_evolution step 54: f(x)= 0.317258
# differential_evolution step 55: f(x)= 0.317258
# differential_evolution step 56: f(x)= 0.317258
# differential_evolution step 57: f(x)= 0.317258
# differential_evolution step 58: f(x)= 0.317258
# differential_evolution step 59: f(x)= 0.316113
# differential_evolution step 60: f(x)= 0.313917
# differential_evolution step 61: f(x)= 0.313917
# differential_evolution step 62: f(x)= 0.313917
# differential_evolution step 63: f(x)= 0.313917
# differential_evolution step 64: f(x)= 0.313917
# differential_evolution step 65: f(x)= 0.313917
# differential_evolution step 66: f(x)= 0.313917
# differential_evolution step 67: f(x)= 0.313917
# differential_evolution step 68: f(x)= 0.313917
# differential_evolution step 69: f(x)= 0.313917
# differential_evolution step 70: f(x)= 0.313077
# differential_evolution step 71: f(x)= 0.311606
# differential_evolution step 72: f(x)= 0.311606
# differential_evolution step 73: f(x)= 0.311606
# differential_evolution step 74: f(x)= 0.311606
# differential_evolution step 75: f(x)= 0.311606
# differential_evolution step 76: f(x)= 0.3114
# differential_evolution step 77: f(x)= 0.3114
# differential_evolution step 78: f(x)= 0.3114
# differential_evolution step 79: f(x)= 0.3114
# differential_evolution step 80: f(x)= 0.3114
# differential_evolution step 81: f(x)= 0.31117
# differential_evolution step 82: f(x)= 0.306648
# differential_evolution step 83: f(x)= 0.306648
# differential_evolution step 84: f(x)= 0.306648
# differential_evolution step 85: f(x)= 0.306648
# differential_evolution step 86: f(x)= 0.306648
# differential_evolution step 87: f(x)= 0.306648
# differential_evolution step 88: f(x)= 0.306648
# differential_evolution step 89: f(x)= 0.306648
# differential_evolution step 90: f(x)= 0.306648
# differential_evolution step 91: f(x)= 0.306648
# differential_evolution step 92: f(x)= 0.306648
# differential_evolution step 93: f(x)= 0.306648
# differential_evolution step 94: f(x)= 0.306648
# differential_evolution step 95: f(x)= 0.305161
# differential_evolution step 96: f(x)= 0.305161
# differential_evolution step 97: f(x)= 0.30155
# differential_evolution step 98: f(x)= 0.30155
# differential_evolution step 99: f(x)= 0.30155
# differential_evolution step 100: f(x)= 0.30155
# differential_evolution step 101: f(x)= 0.30155
# differential_evolution step 102: f(x)= 0.30155
# differential_evolution step 103: f(x)= 0.30155
# differential_evolution step 104: f(x)= 0.30155
# differential_evolution step 105: f(x)= 0.30155
# differential_evolution step 106: f(x)= 0.30155
# differential_evolution step 107: f(x)= 0.30155
# differential_evolution step 108: f(x)= 0.30155
# differential_evolution step 109: f(x)= 0.30155
# differential_evolution step 110: f(x)= 0.30155
# differential_evolution step 111: f(x)= 0.30155
# differential_evolution step 112: f(x)= 0.30155
# differential_evolution step 113: f(x)= 0.30155
# differential_evolution step 114: f(x)= 0.30155
# differential_evolution step 115: f(x)= 0.30155
# differential_evolution step 116: f(x)= 0.30155
# differential_evolution step 117: f(x)= 0.30155
# differential_evolution step 118: f(x)= 0.30155
# differential_evolution step 119: f(x)= 0.30155
# differential_evolution step 120: f(x)= 0.30155
# differential_evolution step 121: f(x)= 0.30155
# differential_evolution step 122: f(x)= 0.30155
# differential_evolution step 123: f(x)= 0.30155
# differential_evolution step 124: f(x)= 0.30155
# differential_evolution step 125: f(x)= 0.30155
# differential_evolution step 126: f(x)= 0.30155
# differential_evolution step 127: f(x)= 0.300999
# differential_evolution step 128: f(x)= 0.300999
# differential_evolution step 129: f(x)= 0.300999
# differential_evolution step 130: f(x)= 0.300999
# differential_evolution step 131: f(x)= 0.300999
# differential_evolution step 132: f(x)= 0.300999
# differential_evolution step 133: f(x)= 0.300999
# differential_evolution step 134: f(x)= 0.299525
# differential_evolution step 135: f(x)= 0.299525
# differential_evolution step 136: f(x)= 0.299525
# Params [ 5.22139134 -6.26552662 -0.5662328  -3.85014528  9.26141238  9.25642151
#  13.13036591  7.88474514 16.18319952 11.75950084 19.99815286 16.50813155
#   2.39607437  2.98456176  7.97194664  3.57491046  6.27113306 11.4727854
#   9.34656313 11.94839236  8.19362721 14.34647988 10.80925774 16.81337188
#  12.1661539   0.26146539] gave 0.29299691108834597
# 7
# <ipython-input-22-35855da91661>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-22-35855da91661>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 0.385961
# differential_evolution step 2: f(x)= 0.379034
# differential_evolution step 3: f(x)= 0.379034
# differential_evolution step 4: f(x)= 0.379034
# differential_evolution step 5: f(x)= 0.379034
# differential_evolution step 6: f(x)= 0.377306
# differential_evolution step 7: f(x)= 0.373868
# differential_evolution step 8: f(x)= 0.373868
# differential_evolution step 9: f(x)= 0.373868
# differential_evolution step 10: f(x)= 0.372969
# differential_evolution step 11: f(x)= 0.36968
# differential_evolution step 12: f(x)= 0.36968
# differential_evolution step 13: f(x)= 0.36968
# differential_evolution step 14: f(x)= 0.36968
# differential_evolution step 15: f(x)= 0.36968
# differential_evolution step 16: f(x)= 0.359539
# differential_evolution step 17: f(x)= 0.359539
# differential_evolution step 18: f(x)= 0.359539
# differential_evolution step 19: f(x)= 0.359539
# differential_evolution step 20: f(x)= 0.359539
# differential_evolution step 21: f(x)= 0.359539
# differential_evolution step 22: f(x)= 0.359003
# differential_evolution step 23: f(x)= 0.359003
# differential_evolution step 24: f(x)= 0.359003
# differential_evolution step 25: f(x)= 0.359003
# differential_evolution step 26: f(x)= 0.359003
# differential_evolution step 27: f(x)= 0.359003
# differential_evolution step 28: f(x)= 0.349496
# differential_evolution step 29: f(x)= 0.349496
# differential_evolution step 30: f(x)= 0.349496
# differential_evolution step 31: f(x)= 0.349496
# differential_evolution step 32: f(x)= 0.349496
# differential_evolution step 33: f(x)= 0.349496
# differential_evolution step 34: f(x)= 0.349496
# differential_evolution step 35: f(x)= 0.349496
# differential_evolution step 36: f(x)= 0.349496
# differential_evolution step 37: f(x)= 0.349496
# differential_evolution step 38: f(x)= 0.349496
# differential_evolution step 39: f(x)= 0.349496
# differential_evolution step 40: f(x)= 0.349496
# differential_evolution step 41: f(x)= 0.349496
# differential_evolution step 42: f(x)= 0.345722
# differential_evolution step 43: f(x)= 0.345722
# differential_evolution step 44: f(x)= 0.345722
# differential_evolution step 45: f(x)= 0.339308
# differential_evolution step 46: f(x)= 0.339308
# differential_evolution step 47: f(x)= 0.339308
# differential_evolution step 48: f(x)= 0.339308
# differential_evolution step 49: f(x)= 0.339308
# differential_evolution step 50: f(x)= 0.339308
# differential_evolution step 51: f(x)= 0.339308
# differential_evolution step 52: f(x)= 0.339308
# differential_evolution step 53: f(x)= 0.339308
# differential_evolution step 54: f(x)= 0.339308
# differential_evolution step 55: f(x)= 0.339308
# differential_evolution step 56: f(x)= 0.337275
# differential_evolution step 57: f(x)= 0.337275
# differential_evolution step 58: f(x)= 0.337275
# differential_evolution step 59: f(x)= 0.337275
# differential_evolution step 60: f(x)= 0.337275
# differential_evolution step 61: f(x)= 0.336545
# differential_evolution step 62: f(x)= 0.336536
# differential_evolution step 63: f(x)= 0.336536
# differential_evolution step 64: f(x)= 0.336536
# differential_evolution step 65: f(x)= 0.336536
# differential_evolution step 66: f(x)= 0.336536
# differential_evolution step 67: f(x)= 0.336536
# differential_evolution step 68: f(x)= 0.336536
# differential_evolution step 69: f(x)= 0.336536
# differential_evolution step 70: f(x)= 0.336536
# differential_evolution step 71: f(x)= 0.336536
# differential_evolution step 72: f(x)= 0.336536
# differential_evolution step 73: f(x)= 0.332657
# differential_evolution step 74: f(x)= 0.332657
# differential_evolution step 75: f(x)= 0.332657
# differential_evolution step 76: f(x)= 0.332657
# differential_evolution step 77: f(x)= 0.332657
# differential_evolution step 78: f(x)= 0.332657
# differential_evolution step 79: f(x)= 0.332657
# differential_evolution step 80: f(x)= 0.332657
# differential_evolution step 81: f(x)= 0.332657
# differential_evolution step 82: f(x)= 0.332657
# differential_evolution step 83: f(x)= 0.332657
# differential_evolution step 84: f(x)= 0.332657
# differential_evolution step 85: f(x)= 0.332657
# differential_evolution step 86: f(x)= 0.332657
# differential_evolution step 87: f(x)= 0.329463
# differential_evolution step 88: f(x)= 0.329463
# differential_evolution step 89: f(x)= 0.329463
# differential_evolution step 90: f(x)= 0.329463
# differential_evolution step 91: f(x)= 0.329463
# differential_evolution step 92: f(x)= 0.329463
# differential_evolution step 93: f(x)= 0.329463
# differential_evolution step 94: f(x)= 0.329463
# differential_evolution step 95: f(x)= 0.329463
# differential_evolution step 96: f(x)= 0.329463
# differential_evolution step 97: f(x)= 0.329414
# differential_evolution step 98: f(x)= 0.329414
# differential_evolution step 99: f(x)= 0.329414
# differential_evolution step 100: f(x)= 0.329414
# differential_evolution step 101: f(x)= 0.329414
# differential_evolution step 102: f(x)= 0.329414
# differential_evolution step 103: f(x)= 0.329414
# differential_evolution step 104: f(x)= 0.329414
# differential_evolution step 105: f(x)= 0.329414
# differential_evolution step 106: f(x)= 0.329414
# differential_evolution step 107: f(x)= 0.329414
# differential_evolution step 108: f(x)= 0.329414
# differential_evolution step 109: f(x)= 0.326983
# differential_evolution step 110: f(x)= 0.326983
# differential_evolution step 111: f(x)= 0.326983
# differential_evolution step 112: f(x)= 0.326658
# differential_evolution step 113: f(x)= 0.326658
# differential_evolution step 114: f(x)= 0.326658
# differential_evolution step 115: f(x)= 0.326658
# differential_evolution step 116: f(x)= 0.326488
# differential_evolution step 117: f(x)= 0.326488
# differential_evolution step 118: f(x)= 0.326488
# differential_evolution step 119: f(x)= 0.326488
# differential_evolution step 120: f(x)= 0.326488
# differential_evolution step 121: f(x)= 0.326488
# differential_evolution step 122: f(x)= 0.326488
# differential_evolution step 123: f(x)= 0.326488
# differential_evolution step 124: f(x)= 0.324657
# differential_evolution step 125: f(x)= 0.324657
# differential_evolution step 126: f(x)= 0.324657
# differential_evolution step 127: f(x)= 0.324657
# differential_evolution step 128: f(x)= 0.324657
# differential_evolution step 129: f(x)= 0.324657
# differential_evolution step 130: f(x)= 0.324657
# differential_evolution step 131: f(x)= 0.324657
# differential_evolution step 132: f(x)= 0.324657
# differential_evolution step 133: f(x)= 0.324657
# differential_evolution step 134: f(x)= 0.324112
# differential_evolution step 135: f(x)= 0.324112
# differential_evolution step 136: f(x)= 0.322469
# differential_evolution step 137: f(x)= 0.322469
# differential_evolution step 138: f(x)= 0.322469
# differential_evolution step 139: f(x)= 0.322469
# differential_evolution step 140: f(x)= 0.322469
# differential_evolution step 141: f(x)= 0.322469
# differential_evolution step 142: f(x)= 0.322469
# differential_evolution step 143: f(x)= 0.322469
# differential_evolution step 144: f(x)= 0.322469
# differential_evolution step 145: f(x)= 0.322469
# differential_evolution step 146: f(x)= 0.322469
# differential_evolution step 147: f(x)= 0.322469
# differential_evolution step 148: f(x)= 0.322469
# differential_evolution step 149: f(x)= 0.322469
# differential_evolution step 150: f(x)= 0.322469
# differential_evolution step 151: f(x)= 0.322469
# differential_evolution step 152: f(x)= 0.322469
# differential_evolution step 153: f(x)= 0.322469
# differential_evolution step 154: f(x)= 0.322469
# differential_evolution step 155: f(x)= 0.322469
# differential_evolution step 156: f(x)= 0.322469
# differential_evolution step 157: f(x)= 0.322469
# differential_evolution step 158: f(x)= 0.322469
# differential_evolution step 159: f(x)= 0.322469
# differential_evolution step 160: f(x)= 0.322469
# differential_evolution step 161: f(x)= 0.320565
# differential_evolution step 162: f(x)= 0.320565
# differential_evolution step 163: f(x)= 0.320565
# differential_evolution step 164: f(x)= 0.320565
# differential_evolution step 165: f(x)= 0.320565
# differential_evolution step 166: f(x)= 0.320565
# differential_evolution step 167: f(x)= 0.320565
# differential_evolution step 168: f(x)= 0.320565
# differential_evolution step 169: f(x)= 0.320565
# differential_evolution step 170: f(x)= 0.320551
# differential_evolution step 171: f(x)= 0.320551
# differential_evolution step 172: f(x)= 0.320551
# differential_evolution step 173: f(x)= 0.320487
# differential_evolution step 174: f(x)= 0.320487
# differential_evolution step 175: f(x)= 0.320487
# differential_evolution step 176: f(x)= 0.320446
# differential_evolution step 177: f(x)= 0.319905
# differential_evolution step 178: f(x)= 0.319905
# differential_evolution step 179: f(x)= 0.319905
# differential_evolution step 180: f(x)= 0.319905
# differential_evolution step 181: f(x)= 0.319905
# differential_evolution step 182: f(x)= 0.319905
# differential_evolution step 183: f(x)= 0.319905
# differential_evolution step 184: f(x)= 0.319905
# Params [ 16.38674323  11.08158194  10.72827793  -1.14186518 -16.18781936
#   -8.76355514  -7.99164147  -5.05600299 -14.89800621  11.76362922
#   -0.54470564  20.           2.68044232  14.67454749   9.87973491
#    9.9671749    2.43346317  12.52806287   7.01999018   7.11637794
#    4.88673337  14.42032275  10.84023909   2.95529129  16.01384103
#    0.3785119 ] gave 0.3092956473641623
# 9
# <ipython-input-22-35855da91661>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-22-35855da91661>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 0.269092
# differential_evolution step 2: f(x)= 0.269092
# differential_evolution step 3: f(x)= 0.266049
# differential_evolution step 4: f(x)= 0.255852
# differential_evolution step 5: f(x)= 0.255852
# differential_evolution step 6: f(x)= 0.255852
# differential_evolution step 7: f(x)= 0.255852
# differential_evolution step 8: f(x)= 0.255852
# differential_evolution step 9: f(x)= 0.253866
# differential_evolution step 10: f(x)= 0.253217
# differential_evolution step 11: f(x)= 0.253217
# differential_evolution step 12: f(x)= 0.253217
# differential_evolution step 13: f(x)= 0.253217
# differential_evolution step 14: f(x)= 0.246743
# differential_evolution step 15: f(x)= 0.245986
# differential_evolution step 16: f(x)= 0.245986
# differential_evolution step 17: f(x)= 0.245986
# differential_evolution step 18: f(x)= 0.245986
# differential_evolution step 19: f(x)= 0.245986
# differential_evolution step 20: f(x)= 0.243793
# differential_evolution step 21: f(x)= 0.243793
# differential_evolution step 22: f(x)= 0.243793
# differential_evolution step 23: f(x)= 0.235025
# differential_evolution step 24: f(x)= 0.235025
# differential_evolution step 25: f(x)= 0.235025
# differential_evolution step 26: f(x)= 0.231564
# differential_evolution step 27: f(x)= 0.229719
# differential_evolution step 28: f(x)= 0.229719
# differential_evolution step 29: f(x)= 0.229719
# differential_evolution step 30: f(x)= 0.229719
# differential_evolution step 31: f(x)= 0.229719
# differential_evolution step 32: f(x)= 0.229719
# differential_evolution step 33: f(x)= 0.225127
# differential_evolution step 34: f(x)= 0.225127
# differential_evolution step 35: f(x)= 0.225127
# differential_evolution step 36: f(x)= 0.225127
# differential_evolution step 37: f(x)= 0.221617
# differential_evolution step 38: f(x)= 0.221617
# differential_evolution step 39: f(x)= 0.2213
# differential_evolution step 40: f(x)= 0.219064
# differential_evolution step 41: f(x)= 0.219064
# differential_evolution step 42: f(x)= 0.218425
# differential_evolution step 43: f(x)= 0.218425
# differential_evolution step 44: f(x)= 0.218425
# differential_evolution step 45: f(x)= 0.218425
# differential_evolution step 46: f(x)= 0.218425
# differential_evolution step 47: f(x)= 0.218425
# differential_evolution step 48: f(x)= 0.218425
# differential_evolution step 49: f(x)= 0.218425
# differential_evolution step 50: f(x)= 0.214512
# differential_evolution step 51: f(x)= 0.214512
# differential_evolution step 52: f(x)= 0.213708
# differential_evolution step 53: f(x)= 0.213708
# differential_evolution step 54: f(x)= 0.211213
# differential_evolution step 55: f(x)= 0.211122
# differential_evolution step 56: f(x)= 0.211122
# differential_evolution step 57: f(x)= 0.211122
# differential_evolution step 58: f(x)= 0.211122
# differential_evolution step 59: f(x)= 0.211122
# differential_evolution step 60: f(x)= 0.211122
# differential_evolution step 61: f(x)= 0.208617
# differential_evolution step 62: f(x)= 0.208617
# differential_evolution step 63: f(x)= 0.208617
# differential_evolution step 64: f(x)= 0.208617
# differential_evolution step 65: f(x)= 0.207042
# differential_evolution step 66: f(x)= 0.207042
# differential_evolution step 67: f(x)= 0.20626
# differential_evolution step 68: f(x)= 0.20626
# differential_evolution step 69: f(x)= 0.20626
# differential_evolution step 70: f(x)= 0.206167
# differential_evolution step 71: f(x)= 0.206167
# differential_evolution step 72: f(x)= 0.206167
# differential_evolution step 73: f(x)= 0.205859
# differential_evolution step 74: f(x)= 0.205859
# differential_evolution step 75: f(x)= 0.205588
# differential_evolution step 76: f(x)= 0.20436
# differential_evolution step 77: f(x)= 0.203998
# differential_evolution step 78: f(x)= 0.202983
# differential_evolution step 79: f(x)= 0.202983
# differential_evolution step 80: f(x)= 0.202983
# differential_evolution step 81: f(x)= 0.202983
# differential_evolution step 82: f(x)= 0.202983
# differential_evolution step 83: f(x)= 0.202983
# differential_evolution step 84: f(x)= 0.202172
# differential_evolution step 85: f(x)= 0.202172
# Params [20.         19.62436439  2.20482557 -9.61294537  0.84649187  9.80306672
#   5.92015323  1.2862293   2.01995082  3.46544638 11.38746185  0.58915842
#   4.56179872  6.4481694   6.2720568   3.3517381   4.82147979  4.27686745
#   6.45700971  6.15706561  3.93040846  5.47277154  6.46087631  9.07708058
#   3.73834498  0.36100614] gave 0.19824418414215134
# 12
# <ipython-input-22-35855da91661>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-22-35855da91661>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 0.271699
# differential_evolution step 2: f(x)= 0.260219
# differential_evolution step 3: f(x)= 0.243909
# differential_evolution step 4: f(x)= 0.243909
# differential_evolution step 5: f(x)= 0.243909
# differential_evolution step 6: f(x)= 0.243737
# differential_evolution step 7: f(x)= 0.223985
# differential_evolution step 8: f(x)= 0.223985
# differential_evolution step 9: f(x)= 0.223985
# differential_evolution step 10: f(x)= 0.223985
# differential_evolution step 11: f(x)= 0.223985
# differential_evolution step 12: f(x)= 0.223985
# differential_evolution step 13: f(x)= 0.223985
# differential_evolution step 14: f(x)= 0.223985
# differential_evolution step 15: f(x)= 0.223985
# differential_evolution step 16: f(x)= 0.223985
# differential_evolution step 17: f(x)= 0.223985
# differential_evolution step 18: f(x)= 0.223985
# differential_evolution step 19: f(x)= 0.223062
# differential_evolution step 20: f(x)= 0.223062
# differential_evolution step 21: f(x)= 0.22294
# differential_evolution step 22: f(x)= 0.22294
# differential_evolution step 23: f(x)= 0.22294
# differential_evolution step 24: f(x)= 0.22294
# differential_evolution step 25: f(x)= 0.221771
# differential_evolution step 26: f(x)= 0.217093
# differential_evolution step 27: f(x)= 0.211961
# differential_evolution step 28: f(x)= 0.211961
# differential_evolution step 29: f(x)= 0.211961
# differential_evolution step 30: f(x)= 0.211961
# differential_evolution step 31: f(x)= 0.210163
# differential_evolution step 32: f(x)= 0.204206
# differential_evolution step 33: f(x)= 0.204206
# differential_evolution step 34: f(x)= 0.204206
# differential_evolution step 35: f(x)= 0.204206
# differential_evolution step 36: f(x)= 0.204206
# differential_evolution step 37: f(x)= 0.204206
# differential_evolution step 38: f(x)= 0.204206
# differential_evolution step 39: f(x)= 0.204206
# differential_evolution step 40: f(x)= 0.204133
# differential_evolution step 41: f(x)= 0.204133
# differential_evolution step 42: f(x)= 0.204133
# differential_evolution step 43: f(x)= 0.204133
# differential_evolution step 44: f(x)= 0.204133
# differential_evolution step 45: f(x)= 0.204133
# differential_evolution step 46: f(x)= 0.204101
# differential_evolution step 47: f(x)= 0.202365
# differential_evolution step 48: f(x)= 0.200015
# differential_evolution step 49: f(x)= 0.200015
# differential_evolution step 50: f(x)= 0.197542
# differential_evolution step 51: f(x)= 0.197542
# differential_evolution step 52: f(x)= 0.197542
# differential_evolution step 53: f(x)= 0.197542
# differential_evolution step 54: f(x)= 0.197542
# differential_evolution step 55: f(x)= 0.197542
# differential_evolution step 56: f(x)= 0.197542
# differential_evolution step 57: f(x)= 0.197542
# differential_evolution step 58: f(x)= 0.197542
# differential_evolution step 59: f(x)= 0.197542
# differential_evolution step 60: f(x)= 0.197542
# differential_evolution step 61: f(x)= 0.197542
# differential_evolution step 62: f(x)= 0.197542
# differential_evolution step 63: f(x)= 0.197542
# differential_evolution step 64: f(x)= 0.197542
# differential_evolution step 65: f(x)= 0.197542
# differential_evolution step 66: f(x)= 0.196685
# differential_evolution step 67: f(x)= 0.196685
# differential_evolution step 68: f(x)= 0.196685
# differential_evolution step 69: f(x)= 0.196685
# differential_evolution step 70: f(x)= 0.196155
# differential_evolution step 71: f(x)= 0.195474
# differential_evolution step 72: f(x)= 0.195424
# differential_evolution step 73: f(x)= 0.195424
# differential_evolution step 74: f(x)= 0.195424
# differential_evolution step 75: f(x)= 0.195424
# differential_evolution step 76: f(x)= 0.195424
# differential_evolution step 77: f(x)= 0.195424
# differential_evolution step 78: f(x)= 0.193537
# differential_evolution step 79: f(x)= 0.193537
# differential_evolution step 80: f(x)= 0.193537
# differential_evolution step 81: f(x)= 0.193537
# differential_evolution step 82: f(x)= 0.193537
# differential_evolution step 83: f(x)= 0.193226
# differential_evolution step 84: f(x)= 0.193226
# differential_evolution step 85: f(x)= 0.193226
# Params [10.30644557  1.38957919 15.53517682 10.77316333  6.77731307  1.85058326
#  10.13533506 15.49419024 13.26124817 12.74340938 15.7840906  10.76744802
#   4.16882073  7.73544403  5.56318888 16.27645302 11.67017541  8.2818439
#   5.74443278 10.13439201 10.52299615  8.97950603  9.63533241  8.72764184
#   4.59536111  0.40965997] gave 0.19070623558019342

# %%
model_fits_ = pickle.load(open('pyddm_fits.pickle', 'rb'))

# %%
pickle.dump(model_fits_, open('pyddm_fits1.pickle', 'wb'))

# %%
fits = pickle.load(open('pyddm_fits1.pickle', 'rb'))

# %%
fits[13].get_model_parameters()[13].real
# Out:
# 5.245067663181991

# %%
drift_rates = np.zeros((14, 12))
bounds = np.zeros((14, 12))
drift_noise = np.zeros(14)
Ter = np.zeros(14)
for participant in range(14):
    for block in range(12):
        drift_rates[participant][block] = fits[participant].get_model_parameters()[block].real
        bounds[participant][block] = fits[participant].get_model_parameters()[block+13].real 
        
    
    Ter[participant] = fits[participant].get_model_parameters()[12].real
    drift_noise[participant] = fits[participant].get_model_parameters()[25].real

# %%
incorrect_thresold = [np.pi/9]
df_ddm = pd.DataFrame({'Condition': np.tile(np.ravel(np.array([np.repeat(['Sudden'], 12*len(incorrect_thresold)), np.repeat(['Gradual'], 12*len(incorrect_thresold))])), 7),
                       'Block': np.tile(np.repeat(np.arange(12), len(incorrect_thresold)), 14),
                      'Drift_Rates': np.ravel(drift_rates),
                       
                       'Incorrect_Criterian':np.tile(np.array([20]), 12*14),
                      'Bounds': np.ravel(bounds),
                    })

# %%
sns.catplot(x = 'Block', y = 'Drift_Rates', hue = 'Condition', data = df_ddm, kind = 'point', capsize = 0.2)

# %%
import pickle
pickle.dump(model_fits, open('ddm_model_point_fits.pickle', 'wb'))

# %% [markdown]
# # Using HDDMs

# %%
import hddm
# Out:
# C:\Users\Tejas\anaconda3\lib\site-packages\IPython\parallel.py:12: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   warn("The `IPython.parallel` package has been deprecated since IPython 4.0. "

# %%
df_rt = hddm.load_csv('RTs.csv')

# %%
df_rt = df_rt.drop(['Unnamed: 0', 'MTs'], axis = 1)
df_error = pd.read_csv(open('Angular_errors.csv'))

df_rt['response'] = 0
df_rt['response'][df_error['Error'] < np.pi/9] = 1
df_rt['response'][df_error['Error'] > np.pi/9] = 0
# Out:
# <ipython-input-4-f9c3b37dc88a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['response'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-4-f9c3b37dc88a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['response'][df_error['Error'] > np.pi/9] = 0

# %%
df_rt = df_rt.rename(columns={'participant_id': 'subj_idx', 'ITs':'rt'})

# %%
model = hddm.load('hddm_fit')

# %%
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-656ac9cc95c6> in <module>
# ----> 1 hddm.analyze.plot_posterior_nodes(model.nodes_db.node[0])
#
# ~\anaconda3\lib\site-packages\kabuki\analyze.py in plot_posterior_nodes(nodes, bins, lb, ub)
#      32     figure()
#      33     if lb is None:
# ---> 34         lb = min([min(node.trace()[:]) for node in nodes])
#      35     if ub is None:
#      36         ub = max([max(node.trace()[:]) for node in nodes])
#
# ~\anaconda3\lib\site-packages\pymc\CommonDeterministics.py in new_method(self, op)
#     644                 'Special method %s called on %s, but special methods have been disabled. Set pymc.special_methods_available to True to enable them.' %
#     645                 (op_name, str(self)))
# --> 646         return op(self.value)
#     647     # Make the function into a method for klass.
#     648     new_method.__name__ = '__' + op.__name__ + '__'
#
# TypeError: iteration over a 0-d array

# %%
m.sample(2000, burn = 20)
# Out:
#  [-----------------100%-----------------] 2000 of 2000 complete in 460.4 sec

# %%
stats = m.gen_stats()

# %%
stats[stats.index.isin(['a', 'a_std', 'a_subj.0', 'a_subj.1'])]
# Out:
#               mean        std      2.5q       25q       50q       75q  \
# a          2.13484   0.194851   1.78852   2.00406   2.12462   2.24595
# a_std     0.726409   0.183406  0.455013  0.596192  0.694274  0.831464
# a_subj.0   1.97159  0.0450135   1.88241    1.9412   1.97107   2.00136
# a_subj.1   2.33866  0.0607831   2.22544   2.29638   2.33684   2.37999
#
#             97.5q      mc err
# a          2.5731  0.00693227
# a_std     1.17195  0.00860781
# a_subj.0  2.05996  0.00141201
# a_subj.1  2.46379    0.002478

# %%
m.plot_posteriors(['a', 't', 'v', 'a_std'])
# Out:
# Plotting a
# Plotting a_std
# Plotting v
# Plotting t

# %%
m_stim = hddm.HDDM(df_rt, depends_on={'v': ['block', 'condition'], 'a':['block', 'condition']})
m_stim.find_starting_values()
m_stim.sample(10000, burn=1000, dbname = 'traces.db', db = 'pickle')
m_stim.save('hddm_fit')

non_hierarchical_model = hddm.HDDM(df_rt, depends_on={'v': ['block', 'condition'], 'a':['block', 'condition']}, is_group_model = False)
non_hierarchical_model.find_starting_values()
non_hierarchical_model.sample(10000, burn=1000, dbname = 'traces.db', db = 'pickle')
non_hierarchical_model.save('nhddm_fit')
# Out:
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
#  [-----------------100%-----------------] 10000 of 10000 complete in 5300.2 sec-17191.38500230904
# -17191.321958238004
#  [-----------------100%-----------------] 10000 of 10000 complete in 1313.5 sec-------------   38%                  ] 3813 of 10000 complete in 505.2 sec

# %%
m_stim.dbname = 'traces.db'
m_stim.db = 'pickle'

# %%
m_stim.
# Out:
#        subj_idx condition  Trial        rt  block  response
# 0             0    Sudden      0 -0.000074      0         0
# 1             1   Gradual      0 -0.000075      0         0
# 2             2    Sudden      0 -0.000134      0         0
# 3             3   Gradual      0  0.883418      0         1
# 4             4    Sudden      0 -0.920651      0         0
# ...         ...       ...    ...       ...    ...       ...
# 10747         9   Gradual    767  0.780795     11         1
# 10748        10    Sudden    767  0.733294     11         1
# 10749        11   Gradual    767 -1.200126     11         0
# 10750        12    Sudden    767  0.560747     11         1
# 10751        13   Gradual    767 -0.633230     11         0
#
# [10752 rows x 6 columns]

# %%
m_stim = hddm.load('hddm_fit')

# %%
m_stim.
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-23-25b936ff4097> in <module>
# ----> 1 m_stim.aic
#
# ~/anaconda3/lib/python3.8/site-packages/kabuki/hierarchical.py in aic(self)
#     689         """
#     690         if self.is_group_model:
# --> 691             raise NotImplementedError('AIC can only be computed for non-hierarchical models. See dic.')
#     692         k = len(self.get_stochastics())
#     693         logp = sum([x.logp for x in self.get_observeds()['node']])
#
# NotImplementedError: AIC can only be computed for non-hierarchical models. See dic.

# %%
list(m_stim.nodes_db.node)
# Out:
# [<pymc.distributions.new_dist_class.<locals>.new_class 'a(0.Gradual)' at 0x000002853C1C8940>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(0.Sudden)' at 0x0000028536A58E20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(1.Gradual)' at 0x000002853C1F90D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(1.Sudden)' at 0x000002853C1F9100>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(2.Gradual)' at 0x0000028536A4D760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(2.Sudden)' at 0x000002853C1B6370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(3.Gradual)' at 0x000002853C1B6190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(3.Sudden)' at 0x000002853C1B66A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(4.Gradual)' at 0x000002853C1B6400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(4.Sudden)' at 0x000002853C1C87C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(5.Gradual)' at 0x000002853C1C8670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(5.Sudden)' at 0x000002853C1C8C40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(6.Gradual)' at 0x000002853C1C8CA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(6.Sudden)' at 0x000002853C1C8790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(7.Gradual)' at 0x000002853C21D910>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(7.Sudden)' at 0x000002853C21D9A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(8.Gradual)' at 0x000002853C21D940>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(8.Sudden)' at 0x000002853C21D310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(9.Gradual)' at 0x000002853C21DC40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(9.Sudden)' at 0x000002853C21DC70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(10.Gradual)' at 0x000002853C21DCA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(10.Sudden)' at 0x000002853C21DD30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(11.Gradual)' at 0x000002853C21DDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a(11.Sudden)' at 0x000002853C21D8B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_std' at 0x000002853C1B6070>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(0.Gradual)' at 0x000002853C21D850>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(0.Sudden)' at 0x000002853C1B6790>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(1.Gradual)' at 0x000002853C1C8BE0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(1.Sudden)' at 0x000002853C21DAC0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(2.Gradual)' at 0x000002853C1B69D0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(2.Sudden)' at 0x000002853C21D820>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(3.Gradual)' at 0x000002853C21D790>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(3.Sudden)' at 0x000002853C21DF40>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(4.Gradual)' at 0x000002853C21DF10>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(4.Sudden)' at 0x000002853C21D640>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(5.Gradual)' at 0x000002853C21DA00>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(5.Sudden)' at 0x000002853C21DE50>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(6.Gradual)' at 0x000002853C21DEE0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(6.Sudden)' at 0x000002853C21D430>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(7.Gradual)' at 0x000002853C21D1C0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(7.Sudden)' at 0x000002853C21D760>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(8.Gradual)' at 0x000002853C2574C0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(8.Sudden)' at 0x000002853C257820>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(9.Gradual)' at 0x000002853C257850>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(9.Sudden)' at 0x000002853C257880>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(10.Gradual)' at 0x000002853C2578B0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(10.Sudden)' at 0x000002853C2578E0>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(11.Gradual)' at 0x000002853C257910>,
#  <pymc.PyMCObjects.Deterministic 'a_rate(11.Sudden)' at 0x000002853C257940>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(0.Gradual)' at 0x000002853C257220>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(0.Sudden)' at 0x000002853C21DE20>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(1.Gradual)' at 0x000002853C1B61C0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(1.Sudden)' at 0x000002853C1C8B80>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(2.Gradual)' at 0x000002853C21DFD0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(2.Sudden)' at 0x000002853C21D0A0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(3.Gradual)' at 0x000002853C257700>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(3.Sudden)' at 0x000002853C257D00>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(4.Gradual)' at 0x000002853C257C70>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(4.Sudden)' at 0x000002853C257BB0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(5.Gradual)' at 0x000002853C257CA0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(5.Sudden)' at 0x000002853C257C10>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(6.Gradual)' at 0x000002853C257D90>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(6.Sudden)' at 0x000002853C257D60>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(7.Gradual)' at 0x000002853C257DC0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(7.Sudden)' at 0x000002853C257DF0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(8.Gradual)' at 0x000002853C257E20>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(8.Sudden)' at 0x000002853C257E50>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(9.Gradual)' at 0x000002853C257E80>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(9.Sudden)' at 0x000002853C257D30>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(10.Gradual)' at 0x000002853C257190>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(10.Sudden)' at 0x000002853C2571C0>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(11.Gradual)' at 0x000002853C257160>,
#  <pymc.PyMCObjects.Deterministic 'a_shape(11.Sudden)' at 0x000002853C2577C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).1' at 0x000002853C257B50>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).3' at 0x000002853C1B6730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).5' at 0x000002853C21D190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).7' at 0x000002853C257B80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).9' at 0x000002853C2579A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).11' at 0x000002853C257F70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Gradual).13' at 0x000002853C2573A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).0' at 0x000002853C2570A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).2' at 0x000002853C257B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).4' at 0x000002853C257F10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).6' at 0x000002853C2577F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).8' at 0x000002853C257640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).10' at 0x000002853C257970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(0.Sudden).12' at 0x000002853C257460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).1' at 0x000002853C3CDD00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).3' at 0x000002853C3CD2B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).5' at 0x000002853C3CD310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).7' at 0x000002853C3CD370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).9' at 0x000002853C3CD400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).11' at 0x000002853C3CD820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Gradual).13' at 0x000002853C3CDAF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).0' at 0x000002853C3CDDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).2' at 0x000002853C3CDC70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).4' at 0x000002853C3CDF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).6' at 0x000002853C3CD850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).8' at 0x000002853C3CD6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).10' at 0x000002853C3CDA60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(1.Sudden).12' at 0x000002853C3CDFA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).1' at 0x000002853C3CDE20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).3' at 0x000002853C3CD250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).5' at 0x000002853C3CD5E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).7' at 0x000002853C3FFD30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).9' at 0x000002853C3FF2E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).11' at 0x000002853C3FF340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Gradual).13' at 0x000002853C3FF3A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).0' at 0x000002853C3FF430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).2' at 0x000002853C3FF850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).4' at 0x000002853C3FF970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).6' at 0x000002853C3FFEE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).8' at 0x000002853C3FFD90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).10' at 0x000002853C3FF280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(2.Sudden).12' at 0x000002853C3FFB20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).1' at 0x000002853C3FF880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).3' at 0x000002853C3FFA90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).5' at 0x000002853C3FF640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).7' at 0x000002853C3FF4C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).9' at 0x000002853C3FFF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).11' at 0x000002853C3FF790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Gradual).13' at 0x000002853C42FDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).0' at 0x000002853C42F280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).2' at 0x000002853C42F2E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).4' at 0x000002853C42F370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).6' at 0x000002853C42F790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).8' at 0x000002853C42F730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).10' at 0x000002853C42F820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(3.Sudden).12' at 0x000002853C42FF10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).1' at 0x000002853C42FFD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).3' at 0x000002853C42F400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).5' at 0x000002853C42FD30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).7' at 0x000002853C42F6A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).9' at 0x000002853C42F670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).11' at 0x000002853C42FA00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Gradual).13' at 0x000002853C42F7C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).0' at 0x000002853C42FCA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).2' at 0x000002853C45FD00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).4' at 0x000002853C45F2B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).6' at 0x000002853C45F310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).8' at 0x000002853C45F370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).10' at 0x000002853C45F400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(4.Sudden).12' at 0x000002853C45F820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).1' at 0x000002853C45FAF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).3' at 0x000002853C45FDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).5' at 0x000002853C45FC70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).7' at 0x000002853C45FF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).9' at 0x000002853C45F850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).11' at 0x000002853C45F6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Gradual).13' at 0x000002853C45FA60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).0' at 0x000002853C45FFA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).2' at 0x000002853C45FE20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).4' at 0x000002853C45F250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).6' at 0x000002853C45F5E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).8' at 0x000002853C490D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).10' at 0x000002853C4902E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(5.Sudden).12' at 0x000002853C490340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).1' at 0x000002853C4903A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).3' at 0x000002853C490430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).5' at 0x000002853C490850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).7' at 0x000002853C490C10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).9' at 0x000002853C490BB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).11' at 0x000002853C490FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Gradual).13' at 0x000002853C490F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).0' at 0x000002853C490970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).2' at 0x000002853C490B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).4' at 0x000002853C490A60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).6' at 0x000002853C490640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).8' at 0x000002853C490E50>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).10' at 0x000002853C490EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(6.Sudden).12' at 0x000002853C490C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).1' at 0x000002853C4BED90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).3' at 0x000002853C4BE280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).5' at 0x000002853C4BE2E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).7' at 0x000002853C4BE310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).9' at 0x000002853C4BE6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).11' at 0x000002853C4BE760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Gradual).13' at 0x000002853C4BE850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).0' at 0x000002853C4BEF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).2' at 0x000002853C4BEFA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).4' at 0x000002853C4BE8B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).6' at 0x000002853C4BEC70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).8' at 0x000002853C4BEF70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).10' at 0x000002853C4BEAF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(7.Sudden).12' at 0x000002853C4BEEB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).1' at 0x000002853C4BEBB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).3' at 0x000002853C4BE5E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).5' at 0x000002853C4BE9D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).7' at 0x000002853C4ECDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).9' at 0x000002853C4EC2B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).11' at 0x000002853C4EC310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Gradual).13' at 0x000002853C4EC340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).0' at 0x000002853C4EC700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).2' at 0x000002853C4EC790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).4' at 0x000002853C4EC880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).6' at 0x000002853C4ECF10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).8' at 0x000002853C4ECFD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).10' at 0x000002853C4EC430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(8.Sudden).12' at 0x000002853C4ECD30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).1' at 0x000002853C4EC610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).3' at 0x000002853C4EC6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).5' at 0x000002853C4EC8E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).7' at 0x000002853C4EC820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).9' at 0x000002853C4ECCA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).11' at 0x000002853C519D00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Gradual).13' at 0x000002853C5192B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).0' at 0x000002853C519310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).2' at 0x000002853C519370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).4' at 0x000002853C519400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).6' at 0x000002853C519820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).8' at 0x000002853C519AF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).10' at 0x000002853C519DC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(9.Sudden).12' at 0x000002853C519C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).1' at 0x000002853C519F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).3' at 0x000002853C519850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).5' at 0x000002853C5196D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).7' at 0x000002853C519A60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).9' at 0x000002853C519FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).11' at 0x000002853C519E20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Gradual).13' at 0x000002853C519250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).0' at 0x000002853C5195E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).2' at 0x000002853C546D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).4' at 0x000002853C5462E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).6' at 0x000002853C546340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).8' at 0x000002853C5463A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).10' at 0x000002853C546430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(10.Sudden).12' at 0x000002853C546850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).1' at 0x000002853C546970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).3' at 0x000002853C546EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).5' at 0x000002853C546D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).7' at 0x000002853C546280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).9' at 0x000002853C546B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).11' at 0x000002853C546880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Gradual).13' at 0x000002853C546A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).0' at 0x000002853C546640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).2' at 0x000002853C5464C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).4' at 0x000002853C546F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).6' at 0x000002853C546790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).8' at 0x000002853C571D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).10' at 0x000002853C571280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'a_subj(11.Sudden).12' at 0x000002853C5712E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(0.Gradual)' at 0x000002853C571F10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(0.Sudden)' at 0x000002853C21D070>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(1.Gradual)' at 0x000002853C1B6460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(1.Sudden)' at 0x000002853C571670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(2.Gradual)' at 0x000002853C5719D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(2.Sudden)' at 0x000002853C2579D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(3.Gradual)' at 0x000002853C257550>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(3.Sudden)' at 0x000002853C571D60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(4.Gradual)' at 0x000002853C571910>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(4.Sudden)' at 0x000002853C571F70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(5.Gradual)' at 0x000002853C571970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(5.Sudden)' at 0x000002853C5716A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(6.Gradual)' at 0x000002853C571FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(6.Sudden)' at 0x000002853C59B880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(7.Gradual)' at 0x000002853C59B910>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(7.Sudden)' at 0x000002853C59B9A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(8.Gradual)' at 0x000002853C59BA30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(8.Sudden)' at 0x000002853C59BAC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(9.Gradual)' at 0x000002853C59BB50>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(9.Sudden)' at 0x000002853C59BBE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(10.Gradual)' at 0x000002853C59BC70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(10.Sudden)' at 0x000002853C59BD00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(11.Gradual)' at 0x000002853C59BD90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v(11.Sudden)' at 0x000002853C59BE20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_std' at 0x000002853C571790>,
#  <pymc.PyMCObjects.Deterministic 'v_tau' at 0x000002853C571730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).1' at 0x000002853C59B490>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).3' at 0x000002853C59B340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).5' at 0x000002853C571370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).7' at 0x000002853C257BE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).9' at 0x000002853C59B7C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).11' at 0x000002853C59BF70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Gradual).13' at 0x000002853C59BF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).0' at 0x000002853C59B4C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).2' at 0x000002853C59B1C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).4' at 0x000002853C5E1A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).6' at 0x000002853C5E1550>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).8' at 0x000002853C5E1610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).10' at 0x000002853C5E1670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(0.Sudden).12' at 0x000002853C5E16A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).1' at 0x000002853C5E1970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).3' at 0x000002853C5E1310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).5' at 0x000002853C5E1580>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).7' at 0x000002853C5E1F10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).9' at 0x000002853C5E1FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).11' at 0x000002853C5E18E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Gradual).13' at 0x000002853C5E17C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).0' at 0x000002853C5E17F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).2' at 0x000002853C5E1A00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).4' at 0x000002853C5E1910>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).6' at 0x000002853C5E1C10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).8' at 0x000002853C5E1D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).10' at 0x000002853C612D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(1.Sudden).12' at 0x000002853C6122E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).1' at 0x000002853C612340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).3' at 0x000002853C612400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).5' at 0x000002853C6124F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).7' at 0x000002853C6127C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).9' at 0x000002853C612970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).11' at 0x000002853C612EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Gradual).13' at 0x000002853C612FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).0' at 0x000002853C612280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).2' at 0x000002853C612B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).4' at 0x000002853C612640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).6' at 0x000002853C612A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).8' at 0x000002853C612610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).10' at 0x000002853C612FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(2.Sudden).12' at 0x000002853C612F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).1' at 0x000002853C612550>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).3' at 0x000002853C647D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).5' at 0x000002853C647280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).7' at 0x000002853C6472E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).9' at 0x000002853C647310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).11' at 0x000002853C6476D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Gradual).13' at 0x000002853C647760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).0' at 0x000002853C647850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).2' at 0x000002853C647F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).4' at 0x000002853C647FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).6' at 0x000002853C6478B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).8' at 0x000002853C647C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).10' at 0x000002853C647F70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(3.Sudden).12' at 0x000002853C647AF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).1' at 0x000002853C647EB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).3' at 0x000002853C647BB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).5' at 0x000002853C6475E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).7' at 0x000002853C6479D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).9' at 0x000002853C680DC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).11' at 0x000002853C6802B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Gradual).13' at 0x000002853C680310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).0' at 0x000002853C680340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).2' at 0x000002853C680700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).4' at 0x000002853C680790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).6' at 0x000002853C680880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).8' at 0x000002853C680F10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).10' at 0x000002853C680FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(4.Sudden).12' at 0x000002853C680430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).1' at 0x000002853C680D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).3' at 0x000002853C680610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).5' at 0x000002853C6806D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).7' at 0x000002853C6808E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).9' at 0x000002853C680820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).11' at 0x000002853C680CA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Gradual).13' at 0x000002853C6B9D00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).0' at 0x000002853C6B92B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).2' at 0x000002853C6B9310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).4' at 0x000002853C6B9370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).6' at 0x000002853C6B9400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).8' at 0x000002853C6B9820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).10' at 0x000002853C6B9AF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(5.Sudden).12' at 0x000002853C6B9DC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).1' at 0x000002853C6B9C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).3' at 0x000002853C6B9F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).5' at 0x000002853C6B9850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).7' at 0x000002853C6B96D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).9' at 0x000002853C6B9A60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).11' at 0x000002853C6B9FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Gradual).13' at 0x000002853C6B9E20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).0' at 0x000002853C6B9250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).2' at 0x000002853C6B95E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).4' at 0x000002853C6F0D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).6' at 0x000002853C6F02E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).8' at 0x000002853C6F0340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).10' at 0x000002853C6F03A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(6.Sudden).12' at 0x000002853C6F0430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).1' at 0x000002853C6F0850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).3' at 0x000002853C6F0970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).5' at 0x000002853C6F0EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).7' at 0x000002853C6F0D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).9' at 0x000002853C6F0280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).11' at 0x000002853C6F0B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Gradual).13' at 0x000002853C6F0880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).0' at 0x000002853C6F0A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).2' at 0x000002853C6F0640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).4' at 0x000002853C6F04C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).6' at 0x000002853C6F0F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).8' at 0x000002853C6F0790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).10' at 0x000002853C727D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(7.Sudden).12' at 0x000002853C727280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).1' at 0x000002853C7272E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).3' at 0x000002853C727610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).5' at 0x000002853C727730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).7' at 0x000002853C727A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).9' at 0x000002853C727EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).11' at 0x000002853C727FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Gradual).13' at 0x000002853C727FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).0' at 0x000002853C727400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).2' at 0x000002853C727D00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).4' at 0x000002853C727640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).6' at 0x000002853C727550>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).8' at 0x000002853C7279A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).10' at 0x000002853C727460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(8.Sudden).12' at 0x000002853C727850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).1' at 0x000002853C75ED00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).3' at 0x000002853C75E2B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).5' at 0x000002853C75E310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).7' at 0x000002853C75E370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).9' at 0x000002853C75E400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).11' at 0x000002853C75E910>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Gradual).13' at 0x000002853C75EBE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).0' at 0x000002853C75EB80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).2' at 0x000002853C75ED60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).4' at 0x000002853C75EDC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).6' at 0x000002853C75E940>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).8' at 0x000002853C75EAF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).10' at 0x000002853C75EA30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(9.Sudden).12' at 0x000002853C75E9A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).1' at 0x000002853C75EFA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).3' at 0x000002853C75EEB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).5' at 0x000002853C75E5E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).7' at 0x000002853C794D60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).9' at 0x000002853C794250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).11' at 0x000002853C7942B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Gradual).13' at 0x000002853C794370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).0' at 0x000002853C794460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).2' at 0x000002853C794880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).4' at 0x000002853C7949A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).6' at 0x000002853C794F10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).8' at 0x000002853C794F70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).10' at 0x000002853C7941F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(10.Sudden).12' at 0x000002853C794B50>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).1' at 0x000002853C7948B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).3' at 0x000002853C794AC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).5' at 0x000002853C794670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).7' at 0x000002853C794400>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).9' at 0x000002853C794E80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).11' at 0x000002853C7947C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Gradual).13' at 0x000002853C7CED90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).0' at 0x000002853C7CE280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).2' at 0x000002853C7CE2E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).4' at 0x000002853C7CE310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).6' at 0x000002853C7CE6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).8' at 0x000002853C7CE760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).10' at 0x000002853C7CE850>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'v_subj(11.Sudden).12' at 0x000002853C7CEF40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't' at 0x000002853C21D9D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_std' at 0x000002853C59BDF0>,
#  <pymc.PyMCObjects.Deterministic 't_rate' at 0x000002853C7CEF70>,
#  <pymc.PyMCObjects.Deterministic 't_shape' at 0x000002853C2570D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.0' at 0x000002853C803700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.1' at 0x000002853C1B6310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.2' at 0x000002853C59B130>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.3' at 0x000002853C803970>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.4' at 0x000002853C8033D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.5' at 0x000002853C803940>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.6' at 0x000002853C803D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.7' at 0x000002853C803EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.8' at 0x000002853C803A30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.9' at 0x000002853C803CA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.10' at 0x000002853C803FA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.11' at 0x000002853C803D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.12' at 0x000002853C8032E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 't_subj.13' at 0x000002853C803C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).1' at 0x000002853C82D070>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).3' at 0x000002853C82D8B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).5' at 0x000002853C82DB80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).7' at 0x000002853C82DEB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).9' at 0x000002853C8574F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).11' at 0x000002853C857700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Gradual).13' at 0x000002853C857280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).0' at 0x000002853C857580>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).2' at 0x000002853C8577F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).4' at 0x000002853C857C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).6' at 0x000002853C857EE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).8' at 0x000002853C8723D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).10' at 0x000002853C872160>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(0.Sudden).12' at 0x000002853C872460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).1' at 0x000002853C872670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).3' at 0x000002853C872A90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).5' at 0x000002853C872DF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).7' at 0x000002853C894520>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).9' at 0x000002853C894730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).11' at 0x000002853C8942B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Gradual).13' at 0x000002853C8945B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).0' at 0x000002853C894820>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).2' at 0x000002853C3CD0D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).4' at 0x000002853C3CD1F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).6' at 0x000002853C3CDA00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).8' at 0x000002853C3FF190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).10' at 0x000002853C3FFEB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(1.Sudden).12' at 0x000002853C42F3D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).1' at 0x000002853C42F1F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).3' at 0x000002853C42FDF0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).5' at 0x000002853C45FD90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).7' at 0x000002853C45F340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).9' at 0x000002853C490250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).11' at 0x000002853C4909A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Gradual).13' at 0x000002853C490700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).0' at 0x000002853C4BE250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).2' at 0x000002853C4BED30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).4' at 0x000002853C4ECD60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).6' at 0x000002853C4ECA30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).8' at 0x000002853C4ECE20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).10' at 0x000002853C519220>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(2.Sudden).12' at 0x000002853C5192E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).1' at 0x000002853C546CD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).3' at 0x000002853C546250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).5' at 0x000002853C546490>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).7' at 0x000002853C571C40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).9' at 0x000002853C571040>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).11' at 0x000002853C5E1CD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Gradual).13' at 0x000002853C5E16D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).0' at 0x000002853C6121C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).2' at 0x000002853C6122B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).4' at 0x000002853C612940>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).6' at 0x000002853C647070>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).8' at 0x000002853C647250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).10' at 0x000002853C647E20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(3.Sudden).12' at 0x000002853C680670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).1' at 0x000002853C680E50>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).3' at 0x000002853C6B9BB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).5' at 0x000002853C6B9340>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).7' at 0x000002853C6B9190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).9' at 0x000002853C6F0310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).11' at 0x000002853C6F0370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Gradual).13' at 0x000002853C7271F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).0' at 0x000002853C727A00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).2' at 0x000002853C727B80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).4' at 0x000002853C75E2E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).6' at 0x000002853C75ED90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).8' at 0x000002853C794220>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).10' at 0x000002853C7948E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(4.Sudden).12' at 0x000002853C794C40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).1' at 0x000002853C7CE250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).3' at 0x000002853C8039D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).5' at 0x000002853C82D1C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).7' at 0x000002853C872BE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).9' at 0x000002853C857CD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).11' at 0x000002853C894F70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Gradual).13' at 0x0000028536996B20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).0' at 0x000002853C7CE8E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).2' at 0x0000028536A3E700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).4' at 0x000002853B87B460>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).6' at 0x000002853B87B190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).8' at 0x000002853BB82280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).10' at 0x000002853BB97130>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(5.Sudden).12' at 0x000002853B8979A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).1' at 0x000002853BB82D90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).3' at 0x000002853BB9E040>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).5' at 0x000002853BB9E8B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).7' at 0x000002853BB9E280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).9' at 0x000002853BB6CB20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).11' at 0x000002853BB6CF10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Gradual).13' at 0x000002853BA97F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).0' at 0x000002853BC6E5B0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).2' at 0x000002853BC6E3A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).4' at 0x0000028536A58FD0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).6' at 0x000002853C9DD040>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).8' at 0x000002853C9DD190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).10' at 0x000002853C9DD490>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(6.Sudden).12' at 0x000002853C9DD6A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).1' at 0x000002853C9DDAC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).3' at 0x000002853C9DDE20>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).5' at 0x000002853CA026A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).7' at 0x000002853CA02700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).9' at 0x000002853CA022E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).11' at 0x000002853CA025E0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Gradual).13' at 0x000002853CA029A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).0' at 0x000002853CA02D00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).2' at 0x000002853CA02EB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).4' at 0x000002853CA1F640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).6' at 0x000002853CA1F1C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).8' at 0x000002853CA1F4C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).10' at 0x000002853CA1F6D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(7.Sudden).12' at 0x000002853CA1FBB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).1' at 0x000002853CA1FE80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).3' at 0x000002853CA43070>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).5' at 0x000002853CA43730>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).7' at 0x000002853CA43310>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).9' at 0x000002853CA43610>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).11' at 0x000002853CA439D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Gradual).13' at 0x000002853CA43D30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).0' at 0x000002853CA43F40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).2' at 0x000002853CA5D670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).4' at 0x000002853CA5D1F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).6' at 0x000002853CA5D4F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).8' at 0x000002853CA5D760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).10' at 0x000002853CA5DBE0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(8.Sudden).12' at 0x000002853CA5DE80>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).1' at 0x000002853CA80490>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).3' at 0x000002853CA80760>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).5' at 0x000002853CA80280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).7' at 0x000002853CA80640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).9' at 0x000002853CA80A00>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).11' at 0x000002853CA80D60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Gradual).13' at 0x000002853CA80C70>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).0' at 0x000002853CA9C6A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).2' at 0x000002853CA9C220>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).4' at 0x000002853CA9C520>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).6' at 0x000002853CA9C790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).8' at 0x000002853CA9CC10>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).10' at 0x000002853CA9CFA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(9.Sudden).12' at 0x000002853CABB0D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).1' at 0x000002853CABB790>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).3' at 0x000002853CABB370>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).5' at 0x000002853CABB670>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).7' at 0x000002853CABBA30>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).9' at 0x000002853CABBD90>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).11' at 0x000002853CAD64C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Gradual).13' at 0x000002853CAD66D0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).0' at 0x000002853CAD6250>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).2' at 0x000002853CAD6550>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).4' at 0x000002853CAD67C0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).6' at 0x000002853CAD6C40>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).8' at 0x000002853CAD6EB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).10' at 0x000002853CAF53A0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(10.Sudden).12' at 0x000002853CAF5130>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).1' at 0x000002853CAF5430>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).3' at 0x000002853CAF5640>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).5' at 0x000002853CAF5A60>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).7' at 0x000002853CAF5DC0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).9' at 0x000002853CB134F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).11' at 0x000002853CB13700>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Gradual).13' at 0x000002853CB13280>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).0' at 0x000002853CB13880>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).2' at 0x000002853CB137F0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).4' at 0x000002853CB13CA0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).6' at 0x000002853CB13BB0>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).8' at 0x000002853CB2E040>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).10' at 0x000002853CB2E190>,
#  <pymc.distributions.new_dist_class.<locals>.new_class 'wfpt(11.Sudden).12' at 0x000002853CB2E490>]

# %%
v_gradual = m_stim.nodes_db.node[['v(0.Gradual)', 'v(1.Gradual)', 'v(2.Gradual)', 'v(3.Gradual)', 'v(4.Gradual)', 'v(5.Gradual)',
                                'v(6.Gradual)', 'v(7.Gradual)', 'v(8.Gradual)', 'v(9.Gradual)', 'v(10.Gradual)', 'v(11.Gradual)']]

# %%
v_sudden = m_stim.nodes_db.node[['v(0.Sudden)', 'v(1.Sudden)', 'v(2.Sudden)', 'v(3.Sudden)', 'v(4.Sudden)', 'v(5.Sudden)',
                                'v(6.Sudden)', 'v(7.Sudden)', 'v(8.Sudden)', 'v(9.Sudden)', 'v(10.Sudden)', 'v(11.Sudden)']]

# %%
a_gradual = m_stim.nodes_db.node[['a(0.Gradual)', 'a(1.Gradual)', 'a(2.Gradual)', 'a(3.Gradual)', 'a(4.Gradual)', 'a(5.Gradual)',
                                'a(6.Gradual)', 'a(7.Gradual)', 'a(8.Gradual)', 'a(9.Gradual)', 'a(10.Gradual)', 'a(11.Gradual)']]

# %%
a_sudden = m_stim.nodes_db.node[['a(0.Sudden)', 'a(1.Sudden)', 'a(2.Sudden)', 'a(3.Sudden)', 'a(4.Sudden)', 'a(5.Sudden)',
                                'a(6.Sudden)', 'a(7.Sudden)', 'a(8.Sudden)', 'a(9.Sudden)', 'a(10.Sudden)', 'a(11.Sudden)']]

# %%
block = 11
vblock = model.nodes_db.node[['v('+str(block)+'.Gradual)', 'v('+str(block)+'.Sudden)']]
ablock = model.nodes_db.node[['a('+str(block)+'.Gradual)', 'a('+str(block)+'.Sudden)']]

# %%
hddm.analyze.plot_posterior_nodes(vblock),
hddm.analyze.plot_posterior_nodes(ablock)

# %%
ppc_data.head(10)

# %%
non_hierarchical_model = hddm.HDDM(df_rt, depends_on={'v': ['block', 'condition'], 'a':['block', 'condition']}, is_group_model = False)
non_hierarchical_model.find_starting_values()
non_hierarchical_model.sample(10000, burn=1000)
# Out:
# -17191.336388660362
# -17191.31484475386
# Halting at iteration  1620  of  10000   ] 1618 of 10000 complete in 217.6 sec

# %%
m_stim.sample(5000, dbname = 'traces.db', db = 'pickle')
# Out:
#  [                  0%                  ] 10 of 5000 complete in 6.8 secHalting at iteration  9  of  5000

# %%
stats.to_csv('hddm_fits.csv')

# %%
s = pd.read_csv('hddm_fits.csv')

# %%
list(s['Unnamed: 0'])
# Out:
# ['a(0.Gradual)',
#  'a(0.Sudden)',
#  'a(1.Gradual)',
#  'a(1.Sudden)',
#  'a(2.Gradual)',
#  'a(2.Sudden)',
#  'a(3.Gradual)',
#  'a(3.Sudden)',
#  'a(4.Gradual)',
#  'a(4.Sudden)',
#  'a(5.Gradual)',
#  'a(5.Sudden)',
#  'a(6.Gradual)',
#  'a(6.Sudden)',
#  'a(7.Gradual)',
#  'a(7.Sudden)',
#  'a(8.Gradual)',
#  'a(8.Sudden)',
#  'a(9.Gradual)',
#  'a(9.Sudden)',
#  'a(10.Gradual)',
#  'a(10.Sudden)',
#  'a(11.Gradual)',
#  'a(11.Sudden)',
#  'a_std',
#  'a_subj(0.Gradual).1',
#  'a_subj(0.Gradual).3',
#  'a_subj(0.Gradual).5',
#  'a_subj(0.Gradual).7',
#  'a_subj(0.Gradual).9',
#  'a_subj(0.Gradual).11',
#  'a_subj(0.Gradual).13',
#  'a_subj(0.Sudden).0',
#  'a_subj(0.Sudden).2',
#  'a_subj(0.Sudden).4',
#  'a_subj(0.Sudden).6',
#  'a_subj(0.Sudden).8',
#  'a_subj(0.Sudden).10',
#  'a_subj(0.Sudden).12',
#  'a_subj(1.Gradual).1',
#  'a_subj(1.Gradual).3',
#  'a_subj(1.Gradual).5',
#  'a_subj(1.Gradual).7',
#  'a_subj(1.Gradual).9',
#  'a_subj(1.Gradual).11',
#  'a_subj(1.Gradual).13',
#  'a_subj(1.Sudden).0',
#  'a_subj(1.Sudden).2',
#  'a_subj(1.Sudden).4',
#  'a_subj(1.Sudden).6',
#  'a_subj(1.Sudden).8',
#  'a_subj(1.Sudden).10',
#  'a_subj(1.Sudden).12',
#  'a_subj(2.Gradual).1',
#  'a_subj(2.Gradual).3',
#  'a_subj(2.Gradual).5',
#  'a_subj(2.Gradual).7',
#  'a_subj(2.Gradual).9',
#  'a_subj(2.Gradual).11',
#  'a_subj(2.Gradual).13',
#  'a_subj(2.Sudden).0',
#  'a_subj(2.Sudden).2',
#  'a_subj(2.Sudden).4',
#  'a_subj(2.Sudden).6',
#  'a_subj(2.Sudden).8',
#  'a_subj(2.Sudden).10',
#  'a_subj(2.Sudden).12',
#  'a_subj(3.Gradual).1',
#  'a_subj(3.Gradual).3',
#  'a_subj(3.Gradual).5',
#  'a_subj(3.Gradual).7',
#  'a_subj(3.Gradual).9',
#  'a_subj(3.Gradual).11',
#  'a_subj(3.Gradual).13',
#  'a_subj(3.Sudden).0',
#  'a_subj(3.Sudden).2',
#  'a_subj(3.Sudden).4',
#  'a_subj(3.Sudden).6',
#  'a_subj(3.Sudden).8',
#  'a_subj(3.Sudden).10',
#  'a_subj(3.Sudden).12',
#  'a_subj(4.Gradual).1',
#  'a_subj(4.Gradual).3',
#  'a_subj(4.Gradual).5',
#  'a_subj(4.Gradual).7',
#  'a_subj(4.Gradual).9',
#  'a_subj(4.Gradual).11',
#  'a_subj(4.Gradual).13',
#  'a_subj(4.Sudden).0',
#  'a_subj(4.Sudden).2',
#  'a_subj(4.Sudden).4',
#  'a_subj(4.Sudden).6',
#  'a_subj(4.Sudden).8',
#  'a_subj(4.Sudden).10',
#  'a_subj(4.Sudden).12',
#  'a_subj(5.Gradual).1',
#  'a_subj(5.Gradual).3',
#  'a_subj(5.Gradual).5',
#  'a_subj(5.Gradual).7',
#  'a_subj(5.Gradual).9',
#  'a_subj(5.Gradual).11',
#  'a_subj(5.Gradual).13',
#  'a_subj(5.Sudden).0',
#  'a_subj(5.Sudden).2',
#  'a_subj(5.Sudden).4',
#  'a_subj(5.Sudden).6',
#  'a_subj(5.Sudden).8',
#  'a_subj(5.Sudden).10',
#  'a_subj(5.Sudden).12',
#  'a_subj(6.Gradual).1',
#  'a_subj(6.Gradual).3',
#  'a_subj(6.Gradual).5',
#  'a_subj(6.Gradual).7',
#  'a_subj(6.Gradual).9',
#  'a_subj(6.Gradual).11',
#  'a_subj(6.Gradual).13',
#  'a_subj(6.Sudden).0',
#  'a_subj(6.Sudden).2',
#  'a_subj(6.Sudden).4',
#  'a_subj(6.Sudden).6',
#  'a_subj(6.Sudden).8',
#  'a_subj(6.Sudden).10',
#  'a_subj(6.Sudden).12',
#  'a_subj(7.Gradual).1',
#  'a_subj(7.Gradual).3',
#  'a_subj(7.Gradual).5',
#  'a_subj(7.Gradual).7',
#  'a_subj(7.Gradual).9',
#  'a_subj(7.Gradual).11',
#  'a_subj(7.Gradual).13',
#  'a_subj(7.Sudden).0',
#  'a_subj(7.Sudden).2',
#  'a_subj(7.Sudden).4',
#  'a_subj(7.Sudden).6',
#  'a_subj(7.Sudden).8',
#  'a_subj(7.Sudden).10',
#  'a_subj(7.Sudden).12',
#  'a_subj(8.Gradual).1',
#  'a_subj(8.Gradual).3',
#  'a_subj(8.Gradual).5',
#  'a_subj(8.Gradual).7',
#  'a_subj(8.Gradual).9',
#  'a_subj(8.Gradual).11',
#  'a_subj(8.Gradual).13',
#  'a_subj(8.Sudden).0',
#  'a_subj(8.Sudden).2',
#  'a_subj(8.Sudden).4',
#  'a_subj(8.Sudden).6',
#  'a_subj(8.Sudden).8',
#  'a_subj(8.Sudden).10',
#  'a_subj(8.Sudden).12',
#  'a_subj(9.Gradual).1',
#  'a_subj(9.Gradual).3',
#  'a_subj(9.Gradual).5',
#  'a_subj(9.Gradual).7',
#  'a_subj(9.Gradual).9',
#  'a_subj(9.Gradual).11',
#  'a_subj(9.Gradual).13',
#  'a_subj(9.Sudden).0',
#  'a_subj(9.Sudden).2',
#  'a_subj(9.Sudden).4',
#  'a_subj(9.Sudden).6',
#  'a_subj(9.Sudden).8',
#  'a_subj(9.Sudden).10',
#  'a_subj(9.Sudden).12',
#  'a_subj(10.Gradual).1',
#  'a_subj(10.Gradual).3',
#  'a_subj(10.Gradual).5',
#  'a_subj(10.Gradual).7',
#  'a_subj(10.Gradual).9',
#  'a_subj(10.Gradual).11',
#  'a_subj(10.Gradual).13',
#  'a_subj(10.Sudden).0',
#  'a_subj(10.Sudden).2',
#  'a_subj(10.Sudden).4',
#  'a_subj(10.Sudden).6',
#  'a_subj(10.Sudden).8',
#  'a_subj(10.Sudden).10',
#  'a_subj(10.Sudden).12',
#  'a_subj(11.Gradual).1',
#  'a_subj(11.Gradual).3',
#  'a_subj(11.Gradual).5',
#  'a_subj(11.Gradual).7',
#  'a_subj(11.Gradual).9',
#  'a_subj(11.Gradual).11',
#  'a_subj(11.Gradual).13',
#  'a_subj(11.Sudden).0',
#  'a_subj(11.Sudden).2',
#  'a_subj(11.Sudden).4',
#  'a_subj(11.Sudden).6',
#  'a_subj(11.Sudden).8',
#  'a_subj(11.Sudden).10',
#  'a_subj(11.Sudden).12',
#  'v(0.Gradual)',
#  'v(0.Sudden)',
#  'v(1.Gradual)',
#  'v(1.Sudden)',
#  'v(2.Gradual)',
#  'v(2.Sudden)',
#  'v(3.Gradual)',
#  'v(3.Sudden)',
#  'v(4.Gradual)',
#  'v(4.Sudden)',
#  'v(5.Gradual)',
#  'v(5.Sudden)',
#  'v(6.Gradual)',
#  'v(6.Sudden)',
#  'v(7.Gradual)',
#  'v(7.Sudden)',
#  'v(8.Gradual)',
#  'v(8.Sudden)',
#  'v(9.Gradual)',
#  'v(9.Sudden)',
#  'v(10.Gradual)',
#  'v(10.Sudden)',
#  'v(11.Gradual)',
#  'v(11.Sudden)',
#  'v_std',
#  'v_subj(0.Gradual).1',
#  'v_subj(0.Gradual).3',
#  'v_subj(0.Gradual).5',
#  'v_subj(0.Gradual).7',
#  'v_subj(0.Gradual).9',
#  'v_subj(0.Gradual).11',
#  'v_subj(0.Gradual).13',
#  'v_subj(0.Sudden).0',
#  'v_subj(0.Sudden).2',
#  'v_subj(0.Sudden).4',
#  'v_subj(0.Sudden).6',
#  'v_subj(0.Sudden).8',
#  'v_subj(0.Sudden).10',
#  'v_subj(0.Sudden).12',
#  'v_subj(1.Gradual).1',
#  'v_subj(1.Gradual).3',
#  'v_subj(1.Gradual).5',
#  'v_subj(1.Gradual).7',
#  'v_subj(1.Gradual).9',
#  'v_subj(1.Gradual).11',
#  'v_subj(1.Gradual).13',
#  'v_subj(1.Sudden).0',
#  'v_subj(1.Sudden).2',
#  'v_subj(1.Sudden).4',
#  'v_subj(1.Sudden).6',
#  'v_subj(1.Sudden).8',
#  'v_subj(1.Sudden).10',
#  'v_subj(1.Sudden).12',
#  'v_subj(2.Gradual).1',
#  'v_subj(2.Gradual).3',
#  'v_subj(2.Gradual).5',
#  'v_subj(2.Gradual).7',
#  'v_subj(2.Gradual).9',
#  'v_subj(2.Gradual).11',
#  'v_subj(2.Gradual).13',
#  'v_subj(2.Sudden).0',
#  'v_subj(2.Sudden).2',
#  'v_subj(2.Sudden).4',
#  'v_subj(2.Sudden).6',
#  'v_subj(2.Sudden).8',
#  'v_subj(2.Sudden).10',
#  'v_subj(2.Sudden).12',
#  'v_subj(3.Gradual).1',
#  'v_subj(3.Gradual).3',
#  'v_subj(3.Gradual).5',
#  'v_subj(3.Gradual).7',
#  'v_subj(3.Gradual).9',
#  'v_subj(3.Gradual).11',
#  'v_subj(3.Gradual).13',
#  'v_subj(3.Sudden).0',
#  'v_subj(3.Sudden).2',
#  'v_subj(3.Sudden).4',
#  'v_subj(3.Sudden).6',
#  'v_subj(3.Sudden).8',
#  'v_subj(3.Sudden).10',
#  'v_subj(3.Sudden).12',
#  'v_subj(4.Gradual).1',
#  'v_subj(4.Gradual).3',
#  'v_subj(4.Gradual).5',
#  'v_subj(4.Gradual).7',
#  'v_subj(4.Gradual).9',
#  'v_subj(4.Gradual).11',
#  'v_subj(4.Gradual).13',
#  'v_subj(4.Sudden).0',
#  'v_subj(4.Sudden).2',
#  'v_subj(4.Sudden).4',
#  'v_subj(4.Sudden).6',
#  'v_subj(4.Sudden).8',
#  'v_subj(4.Sudden).10',
#  'v_subj(4.Sudden).12',
#  'v_subj(5.Gradual).1',
#  'v_subj(5.Gradual).3',
#  'v_subj(5.Gradual).5',
#  'v_subj(5.Gradual).7',
#  'v_subj(5.Gradual).9',
#  'v_subj(5.Gradual).11',
#  'v_subj(5.Gradual).13',
#  'v_subj(5.Sudden).0',
#  'v_subj(5.Sudden).2',
#  'v_subj(5.Sudden).4',
#  'v_subj(5.Sudden).6',
#  'v_subj(5.Sudden).8',
#  'v_subj(5.Sudden).10',
#  'v_subj(5.Sudden).12',
#  'v_subj(6.Gradual).1',
#  'v_subj(6.Gradual).3',
#  'v_subj(6.Gradual).5',
#  'v_subj(6.Gradual).7',
#  'v_subj(6.Gradual).9',
#  'v_subj(6.Gradual).11',
#  'v_subj(6.Gradual).13',
#  'v_subj(6.Sudden).0',
#  'v_subj(6.Sudden).2',
#  'v_subj(6.Sudden).4',
#  'v_subj(6.Sudden).6',
#  'v_subj(6.Sudden).8',
#  'v_subj(6.Sudden).10',
#  'v_subj(6.Sudden).12',
#  'v_subj(7.Gradual).1',
#  'v_subj(7.Gradual).3',
#  'v_subj(7.Gradual).5',
#  'v_subj(7.Gradual).7',
#  'v_subj(7.Gradual).9',
#  'v_subj(7.Gradual).11',
#  'v_subj(7.Gradual).13',
#  'v_subj(7.Sudden).0',
#  'v_subj(7.Sudden).2',
#  'v_subj(7.Sudden).4',
#  'v_subj(7.Sudden).6',
#  'v_subj(7.Sudden).8',
#  'v_subj(7.Sudden).10',
#  'v_subj(7.Sudden).12',
#  'v_subj(8.Gradual).1',
#  'v_subj(8.Gradual).3',
#  'v_subj(8.Gradual).5',
#  'v_subj(8.Gradual).7',
#  'v_subj(8.Gradual).9',
#  'v_subj(8.Gradual).11',
#  'v_subj(8.Gradual).13',
#  'v_subj(8.Sudden).0',
#  'v_subj(8.Sudden).2',
#  'v_subj(8.Sudden).4',
#  'v_subj(8.Sudden).6',
#  'v_subj(8.Sudden).8',
#  'v_subj(8.Sudden).10',
#  'v_subj(8.Sudden).12',
#  'v_subj(9.Gradual).1',
#  'v_subj(9.Gradual).3',
#  'v_subj(9.Gradual).5',
#  'v_subj(9.Gradual).7',
#  'v_subj(9.Gradual).9',
#  'v_subj(9.Gradual).11',
#  'v_subj(9.Gradual).13',
#  'v_subj(9.Sudden).0',
#  'v_subj(9.Sudden).2',
#  'v_subj(9.Sudden).4',
#  'v_subj(9.Sudden).6',
#  'v_subj(9.Sudden).8',
#  'v_subj(9.Sudden).10',
#  'v_subj(9.Sudden).12',
#  'v_subj(10.Gradual).1',
#  'v_subj(10.Gradual).3',
#  'v_subj(10.Gradual).5',
#  'v_subj(10.Gradual).7',
#  'v_subj(10.Gradual).9',
#  'v_subj(10.Gradual).11',
#  'v_subj(10.Gradual).13',
#  'v_subj(10.Sudden).0',
#  'v_subj(10.Sudden).2',
#  'v_subj(10.Sudden).4',
#  'v_subj(10.Sudden).6',
#  'v_subj(10.Sudden).8',
#  'v_subj(10.Sudden).10',
#  'v_subj(10.Sudden).12',
#  'v_subj(11.Gradual).1',
#  'v_subj(11.Gradual).3',
#  'v_subj(11.Gradual).5',
#  'v_subj(11.Gradual).7',
#  'v_subj(11.Gradual).9',
#  'v_subj(11.Gradual).11',
#  'v_subj(11.Gradual).13',
#  'v_subj(11.Sudden).0',
#  'v_subj(11.Sudden).2',
#  'v_subj(11.Sudden).4',
#  'v_subj(11.Sudden).6',
#  'v_subj(11.Sudden).8',
#  'v_subj(11.Sudden).10',
#  'v_subj(11.Sudden).12',
#  't',
#  't_std',
#  't_subj.0',
#  't_subj.1',
#  't_subj.2',
#  't_subj.3',
#  't_subj.4',
#  't_subj.5',
#  't_subj.6',
#  't_subj.7',
#  't_subj.8',
#  't_subj.9',
#  't_subj.10',
#  't_subj.11',
#  't_subj.12',
#  't_subj.13']

# %%
s[s['Unnamed: 0'] == 'a_subj(2.Gradual).1']
# Out:
#              Unnamed: 0      mean       std      2.5q       25q       50q  \
# 53  a_subj(2.Gradual).1  2.142611  0.124073  1.907156  2.056376  2.137411
#
#          75q     97.5q    mc err
# 53  2.223425  2.396321  0.001848

# %%
s[s['Unnamed: 0'] == 'a(2.Sudden)']
# Out:
#     Unnamed: 0      mean       std      2.5q       25q       50q       75q  \
# 5  a(2.Sudden)  2.591098  0.328239  1.929537  2.376166  2.592523  2.812906
#
#       97.5q    mc err
# 5  3.227496  0.003753
