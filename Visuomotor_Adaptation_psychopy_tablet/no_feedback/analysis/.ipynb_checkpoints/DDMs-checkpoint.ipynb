# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ddm import Model, Sample
from ddm import Model
from ddm.models import DriftConstant, NoiseConstant, BoundConstant, OverlayNonDecision, ICRange
from ddm.functions import fit_adjust_model, display_model
from ddm import Fittable
from ddm.models import LossRobustBIC, LossRobustLikelihood, LossSquaredError
from ddm.functions import fit_adjust_model, fit_model
import seaborn as sns

# %%
from ddm import set_N_cpus
set_N_cpus(8)

# %%
model_fits = np.zeros((14, 12, 4), dtype = object)
incorrect_thresold = np.array([np.pi/9])
for participant in range(14):
    noise_fittable=Fittable(minval = 0, maxval = 10)
    ter_fittable=Fittable(minval=0, maxval=5)
    for block in range(12):
        for ic in range(len(incorrect_thresold)):
            df_rt = pd.read_csv(open('RTs.csv'))
            df_error = pd.read_csv(open('Angular_errors.csv'))

            df_rt['Correct'] = 0
            df_rt['Correct'][df_error['Error'] < incorrect_thresold[ic]] = 1
            df_rt['Correct'][df_error['Error'] > incorrect_thresold[ic]] = 0

            df_rt = df_rt[df_rt['participant_id'] == participant]

            df_rt = df_rt[df_rt["ITs"] > .001]
            df_rt = df_rt[df_rt["ITs"] < 5]
            df_rt = df_rt.drop(['Trial', 'Unnamed: 0', 'participant_id', 'condition', 'MTs'], axis = 1)

            samp = Sample.from_pandas_dataframe(df_rt[df_rt['block'] == block], rt_column_name="ITs", correct_column_name="Correct")
            if block > 1:
                model_fit = Model(name='Simple model (fitted)',
                              drift=DriftConstant(drift=Fittable(minval=-100, maxval=200)),
                              noise=NoiseConstant(noise=model_fits[participant][1][ic].get_model_parameters()[1].real),                      
                              bound=BoundConstant(B=Fittable(minval = 0, maxval = 200)),
                              overlay=OverlayNonDecision(nondectime=model_fits[participant][1][ic].get_model_parameters()[3].real),
                              dx=.001, dt=.01, T_dur=5)
            else:
                model_fit = Model(name='Simple model (fitted)',
                              drift=DriftConstant(drift=Fittable(minval=-10, maxval=10)),
                              noise=NoiseConstant(noise=Fittable(minval = 0, maxval = 10)),                      
                              bound=BoundConstant(B=Fittable(minval = 0, maxval = 10)),
                              overlay=OverlayNonDecision(nondectime=Fittable(minval = 0, maxval = 1)),
                              dx=.001, dt=.01, T_dur=5)

            #try:
            fit_adjust_model(samp, model_fit,
                             fitting_method="differential_evolution",
                             lossfunction=LossRobustLikelihood, verbose=False)
            #except:
            #    print (participant, block)
            model_fits[participant][block][ic] = model_fit

# %%
model_fits[participant][block][0]

# %%
drift_rates = np.zeros((14, 12, len(incorrect_thresold)))
drift_noise = np.zeros((14, 12, len(incorrect_thresold)))
bounds = np.zeros((14, 12, len(incorrect_thresold)))
Ter = np.zeros((14, 12, len(incorrect_thresold)))
for participant in range(14):
    for block in range(12):
        for ic in range(len(incorrect_thresold)):
            if block > 1:
                drift_rates[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[0].real
                #drift_noise[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real
                drift_noise[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[1].real

                bounds[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real 
                #Ter[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[3].real
                Ter[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[3].real
            else:
                drift_rates[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[0].real
                drift_noise[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[1].real
                #drift_noise[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[1].real

                bounds[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[2].real 
                Ter[participant][block][ic] = model_fits[participant][block][ic].get_model_parameters()[3].real
                #Ter[participant][block][ic] = model_fits[participant][1][ic].get_model_parameters()[3].real

# %%
df_ddm = pd.DataFrame({'Condition': np.tile(np.ravel(np.array([np.repeat(['Sudden'], 12*len(incorrect_thresold)), np.repeat(['Gradual'], 12*len(incorrect_thresold))])), 7),
                       'Block': np.tile(np.repeat(np.arange(12), len(incorrect_thresold)), 14),
                      'Drift_Rates': np.ravel(drift_rates),
                       'Drift_Noise': np.ravel(drift_noise),
                       'Incorrect_Criterian':np.tile(np.array([20]), 12*14),
                      'Bounds': np.ravel(bounds),
                      'Ter': np.ravel(Ter)})

# %%
df_ddm

# %%
sns.catplot(x = 'Block', y = 'Bounds', data = df_ddm, kind='point', hue = 'Condition', ci = 95, col = 'Incorrect_Criterian', capsize = 0.2)

# %%
from ddm import Bound
class BoundBlocks(Bound):
    name = "constant"
    required_parameters = ["BBlock0", "BBlock1", "BBlock2", "BBlock3", "BBlock4", "BBlock5",
                          "BBlock6", "BBlock7", "BBlock8", "BBlock9", "BBlock10", "BBlock11"]
    required_conditions = ['block']
    def get_bound(self, conditions, *args, **kwargs):
        if conditions['block'] == 0:
            return self.BBlock0
        if conditions['block'] == 1:
            return self.BBlock1
        if conditions['block'] == 2:
            return self.BBlock2
        if conditions['block'] == 3:
            return self.BBlock3
        if conditions['block'] == 4:
            return self.BBlock4
        if conditions['block'] == 5:
            return self.BBlock5
        if conditions['block'] == 6:
            return self.BBlock6
        if conditions['block'] == 7:
            return self.BBlock7
        if conditions['block'] == 8:
            return self.BBlock8
        if conditions['block'] == 9:
            return self.BBlock9
        if conditions['block'] == 10:
            return self.BBlock10
        if conditions['block'] == 11:
            return self.BBlock11

# %%
from ddm import Drift
class DriftBlocks(Drift):
    name = "constant"
    required_parameters = ["VBlock0", "VBlock1", "VBlock2", "VBlock3", "VBlock4", "VBlock5",
                          "VBlock6", "VBlock7", "VBlock8", "VBlock9", "VBlock10", "VBlock11"]
    required_conditions = ['block']
    def get_drift(self, conditions, *args, **kwargs):
        if conditions['block'] == 0:
            return self.VBlock0
        if conditions['block'] == 1:
            return self.VBlock1
        if conditions['block'] == 2:
            return self.VBlock2
        if conditions['block'] == 3:
            return self.VBlock3
        if conditions['block'] == 4:
            return self.VBlock4
        if conditions['block'] == 5:
            return self.VBlock5
        if conditions['block'] == 6:
            return self.VBlock6
        if conditions['block'] == 7:
            return self.VBlock7
        if conditions['block'] == 8:
            return self.VBlock8
        if conditions['block'] == 9:
            return self.VBlock9
        if conditions['block'] == 10:
            return self.VBlock10
        if conditions['block'] == 11:
            return self.VBlock11

# %%
model_fits = np.zeros(14, dtype = object)
for participant in range(14):
    print(participant)
    df_rt = pd.read_csv(open('RTs.csv'))
    df_error = pd.read_csv(open('Angular_errors.csv'))

    df_rt['Correct'] = 0
    df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
    df_rt['Correct'][df_error['Error'] > np.pi/9] = 0

    df_rt = df_rt[df_rt['participant_id'] == participant]

    df_rt = df_rt[df_rt["ITs"] > .001]
    df_rt = df_rt[df_rt["ITs"] < 5]
    df_rt = df_rt.drop(['Trial', 'Unnamed: 0', 'participant_id', 'condition', 'MTs'], axis = 1)

    samp = Sample.from_pandas_dataframe(df_rt, rt_column_name="ITs", correct_column_name="Correct")
    
    model_fits[participant] = fit_model(samp, bound=BoundBlocks(BBlock0 = Fittable(minval = 0, maxval = 20),
                               BBlock1 = Fittable(minval = 0, maxval = 20),
                               BBlock2 = Fittable(minval = 0, maxval = 20),
                               BBlock3 = Fittable(minval = 0, maxval = 20),
                               BBlock4 = Fittable(minval = 0, maxval = 20),
                               BBlock5 = Fittable(minval = 0, maxval = 20),
                               BBlock6 = Fittable(minval = 0, maxval = 20),
                               BBlock7 = Fittable(minval = 0, maxval = 20),
                               BBlock8 = Fittable(minval = 0, maxval = 20),
                               BBlock9 = Fittable(minval = 0, maxval = 20),
                               BBlock10 = Fittable(minval = 0, maxval = 20),
                               BBlock11 = Fittable(minval = 0, maxval = 20)),
              
              drift=DriftBlocks(VBlock0 = Fittable(minval = -20, maxval = 20),
                               VBlock1 = Fittable(minval = -20, maxval = 20),
                               VBlock2 = Fittable(minval = -20, maxval = 20),
                               VBlock3 = Fittable(minval = -20, maxval = 20),
                               VBlock4 = Fittable(minval = -20, maxval = 20),
                               VBlock5 = Fittable(minval = -20, maxval = 20),
                               VBlock6 = Fittable(minval = -20, maxval = 20),
                               VBlock7 = Fittable(minval = -20, maxval = 20),
                               VBlock8 = Fittable(minval = -20, maxval = 20),
                               VBlock9 = Fittable(minval = -20, maxval = 20),
                               VBlock10 = Fittable(minval = -20, maxval = 20),
                               VBlock11 = Fittable(minval = -20, maxval = 20)),
              
              overlay=OverlayNonDecision(nondectime=Fittable(minval=0, maxval=0.5)),
              
              noise=NoiseConstant(noise=Fittable(minval=0.01, maxval=5)), 
              lossfunction=LossRobustLikelihood, verbose = False
             )
# Out:
# 0
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 3293.48
# differential_evolution step 2: f(x)= 3221.94
# differential_evolution step 3: f(x)= 2628.8
# differential_evolution step 4: f(x)= 2628.8
# differential_evolution step 5: f(x)= 2628.8
# differential_evolution step 6: f(x)= 2356.39
# differential_evolution step 7: f(x)= 2233.13
# differential_evolution step 8: f(x)= 2233.13
# differential_evolution step 9: f(x)= 2233.13
# differential_evolution step 10: f(x)= 2233.13
# differential_evolution step 11: f(x)= 2233.13
# differential_evolution step 12: f(x)= 2233.13
# differential_evolution step 13: f(x)= 1861.49
# differential_evolution step 14: f(x)= 1861.49
# differential_evolution step 15: f(x)= 1501.59
# differential_evolution step 16: f(x)= 1501.59
# differential_evolution step 17: f(x)= 1501.59
# differential_evolution step 18: f(x)= 1501.59
# differential_evolution step 19: f(x)= 1501.59
# differential_evolution step 20: f(x)= 1501.59
# differential_evolution step 21: f(x)= 1501.59
# differential_evolution step 22: f(x)= 1423
# differential_evolution step 23: f(x)= 1423
# differential_evolution step 24: f(x)= 1405.32
# differential_evolution step 25: f(x)= 1405.32
# differential_evolution step 26: f(x)= 1319.74
# differential_evolution step 27: f(x)= 1261.34
# differential_evolution step 28: f(x)= 1261.34
# differential_evolution step 29: f(x)= 1261.34
# differential_evolution step 30: f(x)= 1219.45
# differential_evolution step 31: f(x)= 1219.45
# differential_evolution step 32: f(x)= 1218.3
# differential_evolution step 33: f(x)= 1218.3
# differential_evolution step 34: f(x)= 1218.3
# differential_evolution step 35: f(x)= 1097.34
# differential_evolution step 36: f(x)= 1097.34
# differential_evolution step 37: f(x)= 1097.34
# differential_evolution step 38: f(x)= 1097.34
# differential_evolution step 39: f(x)= 1097.34
# differential_evolution step 40: f(x)= 1097.34
# differential_evolution step 41: f(x)= 1090.78
# differential_evolution step 42: f(x)= 1081.73
# differential_evolution step 43: f(x)= 1065.52
# differential_evolution step 44: f(x)= 1055.3
# differential_evolution step 45: f(x)= 1028.07
# differential_evolution step 46: f(x)= 1028.07
# differential_evolution step 47: f(x)= 1028.07
# differential_evolution step 48: f(x)= 1028.07
# differential_evolution step 49: f(x)= 1019.1
# differential_evolution step 50: f(x)= 1008.25
# differential_evolution step 51: f(x)= 1008.25
# differential_evolution step 52: f(x)= 1008.25
# differential_evolution step 53: f(x)= 1008.25
# differential_evolution step 54: f(x)= 996.184
# differential_evolution step 55: f(x)= 991.319
# differential_evolution step 56: f(x)= 991.319
# differential_evolution step 57: f(x)= 986.143
# differential_evolution step 58: f(x)= 986.143
# differential_evolution step 59: f(x)= 976.223
# differential_evolution step 60: f(x)= 970.075
# differential_evolution step 61: f(x)= 970.075
# differential_evolution step 62: f(x)= 970.075
# differential_evolution step 63: f(x)= 958.573
# differential_evolution step 64: f(x)= 958.135
# differential_evolution step 65: f(x)= 958.135
# differential_evolution step 66: f(x)= 953.632
# differential_evolution step 67: f(x)= 953.632
# differential_evolution step 68: f(x)= 953.632
# differential_evolution step 69: f(x)= 953.632
# differential_evolution step 70: f(x)= 946.294
# differential_evolution step 71: f(x)= 946.294
# differential_evolution step 72: f(x)= 945.673
# differential_evolution step 73: f(x)= 942.425
# differential_evolution step 74: f(x)= 942.343
# differential_evolution step 75: f(x)= 942.343
# differential_evolution step 76: f(x)= 938.568
# Params [-1.42192018e+01 -2.26564700e-04  2.37929320e+00  3.92541820e+00
#   1.86533544e+00  2.61173867e+00  4.64675043e+00  6.36274126e+00
#   7.13765032e+00  4.06749987e+00  8.44777900e-01  6.46365396e+00
#   4.60881503e+00  5.60202468e+00  6.17483684e+00  6.55395433e+00
#   7.48291147e+00  4.97243084e+00  6.19240831e+00  8.26010907e+00
#   5.89648821e+00  7.08659642e+00  5.05267914e+00  5.21087335e+00
#   6.53054743e+00  1.90699715e-03] gave 929.0636106481005
# 1
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 2444.82
# differential_evolution step 2: f(x)= 2404.61
# differential_evolution step 3: f(x)= 2062.04
# differential_evolution step 4: f(x)= 2062.04
# differential_evolution step 5: f(x)= 2025.25
# differential_evolution step 6: f(x)= 1524.46
# differential_evolution step 7: f(x)= 1509.11
# differential_evolution step 8: f(x)= 1509.11
# differential_evolution step 9: f(x)= 1509.11
# differential_evolution step 10: f(x)= 1384.3
# differential_evolution step 11: f(x)= 1384.3
# differential_evolution step 12: f(x)= 1328.21
# differential_evolution step 13: f(x)= 1328.21
# differential_evolution step 14: f(x)= 1328.21
# differential_evolution step 15: f(x)= 1234.18
# differential_evolution step 16: f(x)= 1193.46
# differential_evolution step 17: f(x)= 1155.84
# differential_evolution step 18: f(x)= 1153.39
# differential_evolution step 19: f(x)= 1153.39
# differential_evolution step 20: f(x)= 1151.91
# differential_evolution step 21: f(x)= 1151.91
# differential_evolution step 22: f(x)= 1094.89
# differential_evolution step 23: f(x)= 1094.89
# differential_evolution step 24: f(x)= 1089.57
# differential_evolution step 25: f(x)= 1089.57
# differential_evolution step 26: f(x)= 1089.57
# differential_evolution step 27: f(x)= 1074.64
# differential_evolution step 28: f(x)= 1070.3
# differential_evolution step 29: f(x)= 1046.39
# differential_evolution step 30: f(x)= 993.883
# differential_evolution step 31: f(x)= 993.883
# differential_evolution step 32: f(x)= 970.048
# differential_evolution step 33: f(x)= 962.267
# differential_evolution step 34: f(x)= 962.267
# differential_evolution step 35: f(x)= 962.267
# differential_evolution step 36: f(x)= 928.807
# differential_evolution step 37: f(x)= 928.807
# differential_evolution step 38: f(x)= 921.483
# differential_evolution step 39: f(x)= 921.483
# differential_evolution step 40: f(x)= 921.483
# differential_evolution step 41: f(x)= 921.483
# differential_evolution step 42: f(x)= 921.483
# differential_evolution step 43: f(x)= 921.483
# differential_evolution step 44: f(x)= 921.483
# differential_evolution step 45: f(x)= 921.483
# differential_evolution step 46: f(x)= 921.483
# differential_evolution step 47: f(x)= 921.483
# differential_evolution step 48: f(x)= 921.483
# differential_evolution step 49: f(x)= 909.295
# differential_evolution step 50: f(x)= 909.295
# differential_evolution step 51: f(x)= 909.295
# differential_evolution step 52: f(x)= 909.295
# differential_evolution step 53: f(x)= 909.295
# differential_evolution step 54: f(x)= 909.295
# differential_evolution step 55: f(x)= 908.505
# differential_evolution step 56: f(x)= 880.047
# differential_evolution step 57: f(x)= 872.509
# differential_evolution step 58: f(x)= 859.201
# differential_evolution step 59: f(x)= 859.201
# differential_evolution step 60: f(x)= 859.201
# differential_evolution step 61: f(x)= 858.146
# differential_evolution step 62: f(x)= 858.146
# differential_evolution step 63: f(x)= 847.296
# differential_evolution step 64: f(x)= 845.14
# differential_evolution step 65: f(x)= 843.879
# differential_evolution step 66: f(x)= 843.879
# differential_evolution step 67: f(x)= 843.879
# differential_evolution step 68: f(x)= 841.864
# differential_evolution step 69: f(x)= 841.864
# Params [-20.           3.87222032  -0.30978715  -4.2454007    5.05501824
#    5.39949728   3.04661378   1.71326091   3.32796848   3.24983551
#    3.9861862    7.26029733   3.85613179  12.80154806   4.66489199
#    4.21750415   7.71774062   5.22555186   5.96744651   5.73263996
#    5.12919021   6.06519791   5.85349333   6.1670257    4.9574913
#    0.39147047] gave 827.597763352844
# 2
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 1218.18
# differential_evolution step 2: f(x)= 1218.18
# differential_evolution step 3: f(x)= 1189.52
# differential_evolution step 4: f(x)= 1189.52
# differential_evolution step 5: f(x)= 925.552
# differential_evolution step 6: f(x)= 925.552
# differential_evolution step 7: f(x)= 814.141
# differential_evolution step 8: f(x)= 814.141
# differential_evolution step 9: f(x)= 814.141
# differential_evolution step 10: f(x)= 528.087
# differential_evolution step 11: f(x)= 528.087
# differential_evolution step 12: f(x)= 528.087
# differential_evolution step 13: f(x)= 528.087
# differential_evolution step 14: f(x)= 528.087
# differential_evolution step 15: f(x)= 499.617
# differential_evolution step 16: f(x)= 499.617
# differential_evolution step 17: f(x)= 499.617
# differential_evolution step 18: f(x)= 499.617
# differential_evolution step 19: f(x)= 499.617
# differential_evolution step 20: f(x)= 368.016
# differential_evolution step 21: f(x)= 368.016
# differential_evolution step 22: f(x)= 368.016
# differential_evolution step 23: f(x)= 368.016
# differential_evolution step 24: f(x)= 368.016
# differential_evolution step 25: f(x)= 368.016
# differential_evolution step 26: f(x)= 320.103
# differential_evolution step 27: f(x)= 320.103
# differential_evolution step 28: f(x)= 320.103
# differential_evolution step 29: f(x)= 278.084
# differential_evolution step 30: f(x)= 278.084
# differential_evolution step 31: f(x)= 278.084
# differential_evolution step 32: f(x)= 278.084
# differential_evolution step 33: f(x)= 278.084
# differential_evolution step 34: f(x)= 278.084
# differential_evolution step 35: f(x)= 278.084
# differential_evolution step 36: f(x)= 278.084
# differential_evolution step 37: f(x)= 266.631
# differential_evolution step 38: f(x)= 266.631
# differential_evolution step 39: f(x)= 266.631
# differential_evolution step 40: f(x)= 266.631
# differential_evolution step 41: f(x)= 266.631
# differential_evolution step 42: f(x)= 256.29
# differential_evolution step 43: f(x)= 256.29
# differential_evolution step 44: f(x)= 256.064
# differential_evolution step 45: f(x)= 230.946
# differential_evolution step 46: f(x)= 230.946
# differential_evolution step 47: f(x)= 230.946
# differential_evolution step 48: f(x)= 228.182
# differential_evolution step 49: f(x)= 222.004
# differential_evolution step 50: f(x)= 219.14
# differential_evolution step 51: f(x)= 219.14
# differential_evolution step 52: f(x)= 219.14
# differential_evolution step 53: f(x)= 219.14
# differential_evolution step 54: f(x)= 219.14
# differential_evolution step 55: f(x)= 207.944
# differential_evolution step 56: f(x)= 207.944
# differential_evolution step 57: f(x)= 207.944
# differential_evolution step 58: f(x)= 207.944
# differential_evolution step 59: f(x)= 207.944
# differential_evolution step 60: f(x)= 207.944
# differential_evolution step 61: f(x)= 207.944
# differential_evolution step 62: f(x)= 207.944
# differential_evolution step 63: f(x)= 207.944
# differential_evolution step 64: f(x)= 207.944
# differential_evolution step 65: f(x)= 207.944
# differential_evolution step 66: f(x)= 207.944
# differential_evolution step 67: f(x)= 207.944
# differential_evolution step 68: f(x)= 207.944
# differential_evolution step 69: f(x)= 207.944
# differential_evolution step 70: f(x)= 207.944
# differential_evolution step 71: f(x)= 207.944
# differential_evolution step 72: f(x)= 207.944
# differential_evolution step 73: f(x)= 204.8
# differential_evolution step 74: f(x)= 204.8
# differential_evolution step 75: f(x)= 204.8
# differential_evolution step 76: f(x)= 204.8
# differential_evolution step 77: f(x)= 204.8
# differential_evolution step 78: f(x)= 204.8
# differential_evolution step 79: f(x)= 204.8
# differential_evolution step 80: f(x)= 204.8
# differential_evolution step 81: f(x)= 204.8
# differential_evolution step 82: f(x)= 204.8
# differential_evolution step 83: f(x)= 204.8
# differential_evolution step 84: f(x)= 204.8
# differential_evolution step 85: f(x)= 204.8
# differential_evolution step 86: f(x)= 204.8
# differential_evolution step 87: f(x)= 204.8
# differential_evolution step 88: f(x)= 204.566
# differential_evolution step 89: f(x)= 204.566
# differential_evolution step 90: f(x)= 204.534
# differential_evolution step 91: f(x)= 203.216
# differential_evolution step 92: f(x)= 203.216
# differential_evolution step 93: f(x)= 203.216
# differential_evolution step 94: f(x)= 203.216
# differential_evolution step 95: f(x)= 203.216
# differential_evolution step 96: f(x)= 203.216
# differential_evolution step 97: f(x)= 202.535
# differential_evolution step 98: f(x)= 202.535
# differential_evolution step 99: f(x)= 202.535
# differential_evolution step 100: f(x)= 202.535
# differential_evolution step 101: f(x)= 202.535
# differential_evolution step 102: f(x)= 200.68
# differential_evolution step 103: f(x)= 200.68
# differential_evolution step 104: f(x)= 200.68
# differential_evolution step 105: f(x)= 200.68
# differential_evolution step 106: f(x)= 200.68
# differential_evolution step 107: f(x)= 200.68
# differential_evolution step 108: f(x)= 200.68
# differential_evolution step 109: f(x)= 200.68
# differential_evolution step 110: f(x)= 200.68
# differential_evolution step 111: f(x)= 200.68
# differential_evolution step 112: f(x)= 200.68
# differential_evolution step 113: f(x)= 200.68
# differential_evolution step 114: f(x)= 200.68
# differential_evolution step 115: f(x)= 200.68
# differential_evolution step 116: f(x)= 200.68
# differential_evolution step 117: f(x)= 200.68
# differential_evolution step 118: f(x)= 200.68
# differential_evolution step 119: f(x)= 200.68
# differential_evolution step 120: f(x)= 200.68
# differential_evolution step 121: f(x)= 200.68
# differential_evolution step 122: f(x)= 200.68
# differential_evolution step 123: f(x)= 200.68
# differential_evolution step 124: f(x)= 200.451
# differential_evolution step 125: f(x)= 200.451
# differential_evolution step 126: f(x)= 200.451
# differential_evolution step 127: f(x)= 200.451
# differential_evolution step 128: f(x)= 200.451
# differential_evolution step 129: f(x)= 199.672
# differential_evolution step 130: f(x)= 199.672
# differential_evolution step 131: f(x)= 199.672
# differential_evolution step 132: f(x)= 199.672
# differential_evolution step 133: f(x)= 199.672
# differential_evolution step 134: f(x)= 199.384
# differential_evolution step 135: f(x)= 199.384
# Params [-16.92102024  -8.81266663  -7.83528194 -14.24173817 -11.4558113
#  -12.73845971  -6.43405452 -16.98106166 -16.14789472 -13.92564402
#  -13.98041335 -11.12191322   4.79610835   8.07580495  11.28799362
#    8.21898693  13.3349826   11.19198325  12.82467933   6.31287486
#   12.60979781  10.28091116   9.29765433   9.71515324   6.65500357
#    0.34675771] gave 197.2070579542834
# 3
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 3014.58
# differential_evolution step 2: f(x)= 2092.97
# differential_evolution step 3: f(x)= 2092.97
# differential_evolution step 4: f(x)= 2092.97
# differential_evolution step 5: f(x)= 2049.28
# differential_evolution step 6: f(x)= 1481.57
# differential_evolution step 7: f(x)= 1481.57
# differential_evolution step 8: f(x)= 1481.57
# differential_evolution step 9: f(x)= 1018.71
# differential_evolution step 10: f(x)= 1018.71
# differential_evolution step 11: f(x)= 1018.71
# differential_evolution step 12: f(x)= 862.755
# differential_evolution step 13: f(x)= 862.755
# differential_evolution step 14: f(x)= 862.755
# differential_evolution step 15: f(x)= 862.755
# differential_evolution step 16: f(x)= 862.755
# differential_evolution step 17: f(x)= 862.755
# differential_evolution step 18: f(x)= 862.755
# differential_evolution step 19: f(x)= 862.755
# differential_evolution step 20: f(x)= 862.755
# differential_evolution step 21: f(x)= 862.755
# differential_evolution step 22: f(x)= 862.755
# differential_evolution step 23: f(x)= 862.755
# differential_evolution step 24: f(x)= 862.755
# differential_evolution step 25: f(x)= 862.755
# differential_evolution step 26: f(x)= 862.755
# differential_evolution step 27: f(x)= 862.755
# differential_evolution step 28: f(x)= 808.543
# differential_evolution step 29: f(x)= 808.543
# differential_evolution step 30: f(x)= 808.543
# differential_evolution step 31: f(x)= 783.629
# differential_evolution step 32: f(x)= 783.629
# differential_evolution step 33: f(x)= 719.336
# differential_evolution step 34: f(x)= 716.861
# differential_evolution step 35: f(x)= 714.929
# differential_evolution step 36: f(x)= 676.701
# differential_evolution step 37: f(x)= 666.792
# differential_evolution step 38: f(x)= 666.792
# differential_evolution step 39: f(x)= 666.792
# differential_evolution step 40: f(x)= 666.792
# differential_evolution step 41: f(x)= 666.36
# differential_evolution step 42: f(x)= 666.36
# differential_evolution step 43: f(x)= 666.36
# differential_evolution step 44: f(x)= 660.168
# differential_evolution step 45: f(x)= 660.168
# differential_evolution step 46: f(x)= 660.168
# differential_evolution step 47: f(x)= 660.168
# differential_evolution step 48: f(x)= 660.168
# differential_evolution step 49: f(x)= 660.168
# differential_evolution step 50: f(x)= 660.168
# differential_evolution step 51: f(x)= 651.437
# differential_evolution step 52: f(x)= 614.022
# differential_evolution step 53: f(x)= 614.022
# differential_evolution step 54: f(x)= 614.022
# differential_evolution step 55: f(x)= 606.501
# differential_evolution step 56: f(x)= 606.501
# differential_evolution step 57: f(x)= 606.501
# differential_evolution step 58: f(x)= 606.501
# differential_evolution step 59: f(x)= 604.734
# differential_evolution step 60: f(x)= 604.734
# differential_evolution step 61: f(x)= 604.734
# differential_evolution step 62: f(x)= 604.734
# differential_evolution step 63: f(x)= 604.734
# differential_evolution step 64: f(x)= 599.699
# differential_evolution step 65: f(x)= 599.026
# differential_evolution step 66: f(x)= 597.071
# differential_evolution step 67: f(x)= 597.071
# differential_evolution step 68: f(x)= 597.071
# differential_evolution step 69: f(x)= 587.823
# differential_evolution step 70: f(x)= 587.823
# differential_evolution step 71: f(x)= 587.823
# differential_evolution step 72: f(x)= 587.823
# differential_evolution step 73: f(x)= 587.823
# differential_evolution step 74: f(x)= 587.823
# differential_evolution step 75: f(x)= 587.823
# differential_evolution step 76: f(x)= 585.616
# differential_evolution step 77: f(x)= 585.616
# differential_evolution step 78: f(x)= 585.616
# differential_evolution step 79: f(x)= 585.616
# differential_evolution step 80: f(x)= 585.616
# differential_evolution step 81: f(x)= 585.616
# differential_evolution step 82: f(x)= 585.049
# differential_evolution step 83: f(x)= 585.049
# differential_evolution step 84: f(x)= 582.175
# differential_evolution step 85: f(x)= 581.896
# differential_evolution step 86: f(x)= 581.896
# differential_evolution step 87: f(x)= 580.781
# differential_evolution step 88: f(x)= 580.781
# differential_evolution step 89: f(x)= 580.781
# differential_evolution step 90: f(x)= 580.781
# differential_evolution step 91: f(x)= 580.781
# differential_evolution step 92: f(x)= 579.337
# differential_evolution step 93: f(x)= 579.337
# differential_evolution step 94: f(x)= 579.337
# differential_evolution step 95: f(x)= 579.337
# differential_evolution step 96: f(x)= 579.337
# differential_evolution step 97: f(x)= 579.337
# Params [ 16.66196724  13.4137342    0.59711712  -8.92263471  -9.72707368
#  -10.15460408 -12.92773104  -8.30397654  -9.39424561  -1.02758407
#    4.16891      7.4573642    5.          11.60995624  10.80638088
#    4.63666937   7.97049485   8.43671455   9.0131437   10.22809897
#    9.17907355   9.99953863   6.3218954    7.26332823   7.18483577
#    0.12232328] gave 566.9412915955195
# 4
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 2094.52
# differential_evolution step 2: f(x)= 1770.36
# differential_evolution step 3: f(x)= 1770.36
# differential_evolution step 4: f(x)= 1548.06
# differential_evolution step 5: f(x)= 1383.69
# differential_evolution step 6: f(x)= 1144.26
# differential_evolution step 7: f(x)= 1092.21
# differential_evolution step 8: f(x)= 1092.21
# differential_evolution step 9: f(x)= 1092.21
# differential_evolution step 10: f(x)= 1031.48
# differential_evolution step 11: f(x)= 1031.48
# differential_evolution step 12: f(x)= 1031.48
# differential_evolution step 13: f(x)= 1031.48
# differential_evolution step 14: f(x)= 931.696
# differential_evolution step 15: f(x)= 931.696
# differential_evolution step 16: f(x)= 908.355
# differential_evolution step 17: f(x)= 908.355
# differential_evolution step 18: f(x)= 908.355
# differential_evolution step 19: f(x)= 908.355
# differential_evolution step 20: f(x)= 908.355
# differential_evolution step 21: f(x)= 813.524
# differential_evolution step 22: f(x)= 745.219
# differential_evolution step 23: f(x)= 745.219
# differential_evolution step 24: f(x)= 687.647
# differential_evolution step 25: f(x)= 667.095
# differential_evolution step 26: f(x)= 667.095
# differential_evolution step 27: f(x)= 667.095
# differential_evolution step 28: f(x)= 667.095
# differential_evolution step 29: f(x)= 637.572
# differential_evolution step 30: f(x)= 563.651
# differential_evolution step 31: f(x)= 563.651
# differential_evolution step 32: f(x)= 563.651
# differential_evolution step 33: f(x)= 563.651
# differential_evolution step 34: f(x)= 563.651
# differential_evolution step 35: f(x)= 563.651
# differential_evolution step 36: f(x)= 563.651
# differential_evolution step 37: f(x)= 563.651
# differential_evolution step 38: f(x)= 563.651
# differential_evolution step 39: f(x)= 563.651
# differential_evolution step 40: f(x)= 563.651
# differential_evolution step 41: f(x)= 563.651
# differential_evolution step 42: f(x)= 563.651
# differential_evolution step 43: f(x)= 563.651
# differential_evolution step 44: f(x)= 525.078
# differential_evolution step 45: f(x)= 525.078
# differential_evolution step 46: f(x)= 525.078
# differential_evolution step 47: f(x)= 525.078
# differential_evolution step 48: f(x)= 514.689
# differential_evolution step 49: f(x)= 514.689
# differential_evolution step 50: f(x)= 514.689
# differential_evolution step 51: f(x)= 504.481
# differential_evolution step 52: f(x)= 454.057
# differential_evolution step 53: f(x)= 454.057
# differential_evolution step 54: f(x)= 454.057
# differential_evolution step 55: f(x)= 454.057
# differential_evolution step 56: f(x)= 454.057
# differential_evolution step 57: f(x)= 437.9
# differential_evolution step 58: f(x)= 437.9
# differential_evolution step 59: f(x)= 437.9
# differential_evolution step 60: f(x)= 437.9
# differential_evolution step 61: f(x)= 437.9
# differential_evolution step 62: f(x)= 437.9
# differential_evolution step 63: f(x)= 437.9
# differential_evolution step 64: f(x)= 424.02
# differential_evolution step 65: f(x)= 424.02
# differential_evolution step 66: f(x)= 424.02
# differential_evolution step 67: f(x)= 424.02
# differential_evolution step 68: f(x)= 424.02
# differential_evolution step 69: f(x)= 424.02
# differential_evolution step 70: f(x)= 423.163
# differential_evolution step 71: f(x)= 423.163
# differential_evolution step 72: f(x)= 421.293
# differential_evolution step 73: f(x)= 405.478
# differential_evolution step 74: f(x)= 405.478
# differential_evolution step 75: f(x)= 405.478
# differential_evolution step 76: f(x)= 405.478
# differential_evolution step 77: f(x)= 405.478
# differential_evolution step 78: f(x)= 405.478
# differential_evolution step 79: f(x)= 405.478
# differential_evolution step 80: f(x)= 404.898
# differential_evolution step 81: f(x)= 404.898
# differential_evolution step 82: f(x)= 404.898
# differential_evolution step 83: f(x)= 391.276
# differential_evolution step 84: f(x)= 391.276
# differential_evolution step 85: f(x)= 387.342
# differential_evolution step 86: f(x)= 387.342
# differential_evolution step 87: f(x)= 387.342
# differential_evolution step 88: f(x)= 387.342
# differential_evolution step 89: f(x)= 387.342
# differential_evolution step 90: f(x)= 387.342
# differential_evolution step 91: f(x)= 386.113
# differential_evolution step 92: f(x)= 384.633
# differential_evolution step 93: f(x)= 384.633
# differential_evolution step 94: f(x)= 384.633
# differential_evolution step 95: f(x)= 384.224
# differential_evolution step 96: f(x)= 383.299
# differential_evolution step 97: f(x)= 381.488
# differential_evolution step 98: f(x)= 379.514
# differential_evolution step 99: f(x)= 375.647
# differential_evolution step 100: f(x)= 373.308
# differential_evolution step 101: f(x)= 373.308
# differential_evolution step 102: f(x)= 372.767
# differential_evolution step 103: f(x)= 372.767
# differential_evolution step 104: f(x)= 372.666
# differential_evolution step 105: f(x)= 372.106
# differential_evolution step 106: f(x)= 371.637
# differential_evolution step 107: f(x)= 371.637
# differential_evolution step 108: f(x)= 371.637
# differential_evolution step 109: f(x)= 371.637
# differential_evolution step 110: f(x)= 371.637
# Params [ -9.11312692  -3.94369324  -6.38678531  -8.21512424 -15.73991262
#  -11.91065082  -5.6087682  -19.99999613  -9.28044401  -5.83137204
#   -1.93303965  -9.84510778   4.56370269   4.84960116   4.99674955
#    6.14738718   8.42047714  11.41889754   8.81176036   6.17022388
#   12.26873739   6.5908363    5.20304312   4.24195516   5.06136667
#    0.30769095] gave 363.77378416629006
# 5
# <ipython-input-65-c07f6662b8fc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-65-c07f6662b8fc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['Correct'][df_error['Error'] > np.pi/9] = 0
# differential_evolution step 1: f(x)= 2381.84
# differential_evolution step 2: f(x)= 2381.84
# differential_evolution step 3: f(x)= 1803.16
# differential_evolution step 4: f(x)= 1803.16
# differential_evolution step 5: f(x)= 1803.16
# differential_evolution step 6: f(x)= 1803.16
# differential_evolution step 7: f(x)= 1803.16
# differential_evolution step 8: f(x)= 1803.16
# differential_evolution step 9: f(x)= 1729.14
# differential_evolution step 10: f(x)= 1709.74
# differential_evolution step 11: f(x)= 1500.02
# differential_evolution step 12: f(x)= 1426.04
# differential_evolution step 13: f(x)= 1426.04
# differential_evolution step 14: f(x)= 1426.04
# differential_evolution step 15: f(x)= 1426.04
# differential_evolution step 16: f(x)= 1426.04
# differential_evolution step 17: f(x)= 1350.16
# differential_evolution step 18: f(x)= 1350.16
# differential_evolution step 19: f(x)= 1094.75
# differential_evolution step 20: f(x)= 1094.75
# differential_evolution step 21: f(x)= 1094.75
# differential_evolution step 22: f(x)= 1094.75
# differential_evolution step 23: f(x)= 1094.75
# differential_evolution step 24: f(x)= 1094.75
# differential_evolution step 25: f(x)= 1094.75
# differential_evolution step 26: f(x)= 1094.75
# differential_evolution step 27: f(x)= 1094.75
# differential_evolution step 28: f(x)= 988.949
# differential_evolution step 29: f(x)= 988.949
# differential_evolution step 30: f(x)= 988.949
# differential_evolution step 31: f(x)= 988.949
# differential_evolution step 32: f(x)= 988.949
# differential_evolution step 33: f(x)= 927.403
# differential_evolution step 34: f(x)= 927.403
# differential_evolution step 35: f(x)= 914.763
# differential_evolution step 36: f(x)= 914.763
# differential_evolution step 37: f(x)= 901.001
# differential_evolution step 38: f(x)= 875.838
# differential_evolution step 39: f(x)= 875.838
# differential_evolution step 40: f(x)= 875.838
# differential_evolution step 41: f(x)= 850.626
# differential_evolution step 42: f(x)= 850.626
# differential_evolution step 43: f(x)= 850.626
# differential_evolution step 44: f(x)= 802.191
# differential_evolution step 45: f(x)= 801.113
# differential_evolution step 46: f(x)= 801.113
# differential_evolution step 47: f(x)= 791.697
# differential_evolution step 48: f(x)= 791.697
# differential_evolution step 49: f(x)= 791.697
# differential_evolution step 50: f(x)= 791.697
# differential_evolution step 51: f(x)= 791.697
# differential_evolution step 52: f(x)= 791.697
# differential_evolution step 53: f(x)= 743.156
# differential_evolution step 54: f(x)= 743.156
# differential_evolution step 55: f(x)= 743.156
# differential_evolution step 56: f(x)= 743.156
# differential_evolution step 57: f(x)= 743.156
# differential_evolution step 58: f(x)= 743.156
# differential_evolution step 59: f(x)= 743.156
# differential_evolution step 60: f(x)= 730.482
# differential_evolution step 61: f(x)= 730.482
# differential_evolution step 62: f(x)= 719.327
# differential_evolution step 63: f(x)= 719.327
# differential_evolution step 64: f(x)= 719.327
# differential_evolution step 65: f(x)= 719.327
# differential_evolution step 66: f(x)= 719.327
# differential_evolution step 67: f(x)= 719.327
# differential_evolution step 68: f(x)= 719.327
# differential_evolution step 69: f(x)= 719.327
# differential_evolution step 70: f(x)= 716.789
# differential_evolution step 71: f(x)= 716.789
# differential_evolution step 72: f(x)= 716.789
# differential_evolution step 73: f(x)= 716.789
# differential_evolution step 74: f(x)= 703.463
# differential_evolution step 75: f(x)= 703.463
# differential_evolution step 76: f(x)= 703.463
# differential_evolution step 77: f(x)= 703.463
# differential_evolution step 78: f(x)= 703.463
# differential_evolution step 79: f(x)= 698.127
# differential_evolution step 80: f(x)= 698.127
# differential_evolution step 81: f(x)= 698.127
# differential_evolution step 82: f(x)= 698.127
# differential_evolution step 83: f(x)= 696.49
# differential_evolution step 84: f(x)= 696.49
# differential_evolution step 85: f(x)= 696.49
# differential_evolution step 86: f(x)= 696.49
# differential_evolution step 87: f(x)= 696.49
# differential_evolution step 88: f(x)= 696.49
# differential_evolution step 89: f(x)= 696.49
# differential_evolution step 90: f(x)= 691.37
# differential_evolution step 91: f(x)= 691.37
# differential_evolution step 92: f(x)= 691.37
# differential_evolution step 93: f(x)= 691.37
# differential_evolution step 94: f(x)= 691.37
# differential_evolution step 95: f(x)= 691.37
# differential_evolution step 96: f(x)= 687.229
# differential_evolution step 97: f(x)= 687.229
# differential_evolution step 98: f(x)= 687.229
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-c07f6662b8fc> in <module>
#      17     samp = Sample.from_pandas_dataframe(df_rt, rt_column_name="ITs", correct_column_name="Correct")
#      18
# ---> 19     model_fits[participant] = fit_model(samp, bound=BoundBlocks(BBlock0 = Fittable(minval = 0, maxval = 20),
#      20                                BBlock1 = Fittable(minval = 0, maxval = 20),
#      21                                BBlock2 = Fittable(minval = 0, maxval = 20),
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in fit_model(sample, drift, noise, bound, IC, dt, dx, fitparams, fitting_method, method, overlay, lossfunction, verbose, name, verify)
#     172     # of the model.
#     173     m = copy.deepcopy(Model(name=name, drift=drift, noise=noise, bound=bound, IC=IC, overlay=overlay, T_dur=T_dur, dt=dt, dx=dx))
# --> 174     return fit_adjust_model(sample, m, fitparams=fitparams, fitting_method=fitting_method,
#     175                             method=method, lossfunction=lossfunction, verbose=verbose)
#     176
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in fit_adjust_model(sample, model, fitparams, fitting_method, lossfunction, verify, method, verbose)
#     343         x_fit = basinhopping(_fit_model, x_0, minimizer_kwargs={"bounds" : constraints, "method" : "TNC"}, disp=True, **fitparams)
#     344     elif fitting_method == "differential_evolution":
# --> 345         x_fit = differential_evolution(_fit_model, constraints, disp=True, **fitparams)
#     346     elif fitting_method == "hillclimb":
#     347         x_fit = evolution_strategy(_fit_model, x_0, **fitparams)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints)
#     306                                      workers=workers,
#     307                                      constraints=constraints) as solver:
# --> 308         ret = solver.solve()
#     309
#     310     return ret
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in solve(self)
#     808                                   " infeasible solution", UserWarning)
#     809
# --> 810             result = minimize(self.func,
#     811                               np.copy(DE_result.x),
#     812                               method=polish_method,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     615                                   **options)
#     616     elif meth == 'l-bfgs-b':
# --> 617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#
# ~\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentialevolution.py in __call__(self, x)
#    1259
#    1260     def __call__(self, x):
# -> 1261         return self.f(x, *self.args)
#    1262
#    1263
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in _fit_model(xs)
#     327                 x = p.minval
#     328             s(m, x)
# --> 329         lossf = lf.loss(m)
#     330         if verbose:
#     331             print(repr(m), "loss="+ str(lossf))
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\models\loss.py in loss(self, model)
#     168     def loss(self, model):
#     169         assert model.dt == self.dt and model.T_dur == self.T_dur
# --> 170         sols = self.cache_by_conditions(model)
#     171         loglikelihood = 0
#     172         for k in sols.keys():
#
# ~\anaconda3\lib\site-packages\ddm\models\loss.py in cache_by_conditions(self, model)
#      94         """
#      95         from ..functions import solve_all_conditions
# ---> 96         return solve_all_conditions(model, self.sample, conditions=self.required_conditions, method=self.method)
#      97
#      98 @paranoidclass
#
# ~\anaconda3\lib\site-packages\ddm\functions.py in solve_all_conditions(model, sample, conditions, method)
#     473     if _parallel_pool is None: # No parallelization
#     474         for c in conds:
# --> 475             cache[frozenset(c.items())] = meth(conditions=c)
#     476         return cache
#     477     else: # Parallelize across pool
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\model.py in solve(self, conditions, return_evolution)
#     479         self.check_conditions_satisfied(conditions)
#     480         if self.has_analytical_solution() and return_evolution is False:
# --> 481             return self.solve_analytical(conditions=conditions)
#     482         elif isinstance(self.get_dependence("bound"), BoundConstant) and return_evolution is False:
#     483             return self.solve_numerical_cn(conditions=conditions)
#
# ~\anaconda3\lib\site-packages\paranoid\decorators.py in _decorated(*args, **kwargs)
#     112         # Skip verification if paranoid is disabled.
#     113         if Settings.get("enabled", function=func) == False:
# --> 114             return func(*args, **kwargs)
#     115         # We only run this function once for performance reasons, and
#     116         # then pass it as an argument to each check function.
#
# ~\anaconda3\lib\site-packages\ddm\model.py in solve_analytical(self, conditions)
#     518                                                        self.t_domain(), shift, -self.get_dependence("bound").t) # TODO why must this be negative? -MS
#     519         else: # Constant bound DDM
# --> 520             anal_pdf_corr, anal_pdf_err = analytic_ddm(self.get_dependence("drift").get_drift(t=0, conditions=conditions),
#     521                                                        self.get_dependence("noise").get_noise(t=0, conditions=conditions),
#     522                                                        self.get_dependence("bound").get_bound(t=0, conditions=conditions),
#
# ~\anaconda3\lib\site-packages\ddm\analytic.py in analytic_ddm(drift, noise, b, teval, shift, b_slope)
#      91     teval_valid = teval[b+b_slope*teval>0]
#      92
# ---> 93     dist_cor = analytic_ddm_linbound(b_upper, -drift+b_slope, -b_lower, -drift-b_slope, teval_valid)
#      94     dist_err = analytic_ddm_linbound(b_lower,  drift+b_slope, -b_upper,  drift-b_slope, teval_valid)
#      95
#
# ~\anaconda3\lib\site-packages\ddm\analytic.py in analytic_ddm_linbound(a1, b1, a2, b2, teval)
#      43         # Break when the relative increment is low for three consecutive updates
#      44         # np.where statement avoids dividing by 0
# ---> 45         if np.max(np.abs(inc/np.where(suminc==0,1e-30,suminc))) < errbnd:
#      46             checkerr += 1
#      47             if checkerr == 3:
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2703     5
#    2704     """
# -> 2705     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2706                           keepdims=keepdims, initial=initial, where=where)
#    2707
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
import pickle
pickle.dump(model_fits, open('ddm_model_point_fits.pickle', 'wb'))

# %% [markdown]
# # Using HDDMs

# %%
import hddm
# Out:
# C:\Users\Tejas\anaconda3\lib\site-packages\IPython\parallel.py:12: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   warn("The `IPython.parallel` package has been deprecated since IPython 4.0. "

# %%
df_rt = hddm.load_csv('RTs.csv')

# %%
df_rt = df_rt.drop(['Unnamed: 0', 'MTs'], axis = 1)
df_error = pd.read_csv(open('Angular_errors.csv'))

df_rt['response'] = 0
df_rt['response'][df_error['Error'] < np.pi/9] = 1
df_rt['response'][df_error['Error'] > np.pi/9] = 0
# Out:
# <ipython-input-4-f9c3b37dc88a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['response'][df_error['Error'] < np.pi/9] = 1
# <ipython-input-4-f9c3b37dc88a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rt['response'][df_error['Error'] > np.pi/9] = 0

# %%
df_rt = df_rt.rename(columns={'participant_id': 'subj_idx', 'ITs':'rt'})

# %%
m = hddm.HDDM(df_rt)

# %%
m.find_starting_values()
# Out:
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.

# %%
m.sample(2000, burn = 20)
# Out:
#  [-----------------100%-----------------] 2000 of 2000 complete in 460.4 sec

# %%
stats = m.gen_stats()

# %%
stats[stats.index.isin(['a', 'a_std', 'a_subj.0', 'a_subj.1'])]
# Out:
#               mean        std      2.5q       25q       50q       75q  \
# a          2.13484   0.194851   1.78852   2.00406   2.12462   2.24595
# a_std     0.726409   0.183406  0.455013  0.596192  0.694274  0.831464
# a_subj.0   1.97159  0.0450135   1.88241    1.9412   1.97107   2.00136
# a_subj.1   2.33866  0.0607831   2.22544   2.29638   2.33684   2.37999
#
#             97.5q      mc err
# a          2.5731  0.00693227
# a_std     1.17195  0.00860781
# a_subj.0  2.05996  0.00141201
# a_subj.1  2.46379    0.002478

# %%
m.plot_posteriors(['a', 't', 'v', 'a_std'])
# Out:
# Plotting a
# Plotting a_std
# Plotting v
# Plotting t

# %%
m_stim = hddm.HDDM(df_rt, depends_on={'v': ['block', 'condition'], 'a':['block', 'condition']})

# %%
m_stim.find_starting_values()
# Out:
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.
# Warning: Powell optimization failed. Falling back to simplex.

# %%
m_stim.sample(10000, burn=1000)
# Out:
#  [-----------------100%-----------------] 10001 of 10000 complete in 4698.1 sec

# %%
stats = m_stim.gen_stats()

# %%
stats.to_csv('hddm_fits.csv')

# %%
s = pd.read_csv('hddm_fits.csv')

# %%
list(s['Unnamed: 0'])
# Out:
# ['a(0.Gradual)',
#  'a(0.Sudden)',
#  'a(1.Gradual)',
#  'a(1.Sudden)',
#  'a(2.Gradual)',
#  'a(2.Sudden)',
#  'a(3.Gradual)',
#  'a(3.Sudden)',
#  'a(4.Gradual)',
#  'a(4.Sudden)',
#  'a(5.Gradual)',
#  'a(5.Sudden)',
#  'a(6.Gradual)',
#  'a(6.Sudden)',
#  'a(7.Gradual)',
#  'a(7.Sudden)',
#  'a(8.Gradual)',
#  'a(8.Sudden)',
#  'a(9.Gradual)',
#  'a(9.Sudden)',
#  'a(10.Gradual)',
#  'a(10.Sudden)',
#  'a(11.Gradual)',
#  'a(11.Sudden)',
#  'a_std',
#  'a_subj(0.Gradual).1',
#  'a_subj(0.Gradual).3',
#  'a_subj(0.Gradual).5',
#  'a_subj(0.Gradual).7',
#  'a_subj(0.Gradual).9',
#  'a_subj(0.Gradual).11',
#  'a_subj(0.Gradual).13',
#  'a_subj(0.Sudden).0',
#  'a_subj(0.Sudden).2',
#  'a_subj(0.Sudden).4',
#  'a_subj(0.Sudden).6',
#  'a_subj(0.Sudden).8',
#  'a_subj(0.Sudden).10',
#  'a_subj(0.Sudden).12',
#  'a_subj(1.Gradual).1',
#  'a_subj(1.Gradual).3',
#  'a_subj(1.Gradual).5',
#  'a_subj(1.Gradual).7',
#  'a_subj(1.Gradual).9',
#  'a_subj(1.Gradual).11',
#  'a_subj(1.Gradual).13',
#  'a_subj(1.Sudden).0',
#  'a_subj(1.Sudden).2',
#  'a_subj(1.Sudden).4',
#  'a_subj(1.Sudden).6',
#  'a_subj(1.Sudden).8',
#  'a_subj(1.Sudden).10',
#  'a_subj(1.Sudden).12',
#  'a_subj(2.Gradual).1',
#  'a_subj(2.Gradual).3',
#  'a_subj(2.Gradual).5',
#  'a_subj(2.Gradual).7',
#  'a_subj(2.Gradual).9',
#  'a_subj(2.Gradual).11',
#  'a_subj(2.Gradual).13',
#  'a_subj(2.Sudden).0',
#  'a_subj(2.Sudden).2',
#  'a_subj(2.Sudden).4',
#  'a_subj(2.Sudden).6',
#  'a_subj(2.Sudden).8',
#  'a_subj(2.Sudden).10',
#  'a_subj(2.Sudden).12',
#  'a_subj(3.Gradual).1',
#  'a_subj(3.Gradual).3',
#  'a_subj(3.Gradual).5',
#  'a_subj(3.Gradual).7',
#  'a_subj(3.Gradual).9',
#  'a_subj(3.Gradual).11',
#  'a_subj(3.Gradual).13',
#  'a_subj(3.Sudden).0',
#  'a_subj(3.Sudden).2',
#  'a_subj(3.Sudden).4',
#  'a_subj(3.Sudden).6',
#  'a_subj(3.Sudden).8',
#  'a_subj(3.Sudden).10',
#  'a_subj(3.Sudden).12',
#  'a_subj(4.Gradual).1',
#  'a_subj(4.Gradual).3',
#  'a_subj(4.Gradual).5',
#  'a_subj(4.Gradual).7',
#  'a_subj(4.Gradual).9',
#  'a_subj(4.Gradual).11',
#  'a_subj(4.Gradual).13',
#  'a_subj(4.Sudden).0',
#  'a_subj(4.Sudden).2',
#  'a_subj(4.Sudden).4',
#  'a_subj(4.Sudden).6',
#  'a_subj(4.Sudden).8',
#  'a_subj(4.Sudden).10',
#  'a_subj(4.Sudden).12',
#  'a_subj(5.Gradual).1',
#  'a_subj(5.Gradual).3',
#  'a_subj(5.Gradual).5',
#  'a_subj(5.Gradual).7',
#  'a_subj(5.Gradual).9',
#  'a_subj(5.Gradual).11',
#  'a_subj(5.Gradual).13',
#  'a_subj(5.Sudden).0',
#  'a_subj(5.Sudden).2',
#  'a_subj(5.Sudden).4',
#  'a_subj(5.Sudden).6',
#  'a_subj(5.Sudden).8',
#  'a_subj(5.Sudden).10',
#  'a_subj(5.Sudden).12',
#  'a_subj(6.Gradual).1',
#  'a_subj(6.Gradual).3',
#  'a_subj(6.Gradual).5',
#  'a_subj(6.Gradual).7',
#  'a_subj(6.Gradual).9',
#  'a_subj(6.Gradual).11',
#  'a_subj(6.Gradual).13',
#  'a_subj(6.Sudden).0',
#  'a_subj(6.Sudden).2',
#  'a_subj(6.Sudden).4',
#  'a_subj(6.Sudden).6',
#  'a_subj(6.Sudden).8',
#  'a_subj(6.Sudden).10',
#  'a_subj(6.Sudden).12',
#  'a_subj(7.Gradual).1',
#  'a_subj(7.Gradual).3',
#  'a_subj(7.Gradual).5',
#  'a_subj(7.Gradual).7',
#  'a_subj(7.Gradual).9',
#  'a_subj(7.Gradual).11',
#  'a_subj(7.Gradual).13',
#  'a_subj(7.Sudden).0',
#  'a_subj(7.Sudden).2',
#  'a_subj(7.Sudden).4',
#  'a_subj(7.Sudden).6',
#  'a_subj(7.Sudden).8',
#  'a_subj(7.Sudden).10',
#  'a_subj(7.Sudden).12',
#  'a_subj(8.Gradual).1',
#  'a_subj(8.Gradual).3',
#  'a_subj(8.Gradual).5',
#  'a_subj(8.Gradual).7',
#  'a_subj(8.Gradual).9',
#  'a_subj(8.Gradual).11',
#  'a_subj(8.Gradual).13',
#  'a_subj(8.Sudden).0',
#  'a_subj(8.Sudden).2',
#  'a_subj(8.Sudden).4',
#  'a_subj(8.Sudden).6',
#  'a_subj(8.Sudden).8',
#  'a_subj(8.Sudden).10',
#  'a_subj(8.Sudden).12',
#  'a_subj(9.Gradual).1',
#  'a_subj(9.Gradual).3',
#  'a_subj(9.Gradual).5',
#  'a_subj(9.Gradual).7',
#  'a_subj(9.Gradual).9',
#  'a_subj(9.Gradual).11',
#  'a_subj(9.Gradual).13',
#  'a_subj(9.Sudden).0',
#  'a_subj(9.Sudden).2',
#  'a_subj(9.Sudden).4',
#  'a_subj(9.Sudden).6',
#  'a_subj(9.Sudden).8',
#  'a_subj(9.Sudden).10',
#  'a_subj(9.Sudden).12',
#  'a_subj(10.Gradual).1',
#  'a_subj(10.Gradual).3',
#  'a_subj(10.Gradual).5',
#  'a_subj(10.Gradual).7',
#  'a_subj(10.Gradual).9',
#  'a_subj(10.Gradual).11',
#  'a_subj(10.Gradual).13',
#  'a_subj(10.Sudden).0',
#  'a_subj(10.Sudden).2',
#  'a_subj(10.Sudden).4',
#  'a_subj(10.Sudden).6',
#  'a_subj(10.Sudden).8',
#  'a_subj(10.Sudden).10',
#  'a_subj(10.Sudden).12',
#  'a_subj(11.Gradual).1',
#  'a_subj(11.Gradual).3',
#  'a_subj(11.Gradual).5',
#  'a_subj(11.Gradual).7',
#  'a_subj(11.Gradual).9',
#  'a_subj(11.Gradual).11',
#  'a_subj(11.Gradual).13',
#  'a_subj(11.Sudden).0',
#  'a_subj(11.Sudden).2',
#  'a_subj(11.Sudden).4',
#  'a_subj(11.Sudden).6',
#  'a_subj(11.Sudden).8',
#  'a_subj(11.Sudden).10',
#  'a_subj(11.Sudden).12',
#  'v(0.Gradual)',
#  'v(0.Sudden)',
#  'v(1.Gradual)',
#  'v(1.Sudden)',
#  'v(2.Gradual)',
#  'v(2.Sudden)',
#  'v(3.Gradual)',
#  'v(3.Sudden)',
#  'v(4.Gradual)',
#  'v(4.Sudden)',
#  'v(5.Gradual)',
#  'v(5.Sudden)',
#  'v(6.Gradual)',
#  'v(6.Sudden)',
#  'v(7.Gradual)',
#  'v(7.Sudden)',
#  'v(8.Gradual)',
#  'v(8.Sudden)',
#  'v(9.Gradual)',
#  'v(9.Sudden)',
#  'v(10.Gradual)',
#  'v(10.Sudden)',
#  'v(11.Gradual)',
#  'v(11.Sudden)',
#  'v_std',
#  'v_subj(0.Gradual).1',
#  'v_subj(0.Gradual).3',
#  'v_subj(0.Gradual).5',
#  'v_subj(0.Gradual).7',
#  'v_subj(0.Gradual).9',
#  'v_subj(0.Gradual).11',
#  'v_subj(0.Gradual).13',
#  'v_subj(0.Sudden).0',
#  'v_subj(0.Sudden).2',
#  'v_subj(0.Sudden).4',
#  'v_subj(0.Sudden).6',
#  'v_subj(0.Sudden).8',
#  'v_subj(0.Sudden).10',
#  'v_subj(0.Sudden).12',
#  'v_subj(1.Gradual).1',
#  'v_subj(1.Gradual).3',
#  'v_subj(1.Gradual).5',
#  'v_subj(1.Gradual).7',
#  'v_subj(1.Gradual).9',
#  'v_subj(1.Gradual).11',
#  'v_subj(1.Gradual).13',
#  'v_subj(1.Sudden).0',
#  'v_subj(1.Sudden).2',
#  'v_subj(1.Sudden).4',
#  'v_subj(1.Sudden).6',
#  'v_subj(1.Sudden).8',
#  'v_subj(1.Sudden).10',
#  'v_subj(1.Sudden).12',
#  'v_subj(2.Gradual).1',
#  'v_subj(2.Gradual).3',
#  'v_subj(2.Gradual).5',
#  'v_subj(2.Gradual).7',
#  'v_subj(2.Gradual).9',
#  'v_subj(2.Gradual).11',
#  'v_subj(2.Gradual).13',
#  'v_subj(2.Sudden).0',
#  'v_subj(2.Sudden).2',
#  'v_subj(2.Sudden).4',
#  'v_subj(2.Sudden).6',
#  'v_subj(2.Sudden).8',
#  'v_subj(2.Sudden).10',
#  'v_subj(2.Sudden).12',
#  'v_subj(3.Gradual).1',
#  'v_subj(3.Gradual).3',
#  'v_subj(3.Gradual).5',
#  'v_subj(3.Gradual).7',
#  'v_subj(3.Gradual).9',
#  'v_subj(3.Gradual).11',
#  'v_subj(3.Gradual).13',
#  'v_subj(3.Sudden).0',
#  'v_subj(3.Sudden).2',
#  'v_subj(3.Sudden).4',
#  'v_subj(3.Sudden).6',
#  'v_subj(3.Sudden).8',
#  'v_subj(3.Sudden).10',
#  'v_subj(3.Sudden).12',
#  'v_subj(4.Gradual).1',
#  'v_subj(4.Gradual).3',
#  'v_subj(4.Gradual).5',
#  'v_subj(4.Gradual).7',
#  'v_subj(4.Gradual).9',
#  'v_subj(4.Gradual).11',
#  'v_subj(4.Gradual).13',
#  'v_subj(4.Sudden).0',
#  'v_subj(4.Sudden).2',
#  'v_subj(4.Sudden).4',
#  'v_subj(4.Sudden).6',
#  'v_subj(4.Sudden).8',
#  'v_subj(4.Sudden).10',
#  'v_subj(4.Sudden).12',
#  'v_subj(5.Gradual).1',
#  'v_subj(5.Gradual).3',
#  'v_subj(5.Gradual).5',
#  'v_subj(5.Gradual).7',
#  'v_subj(5.Gradual).9',
#  'v_subj(5.Gradual).11',
#  'v_subj(5.Gradual).13',
#  'v_subj(5.Sudden).0',
#  'v_subj(5.Sudden).2',
#  'v_subj(5.Sudden).4',
#  'v_subj(5.Sudden).6',
#  'v_subj(5.Sudden).8',
#  'v_subj(5.Sudden).10',
#  'v_subj(5.Sudden).12',
#  'v_subj(6.Gradual).1',
#  'v_subj(6.Gradual).3',
#  'v_subj(6.Gradual).5',
#  'v_subj(6.Gradual).7',
#  'v_subj(6.Gradual).9',
#  'v_subj(6.Gradual).11',
#  'v_subj(6.Gradual).13',
#  'v_subj(6.Sudden).0',
#  'v_subj(6.Sudden).2',
#  'v_subj(6.Sudden).4',
#  'v_subj(6.Sudden).6',
#  'v_subj(6.Sudden).8',
#  'v_subj(6.Sudden).10',
#  'v_subj(6.Sudden).12',
#  'v_subj(7.Gradual).1',
#  'v_subj(7.Gradual).3',
#  'v_subj(7.Gradual).5',
#  'v_subj(7.Gradual).7',
#  'v_subj(7.Gradual).9',
#  'v_subj(7.Gradual).11',
#  'v_subj(7.Gradual).13',
#  'v_subj(7.Sudden).0',
#  'v_subj(7.Sudden).2',
#  'v_subj(7.Sudden).4',
#  'v_subj(7.Sudden).6',
#  'v_subj(7.Sudden).8',
#  'v_subj(7.Sudden).10',
#  'v_subj(7.Sudden).12',
#  'v_subj(8.Gradual).1',
#  'v_subj(8.Gradual).3',
#  'v_subj(8.Gradual).5',
#  'v_subj(8.Gradual).7',
#  'v_subj(8.Gradual).9',
#  'v_subj(8.Gradual).11',
#  'v_subj(8.Gradual).13',
#  'v_subj(8.Sudden).0',
#  'v_subj(8.Sudden).2',
#  'v_subj(8.Sudden).4',
#  'v_subj(8.Sudden).6',
#  'v_subj(8.Sudden).8',
#  'v_subj(8.Sudden).10',
#  'v_subj(8.Sudden).12',
#  'v_subj(9.Gradual).1',
#  'v_subj(9.Gradual).3',
#  'v_subj(9.Gradual).5',
#  'v_subj(9.Gradual).7',
#  'v_subj(9.Gradual).9',
#  'v_subj(9.Gradual).11',
#  'v_subj(9.Gradual).13',
#  'v_subj(9.Sudden).0',
#  'v_subj(9.Sudden).2',
#  'v_subj(9.Sudden).4',
#  'v_subj(9.Sudden).6',
#  'v_subj(9.Sudden).8',
#  'v_subj(9.Sudden).10',
#  'v_subj(9.Sudden).12',
#  'v_subj(10.Gradual).1',
#  'v_subj(10.Gradual).3',
#  'v_subj(10.Gradual).5',
#  'v_subj(10.Gradual).7',
#  'v_subj(10.Gradual).9',
#  'v_subj(10.Gradual).11',
#  'v_subj(10.Gradual).13',
#  'v_subj(10.Sudden).0',
#  'v_subj(10.Sudden).2',
#  'v_subj(10.Sudden).4',
#  'v_subj(10.Sudden).6',
#  'v_subj(10.Sudden).8',
#  'v_subj(10.Sudden).10',
#  'v_subj(10.Sudden).12',
#  'v_subj(11.Gradual).1',
#  'v_subj(11.Gradual).3',
#  'v_subj(11.Gradual).5',
#  'v_subj(11.Gradual).7',
#  'v_subj(11.Gradual).9',
#  'v_subj(11.Gradual).11',
#  'v_subj(11.Gradual).13',
#  'v_subj(11.Sudden).0',
#  'v_subj(11.Sudden).2',
#  'v_subj(11.Sudden).4',
#  'v_subj(11.Sudden).6',
#  'v_subj(11.Sudden).8',
#  'v_subj(11.Sudden).10',
#  'v_subj(11.Sudden).12',
#  't',
#  't_std',
#  't_subj.0',
#  't_subj.1',
#  't_subj.2',
#  't_subj.3',
#  't_subj.4',
#  't_subj.5',
#  't_subj.6',
#  't_subj.7',
#  't_subj.8',
#  't_subj.9',
#  't_subj.10',
#  't_subj.11',
#  't_subj.12',
#  't_subj.13']

# %%
s[s['Unnamed: 0'] == 'a_subj(2.Gradual).1']
# Out:
#              Unnamed: 0      mean       std      2.5q       25q       50q  \
# 53  a_subj(2.Gradual).1  2.142611  0.124073  1.907156  2.056376  2.137411
#
#          75q     97.5q    mc err
# 53  2.223425  2.396321  0.001848

# %%
s[s['Unnamed: 0'] == 'a(2.Sudden)']
# Out:
#     Unnamed: 0      mean       std      2.5q       25q       50q       75q  \
# 5  a(2.Sudden)  2.591098  0.328239  1.929537  2.376166  2.592523  2.812906
#
#       97.5q    mc err
# 5  3.227496  0.003753
